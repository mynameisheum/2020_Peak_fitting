# %%
# %ls
# Out:
# '2,3peak mix.ipynb'
# '5peak 3 para when it worksss.ipynb'
# 'Fitting_with_noise (1).ipynb'
#  ITO_O1s_bg.txt
#  ITO_O1s_exp.txt
#  ITO_O1s_fitting.txt
#  ITO_O1s_p1.txt
#  ITO_O1s_p2.txt
#  ITO_O1s_p3.txt
#  P3HT_S2p_bg.txt
#  P3HT_S2p_exp.txt
#  P3HT_S2p_fitting.txt
#  P3HT_S2p_p1.txt
#  P3HT_S2p_p2.txt
#  PeakDetection.ipynb
#  Untitled.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#  amp.csv
#  amp2.csv
#  amp_1000.csv
#  center.csv
#  center2.csv
#  center_1000.csv
#  graph.csv
#  graph2.csv
#  graph_1000.csv
#  labels.png
#  model.png
#  model_shapes.png
#  peak_number.csv
#  peak_number2.csv
#  peak_number_1000.csv
#  width.csv
#  width2.csv
#  width_1000.csv
# '논문 수정.ipynb'
# '데이터 얻기.ipynb'
# '저장된 데이터로 학습하기.ipynb'
# '저장된 데이터로 학습하기10.ipynb'
# '저장된 데이터로 학습하기11.ipynb'
# '저장된 데이터로 학습하기12.ipynb'
# '저장된 데이터로 학습하기13.ipynb'
# '저장된 데이터로 학습하기14-model12(조언)가지고 newdata로 xps peak_number예측하기.ipynb'
# '저장된 데이터로 학습하기15 -data1가지고 model12랑 교수님 model 비교하기.ipynb'
# '저장된 데이터로 학습하기16- 교수님model로 data2로 error확인하기.ipynb'
# '저장된 데이터로 학습하기17-급생각난 2번째 모델 확인 data1.ipynb'
# '저장된 데이터로 학습하기17-급생각난 model- data1으로 확인하기 2트.ipynb'
# '저장된 데이터로 학습하기19- model12로 data_1000으로 학습해보기.ipynb'
# '저장된 데이터로 학습하기2.ipynb'
# '저장된 데이터로 학습하기3.ipynb'
# '저장된 데이터로 학습하기4.ipynb'
# '저장된 데이터로 학습하기5.ipynb'
# '저장된 데이터로 학습하기6.ipynb'
# '저장된 데이터로 학습하기7.ipynb'
# '저장된 데이터로 학습하기8.ipynb'
# '저장된 데이터로 학습하기9.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph_1000.csv').values[:,1:]
center= pd.read_csv('center_1000.csv').values[:,1:]
width= pd.read_csv('width_1000.csv').values[:,1:]
amp= pd.read_csv('amp_1000.csv').values[:,1:]
peak_number= pd.read_csv('peak_number_1000.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(10000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 9.21634859  9.48914101  9.6746136 ]
#  [ 0.         11.26168262 12.74836907]
#  [ 0.          2.12387114  9.04702466]
#  [ 0.          4.96145733  9.91188518]
#  [10.63243993 11.80271559 12.53915876]
#  [ 5.84923381  7.23810912 11.3910589 ]
#  [ 4.70379464  9.96620073 12.81918039]
#  [ 7.14544127  8.06876046 12.64873842]
#  [ 0.          2.08458974  4.24891576]
#  [ 0.          3.80133436 11.76971511]]
# [[1.60158595 1.66123993 0.90235706]
#  [0.         1.40923428 1.3445495 ]
#  [0.         0.78186738 1.13094031]
#  [0.         0.50000271 0.77473982]
#  [1.28667226 0.83949775 1.60972702]
#  [1.8723467  1.61165922 1.05612898]
#  [1.80163672 1.78406503 1.44740219]
#  [0.49529478 1.17637885 1.03014563]
#  [0.         1.3605233  1.35101147]
#  [0.         1.15216295 0.52992202]]
# [[0.26988555 0.18905789 0.24912559]
#  [0.         1.07340945 0.45921841]
#  [0.         0.291188   0.26308662]
#  [0.         1.01440076 0.94229748]
#  [0.33107535 0.92829788 0.97520786]
#  [0.28815727 0.4537231  0.81402281]
#  [0.88170608 0.77501342 0.74417037]
#  [0.80754933 0.50841855 0.35491888]
#  [0.         0.71395818 0.7864612 ]
#  [0.         0.71049866 0.27728167]]
# [3 2 2 2 3 3 3 3 2 2]
# (10000000, 3)
# (10000000, 3)
# (10000000, 3)
# (10000000,)
# (10000000, 401)
# [[ 0.01094473 -0.02272666  0.01609616 ... -0.03043683  0.02722137
#    0.02208656]
#  [-0.00780636  0.00322276  0.00940177 ...  0.01963256  0.01836803
#    0.0234588 ]
#  [ 0.01263877  0.00731667 -0.00526456 ...  0.01546713  0.01695805
#   -0.01905622]
#  ...
#  [ 0.03170691 -0.02419859 -0.00585362 ... -0.00227254  0.00109521
#    0.001506  ]
#  [ 0.01146607 -0.00638027 -0.02255473 ...  0.01860643 -0.01372592
#    0.01849033]
#  [-0.00469547  0.02259855 -0.05179253 ... -0.04310437  0.01702795
#    0.019531  ]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-8-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
# 90:9:1
data_number=5000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (9000000, 401) (900000, 401) (100000, 401)
# (9000000, 3) (900000, 3) (100000, 3)
# (9000000, 3) (900000, 3) (100000, 3)
# (9000000, 3) (900000, 3) (100000, 3)
# (9000000,) (900000,) (100000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (9000000, 401, 1)
# (900000, 401, 1)
# (100000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
input_data = Input(shape = (len(x), 1))

t = layers.Conv1D(32,100,strides=5,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(64,4,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,4,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(192,2,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)


Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(1, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(200, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(100, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(200,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(100,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(200,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(100,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
center_Batchnormalization  = BatchNormalization()(total_center1)
# total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center2 = Dense(3, activation = 'linear',name = 'total_center2')(center_Batchnormalization)


width_merge = concatenate([Dense3_peak_number,Dense3_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
width_Batchnormalization  = BatchNormalization()(total_width1)
# total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width2= Dense(3, activation = 'linear',name = 'total_width2')(width_Batchnormalization)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
amp_Batchnormalization  = BatchNormalization()(total_amp1)
# total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp2 = Dense(3, activation = 'linear',name = 'total_amp2')(amp_Batchnormalization)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center2,total_width2,total_amp2])
print(model.summary())
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 61, 32)       3232        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 30, 32)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 27, 64)       8256        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 13, 64)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 10, 128)      32896       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 5, 128)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 4, 192)       49344       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 2, 192)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 192)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 100)          20100       Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 100)          20100       Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 100)          20100       Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 1)            201         Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           4040        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           4040        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           4040        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           1680        concatenate[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           1680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           1680        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 40)           160         total_center1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 40)           160         total_width1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40)           160         total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 3)            123         batch_normalization[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 3)            123         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 3)            123         batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 366,838
# Trainable params: 366,598
# Non-trainable params: 240
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center2' : 'mse',
                      'total_width2' : 'mse',
                      'total_amp2' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 0.5,
#                            'total_width3' : 1,
#                            'total_amp3' : 1,
#                             'Dense3_peak_number' :1 },
              metrics = ['mae'])

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 100,
          batch_size = 5000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/100
# 1800/1800 [==============================] - 61s 34ms/step - loss: 5.1751 - Dense3_peak_number_loss: 0.0988 - total_center2_loss: 4.9512 - total_width2_loss: 0.0925 - total_amp2_loss: 0.0327 - Dense3_peak_number_mae: 0.2202 - total_center2_mae: 1.0550 - total_width2_mae: 0.1933 - total_amp2_mae: 0.1242 - val_loss: 0.3603 - val_Dense3_peak_number_loss: 0.0308 - val_total_center2_loss: 0.2737 - val_total_width2_loss: 0.0366 - val_total_amp2_loss: 0.0191 - val_Dense3_peak_number_mae: 0.1303 - val_total_center2_mae: 0.2872 - val_total_width2_mae: 0.1303 - val_total_amp2_mae: 0.0968
# Epoch 2/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.3129 - Dense3_peak_number_loss: 0.0221 - total_center2_loss: 0.2425 - total_width2_loss: 0.0319 - total_amp2_loss: 0.0165 - Dense3_peak_number_mae: 0.0906 - total_center2_mae: 0.2370 - total_width2_mae: 0.1146 - total_amp2_mae: 0.0846 - val_loss: 0.2636 - val_Dense3_peak_number_loss: 0.0115 - val_total_center2_loss: 0.2044 - val_total_width2_loss: 0.0312 - val_total_amp2_loss: 0.0164 - val_Dense3_peak_number_mae: 0.0557 - val_total_center2_mae: 0.2373 - val_total_width2_mae: 0.1223 - val_total_amp2_mae: 0.0866
# Epoch 3/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.2427 - Dense3_peak_number_loss: 0.0115 - total_center2_loss: 0.1908 - total_width2_loss: 0.0262 - total_amp2_loss: 0.0143 - Dense3_peak_number_mae: 0.0460 - total_center2_mae: 0.1970 - total_width2_mae: 0.1012 - total_amp2_mae: 0.0761 - val_loss: 1.3428 - val_Dense3_peak_number_loss: 0.0953 - val_total_center2_loss: 1.0988 - val_total_width2_loss: 0.1060 - val_total_amp2_loss: 0.0427 - val_Dense3_peak_number_mae: 0.1838 - val_total_center2_mae: 0.6068 - val_total_width2_mae: 0.2311 - val_total_amp2_mae: 0.1482
# Epoch 4/100
# 1800/1800 [==============================] - 59s 33ms/step - loss: 0.2168 - Dense3_peak_number_loss: 0.0101 - total_center2_loss: 0.1698 - total_width2_loss: 0.0237 - total_amp2_loss: 0.0133 - Dense3_peak_number_mae: 0.0380 - total_center2_mae: 0.1804 - total_width2_mae: 0.0947 - total_amp2_mae: 0.0725 - val_loss: 0.1942 - val_Dense3_peak_number_loss: 0.0071 - val_total_center2_loss: 0.1522 - val_total_width2_loss: 0.0217 - val_total_amp2_loss: 0.0132 - val_Dense3_peak_number_mae: 0.0273 - val_total_center2_mae: 0.1581 - val_total_width2_mae: 0.0906 - val_total_amp2_mae: 0.0723
# Epoch 5/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.1900 - Dense3_peak_number_loss: 0.0082 - total_center2_loss: 0.1487 - total_width2_loss: 0.0209 - total_amp2_loss: 0.0121 - Dense3_peak_number_mae: 0.0316 - total_center2_mae: 0.1628 - total_width2_mae: 0.0877 - total_amp2_mae: 0.0681 - val_loss: 0.1372 - val_Dense3_peak_number_loss: 0.0041 - val_total_center2_loss: 0.1040 - val_total_width2_loss: 0.0182 - val_total_amp2_loss: 0.0109 - val_Dense3_peak_number_mae: 0.0180 - val_total_center2_mae: 0.1405 - val_total_width2_mae: 0.0815 - val_total_amp2_mae: 0.0640
# Epoch 6/100
# 1800/1800 [==============================] - 60s 34ms/step - loss: 0.1642 - Dense3_peak_number_loss: 0.0066 - total_center2_loss: 0.1278 - total_width2_loss: 0.0186 - total_amp2_loss: 0.0112 - Dense3_peak_number_mae: 0.0272 - total_center2_mae: 0.1477 - total_width2_mae: 0.0823 - total_amp2_mae: 0.0646 - val_loss: 0.1293 - val_Dense3_peak_number_loss: 0.0038 - val_total_center2_loss: 0.0976 - val_total_width2_loss: 0.0173 - val_total_amp2_loss: 0.0105 - val_Dense3_peak_number_mae: 0.0224 - val_total_center2_mae: 0.1318 - val_total_width2_mae: 0.0844 - val_total_amp2_mae: 0.0643
# Epoch 7/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1487 - Dense3_peak_number_loss: 0.0056 - total_center2_loss: 0.1153 - total_width2_loss: 0.0172 - total_amp2_loss: 0.0105 - Dense3_peak_number_mae: 0.0250 - total_center2_mae: 0.1378 - total_width2_mae: 0.0785 - total_amp2_mae: 0.0620 - val_loss: 0.1303 - val_Dense3_peak_number_loss: 0.0033 - val_total_center2_loss: 0.1005 - val_total_width2_loss: 0.0163 - val_total_amp2_loss: 0.0101 - val_Dense3_peak_number_mae: 0.0159 - val_total_center2_mae: 0.1465 - val_total_width2_mae: 0.0806 - val_total_amp2_mae: 0.0621
# Epoch 8/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1424 - Dense3_peak_number_loss: 0.0053 - total_center2_loss: 0.1105 - total_width2_loss: 0.0164 - total_amp2_loss: 0.0102 - Dense3_peak_number_mae: 0.0240 - total_center2_mae: 0.1329 - total_width2_mae: 0.0763 - total_amp2_mae: 0.0606 - val_loss: 0.1166 - val_Dense3_peak_number_loss: 0.0034 - val_total_center2_loss: 0.0876 - val_total_width2_loss: 0.0152 - val_total_amp2_loss: 0.0104 - val_Dense3_peak_number_mae: 0.0171 - val_total_center2_mae: 0.1161 - val_total_width2_mae: 0.0736 - val_total_amp2_mae: 0.0633
# Epoch 9/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1334 - Dense3_peak_number_loss: 0.0047 - total_center2_loss: 0.1032 - total_width2_loss: 0.0156 - total_amp2_loss: 0.0099 - Dense3_peak_number_mae: 0.0216 - total_center2_mae: 0.1276 - total_width2_mae: 0.0742 - total_amp2_mae: 0.0593 - val_loss: 0.2453 - val_Dense3_peak_number_loss: 0.0106 - val_total_center2_loss: 0.2052 - val_total_width2_loss: 0.0184 - val_total_amp2_loss: 0.0112 - val_Dense3_peak_number_mae: 0.0314 - val_total_center2_mae: 0.1617 - val_total_width2_mae: 0.0811 - val_total_amp2_mae: 0.0664
# Epoch 10/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1300 - Dense3_peak_number_loss: 0.0047 - total_center2_loss: 0.1007 - total_width2_loss: 0.0149 - total_amp2_loss: 0.0096 - Dense3_peak_number_mae: 0.0215 - total_center2_mae: 0.1243 - total_width2_mae: 0.0725 - total_amp2_mae: 0.0580 - val_loss: 0.1416 - val_Dense3_peak_number_loss: 0.0041 - val_total_center2_loss: 0.1073 - val_total_width2_loss: 0.0196 - val_total_amp2_loss: 0.0106 - val_Dense3_peak_number_mae: 0.0158 - val_total_center2_mae: 0.1416 - val_total_width2_mae: 0.0919 - val_total_amp2_mae: 0.0642
# Epoch 11/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1193 - Dense3_peak_number_loss: 0.0040 - total_center2_loss: 0.0919 - total_width2_loss: 0.0141 - total_amp2_loss: 0.0092 - Dense3_peak_number_mae: 0.0189 - total_center2_mae: 0.1176 - total_width2_mae: 0.0700 - total_amp2_mae: 0.0563 - val_loss: 0.1032 - val_Dense3_peak_number_loss: 0.0026 - val_total_center2_loss: 0.0776 - val_total_width2_loss: 0.0142 - val_total_amp2_loss: 0.0089 - val_Dense3_peak_number_mae: 0.0124 - val_total_center2_mae: 0.1050 - val_total_width2_mae: 0.0711 - val_total_amp2_mae: 0.0542
# Epoch 12/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1240 - Dense3_peak_number_loss: 0.0043 - total_center2_loss: 0.0959 - total_width2_loss: 0.0145 - total_amp2_loss: 0.0094 - Dense3_peak_number_mae: 0.0186 - total_center2_mae: 0.1198 - total_width2_mae: 0.0707 - total_amp2_mae: 0.0566 - val_loss: 0.1357 - val_Dense3_peak_number_loss: 0.0044 - val_total_center2_loss: 0.1053 - val_total_width2_loss: 0.0169 - val_total_amp2_loss: 0.0091 - val_Dense3_peak_number_mae: 0.0183 - val_total_center2_mae: 0.1208 - val_total_width2_mae: 0.0789 - val_total_amp2_mae: 0.0555
# Epoch 13/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.1127 - Dense3_peak_number_loss: 0.0037 - total_center2_loss: 0.0868 - total_width2_loss: 0.0134 - total_amp2_loss: 0.0089 - Dense3_peak_number_mae: 0.0170 - total_center2_mae: 0.1126 - total_width2_mae: 0.0679 - total_amp2_mae: 0.0548 - val_loss: 0.1241 - val_Dense3_peak_number_loss: 0.0039 - val_total_center2_loss: 0.0960 - val_total_width2_loss: 0.0151 - val_total_amp2_loss: 0.0092 - val_Dense3_peak_number_mae: 0.0299 - val_total_center2_mae: 0.1102 - val_total_width2_mae: 0.0751 - val_total_amp2_mae: 0.0566
# Epoch 14/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.1105 - Dense3_peak_number_loss: 0.0036 - total_center2_loss: 0.0850 - total_width2_loss: 0.0131 - total_amp2_loss: 0.0088 - Dense3_peak_number_mae: 0.0168 - total_center2_mae: 0.1114 - total_width2_mae: 0.0672 - total_amp2_mae: 0.0545 - val_loss: 0.1043 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0792 - val_total_width2_loss: 0.0137 - val_total_amp2_loss: 0.0085 - val_Dense3_peak_number_mae: 0.0135 - val_total_center2_mae: 0.1059 - val_total_width2_mae: 0.0747 - val_total_amp2_mae: 0.0530
# Epoch 15/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.1092 - Dense3_peak_number_loss: 0.0036 - total_center2_loss: 0.0841 - total_width2_loss: 0.0128 - total_amp2_loss: 0.0086 - Dense3_peak_number_mae: 0.0171 - total_center2_mae: 0.1104 - total_width2_mae: 0.0662 - total_amp2_mae: 0.0537 - val_loss: 0.1053 - val_Dense3_peak_number_loss: 0.0032 - val_total_center2_loss: 0.0798 - val_total_width2_loss: 0.0129 - val_total_amp2_loss: 0.0093 - val_Dense3_peak_number_mae: 0.0160 - val_total_center2_mae: 0.1085 - val_total_width2_mae: 0.0667 - val_total_amp2_mae: 0.0601
# Epoch 16/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.1072 - Dense3_peak_number_loss: 0.0035 - total_center2_loss: 0.0825 - total_width2_loss: 0.0127 - total_amp2_loss: 0.0086 - Dense3_peak_number_mae: 0.0157 - total_center2_mae: 0.1093 - total_width2_mae: 0.0657 - total_amp2_mae: 0.0533 - val_loss: 0.0977 - val_Dense3_peak_number_loss: 0.0027 - val_total_center2_loss: 0.0743 - val_total_width2_loss: 0.0124 - val_total_amp2_loss: 0.0082 - val_Dense3_peak_number_mae: 0.0111 - val_total_center2_mae: 0.1036 - val_total_width2_mae: 0.0659 - val_total_amp2_mae: 0.0521
# Epoch 17/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.1068 - Dense3_peak_number_loss: 0.0036 - total_center2_loss: 0.0821 - total_width2_loss: 0.0126 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0155 - total_center2_mae: 0.1086 - total_width2_mae: 0.0653 - total_amp2_mae: 0.0529 - val_loss: 0.0918 - val_Dense3_peak_number_loss: 0.0024 - val_total_center2_loss: 0.0693 - val_total_width2_loss: 0.0119 - val_total_amp2_loss: 0.0082 - val_Dense3_peak_number_mae: 0.0111 - val_total_center2_mae: 0.1047 - val_total_width2_mae: 0.0635 - val_total_amp2_mae: 0.0518
# Epoch 18/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1017 - Dense3_peak_number_loss: 0.0032 - total_center2_loss: 0.0780 - total_width2_loss: 0.0122 - total_amp2_loss: 0.0083 - Dense3_peak_number_mae: 0.0143 - total_center2_mae: 0.1058 - total_width2_mae: 0.0642 - total_amp2_mae: 0.0521 - val_loss: 0.0889 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0666 - val_total_width2_loss: 0.0120 - val_total_amp2_loss: 0.0084 - val_Dense3_peak_number_mae: 0.0086 - val_total_center2_mae: 0.0978 - val_total_width2_mae: 0.0652 - val_total_amp2_mae: 0.0549
# Epoch 19/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.1064 - Dense3_peak_number_loss: 0.0036 - total_center2_loss: 0.0820 - total_width2_loss: 0.0125 - total_amp2_loss: 0.0083 - Dense3_peak_number_mae: 0.0153 - total_center2_mae: 0.1071 - total_width2_mae: 0.0648 - total_amp2_mae: 0.0520 - val_loss: 0.0902 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0679 - val_total_width2_loss: 0.0118 - val_total_amp2_loss: 0.0082 - val_Dense3_peak_number_mae: 0.0107 - val_total_center2_mae: 0.0905 - val_total_width2_mae: 0.0656 - val_total_amp2_mae: 0.0521
# Epoch 20/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0972 - Dense3_peak_number_loss: 0.0029 - total_center2_loss: 0.0744 - total_width2_loss: 0.0118 - total_amp2_loss: 0.0081 - Dense3_peak_number_mae: 0.0134 - total_center2_mae: 0.1024 - total_width2_mae: 0.0628 - total_amp2_mae: 0.0511 - val_loss: 0.0980 - val_Dense3_peak_number_loss: 0.0024 - val_total_center2_loss: 0.0736 - val_total_width2_loss: 0.0138 - val_total_amp2_loss: 0.0082 - val_Dense3_peak_number_mae: 0.0112 - val_total_center2_mae: 0.0969 - val_total_width2_mae: 0.0746 - val_total_amp2_mae: 0.0524
# Epoch 21/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0937 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0715 - total_width2_loss: 0.0115 - total_amp2_loss: 0.0080 - Dense3_peak_number_mae: 0.0124 - total_center2_mae: 0.1003 - total_width2_mae: 0.0622 - total_amp2_mae: 0.0506 - val_loss: 0.0909 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0685 - val_total_width2_loss: 0.0119 - val_total_amp2_loss: 0.0083 - val_Dense3_peak_number_mae: 0.0129 - val_total_center2_mae: 0.0908 - val_total_width2_mae: 0.0634 - val_total_amp2_mae: 0.0536
# Epoch 22/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0910 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0692 - total_width2_loss: 0.0113 - total_amp2_loss: 0.0079 - Dense3_peak_number_mae: 0.0121 - total_center2_mae: 0.0987 - total_width2_mae: 0.0615 - total_amp2_mae: 0.0501 - val_loss: 0.0964 - val_Dense3_peak_number_loss: 0.0028 - val_total_center2_loss: 0.0724 - val_total_width2_loss: 0.0131 - val_total_amp2_loss: 0.0081 - val_Dense3_peak_number_mae: 0.0131 - val_total_center2_mae: 0.0995 - val_total_width2_mae: 0.0728 - val_total_amp2_mae: 0.0526
# Epoch 23/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0931 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0710 - total_width2_loss: 0.0114 - total_amp2_loss: 0.0079 - Dense3_peak_number_mae: 0.0126 - total_center2_mae: 0.0994 - total_width2_mae: 0.0617 - total_amp2_mae: 0.0501 - val_loss: 0.0947 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0723 - val_total_width2_loss: 0.0117 - val_total_amp2_loss: 0.0086 - val_Dense3_peak_number_mae: 0.0100 - val_total_center2_mae: 0.1092 - val_total_width2_mae: 0.0623 - val_total_amp2_mae: 0.0560
# Epoch 24/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0948 - Dense3_peak_number_loss: 0.0029 - total_center2_loss: 0.0725 - total_width2_loss: 0.0114 - total_amp2_loss: 0.0079 - Dense3_peak_number_mae: 0.0131 - total_center2_mae: 0.1005 - total_width2_mae: 0.0616 - total_amp2_mae: 0.0501 - val_loss: 0.0912 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0699 - val_total_width2_loss: 0.0113 - val_total_amp2_loss: 0.0077 - val_Dense3_peak_number_mae: 0.0083 - val_total_center2_mae: 0.0983 - val_total_width2_mae: 0.0623 - val_total_amp2_mae: 0.0490
# Epoch 25/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0875 - Dense3_peak_number_loss: 0.0025 - total_center2_loss: 0.0665 - total_width2_loss: 0.0109 - total_amp2_loss: 0.0077 - Dense3_peak_number_mae: 0.0110 - total_center2_mae: 0.0962 - total_width2_mae: 0.0599 - total_amp2_mae: 0.0488 - val_loss: 0.0813 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0608 - val_total_width2_loss: 0.0107 - val_total_amp2_loss: 0.0080 - val_Dense3_peak_number_mae: 0.0122 - val_total_center2_mae: 0.0902 - val_total_width2_mae: 0.0586 - val_total_amp2_mae: 0.0517
# Epoch 26/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.0886 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0673 - total_width2_loss: 0.0110 - total_amp2_loss: 0.0077 - Dense3_peak_number_mae: 0.0123 - total_center2_mae: 0.0971 - total_width2_mae: 0.0601 - total_amp2_mae: 0.0490 - val_loss: 0.0926 - val_Dense3_peak_number_loss: 0.0030 - val_total_center2_loss: 0.0698 - val_total_width2_loss: 0.0116 - val_total_amp2_loss: 0.0083 - val_Dense3_peak_number_mae: 0.0103 - val_total_center2_mae: 0.0912 - val_total_width2_mae: 0.0610 - val_total_amp2_mae: 0.0524
# Epoch 27/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0848 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0642 - total_width2_loss: 0.0107 - total_amp2_loss: 0.0076 - Dense3_peak_number_mae: 0.0114 - total_center2_mae: 0.0944 - total_width2_mae: 0.0593 - total_amp2_mae: 0.0484 - val_loss: 0.0859 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0653 - val_total_width2_loss: 0.0107 - val_total_amp2_loss: 0.0079 - val_Dense3_peak_number_mae: 0.0082 - val_total_center2_mae: 0.0971 - val_total_width2_mae: 0.0606 - val_total_amp2_mae: 0.0502
# Epoch 28/100
# 1800/1800 [==============================] - 58s 32ms/step - loss: 0.0883 - Dense3_peak_number_loss: 0.0025 - total_center2_loss: 0.0673 - total_width2_loss: 0.0109 - total_amp2_loss: 0.0077 - Dense3_peak_number_mae: 0.0117 - total_center2_mae: 0.0965 - total_width2_mae: 0.0599 - total_amp2_mae: 0.0485 - val_loss: 0.1167 - val_Dense3_peak_number_loss: 0.0045 - val_total_center2_loss: 0.0924 - val_total_width2_loss: 0.0117 - val_total_amp2_loss: 0.0081 - val_Dense3_peak_number_mae: 0.0181 - val_total_center2_mae: 0.0899 - val_total_width2_mae: 0.0596 - val_total_amp2_mae: 0.0492
# Epoch 29/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0857 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0650 - total_width2_loss: 0.0107 - total_amp2_loss: 0.0076 - Dense3_peak_number_mae: 0.0118 - total_center2_mae: 0.0951 - total_width2_mae: 0.0593 - total_amp2_mae: 0.0483 - val_loss: 0.0816 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0607 - val_total_width2_loss: 0.0111 - val_total_amp2_loss: 0.0080 - val_Dense3_peak_number_mae: 0.0093 - val_total_center2_mae: 0.0857 - val_total_width2_mae: 0.0605 - val_total_amp2_mae: 0.0522
# Epoch 30/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0848 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0643 - total_width2_loss: 0.0106 - total_amp2_loss: 0.0075 - Dense3_peak_number_mae: 0.0116 - total_center2_mae: 0.0945 - total_width2_mae: 0.0587 - total_amp2_mae: 0.0479 - val_loss: 0.0827 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0628 - val_total_width2_loss: 0.0103 - val_total_amp2_loss: 0.0079 - val_Dense3_peak_number_mae: 0.0116 - val_total_center2_mae: 0.0972 - val_total_width2_mae: 0.0570 - val_total_amp2_mae: 0.0513
# Epoch 31/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0850 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0645 - total_width2_loss: 0.0106 - total_amp2_loss: 0.0075 - Dense3_peak_number_mae: 0.0121 - total_center2_mae: 0.0947 - total_width2_mae: 0.0587 - total_amp2_mae: 0.0478 - val_loss: 0.0868 - val_Dense3_peak_number_loss: 0.0022 - val_total_center2_loss: 0.0648 - val_total_width2_loss: 0.0119 - val_total_amp2_loss: 0.0079 - val_Dense3_peak_number_mae: 0.0076 - val_total_center2_mae: 0.0820 - val_total_width2_mae: 0.0663 - val_total_amp2_mae: 0.0506
# Epoch 32/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0814 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0614 - total_width2_loss: 0.0104 - total_amp2_loss: 0.0074 - Dense3_peak_number_mae: 0.0114 - total_center2_mae: 0.0925 - total_width2_mae: 0.0581 - total_amp2_mae: 0.0473 - val_loss: 0.0926 - val_Dense3_peak_number_loss: 0.0028 - val_total_center2_loss: 0.0713 - val_total_width2_loss: 0.0109 - val_total_amp2_loss: 0.0076 - val_Dense3_peak_number_mae: 0.0108 - val_total_center2_mae: 0.0903 - val_total_width2_mae: 0.0584 - val_total_amp2_mae: 0.0491
# Epoch 33/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0851 - Dense3_peak_number_loss: 0.0025 - total_center2_loss: 0.0647 - total_width2_loss: 0.0105 - total_amp2_loss: 0.0074 - Dense3_peak_number_mae: 0.0114 - total_center2_mae: 0.0945 - total_width2_mae: 0.0585 - total_amp2_mae: 0.0474 - val_loss: 0.1084 - val_Dense3_peak_number_loss: 0.0042 - val_total_center2_loss: 0.0853 - val_total_width2_loss: 0.0113 - val_total_amp2_loss: 0.0076 - val_Dense3_peak_number_mae: 0.0179 - val_total_center2_mae: 0.1054 - val_total_width2_mae: 0.0574 - val_total_amp2_mae: 0.0462
# Epoch 34/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0799 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0603 - total_width2_loss: 0.0102 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0107 - total_center2_mae: 0.0918 - total_width2_mae: 0.0576 - total_amp2_mae: 0.0469 - val_loss: 0.0754 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0566 - val_total_width2_loss: 0.0099 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0061 - val_total_center2_mae: 0.0828 - val_total_width2_mae: 0.0557 - val_total_amp2_mae: 0.0460
# Epoch 35/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0820 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0620 - total_width2_loss: 0.0103 - total_amp2_loss: 0.0074 - Dense3_peak_number_mae: 0.0114 - total_center2_mae: 0.0924 - total_width2_mae: 0.0579 - total_amp2_mae: 0.0472 - val_loss: 0.1114 - val_Dense3_peak_number_loss: 0.0033 - val_total_center2_loss: 0.0835 - val_total_width2_loss: 0.0162 - val_total_amp2_loss: 0.0083 - val_Dense3_peak_number_mae: 0.0188 - val_total_center2_mae: 0.1128 - val_total_width2_mae: 0.0896 - val_total_amp2_mae: 0.0529
# Epoch 36/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0797 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0601 - total_width2_loss: 0.0101 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0104 - total_center2_mae: 0.0917 - total_width2_mae: 0.0574 - total_amp2_mae: 0.0466 - val_loss: 0.0918 - val_Dense3_peak_number_loss: 0.0027 - val_total_center2_loss: 0.0707 - val_total_width2_loss: 0.0108 - val_total_amp2_loss: 0.0075 - val_Dense3_peak_number_mae: 0.0120 - val_total_center2_mae: 0.0856 - val_total_width2_mae: 0.0596 - val_total_amp2_mae: 0.0486
# Epoch 37/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0798 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0601 - total_width2_loss: 0.0102 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0106 - total_center2_mae: 0.0918 - total_width2_mae: 0.0576 - total_amp2_mae: 0.0467 - val_loss: 0.0759 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0566 - val_total_width2_loss: 0.0104 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0105 - val_total_center2_mae: 0.0781 - val_total_width2_mae: 0.0616 - val_total_amp2_mae: 0.0469
# Epoch 38/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0784 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0590 - total_width2_loss: 0.0100 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0102 - total_center2_mae: 0.0910 - total_width2_mae: 0.0571 - total_amp2_mae: 0.0466 - val_loss: 0.0830 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0640 - val_total_width2_loss: 0.0101 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0083 - val_total_center2_mae: 0.0849 - val_total_width2_mae: 0.0594 - val_total_amp2_mae: 0.0454
# Epoch 39/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0776 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0584 - total_width2_loss: 0.0100 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0102 - total_center2_mae: 0.0905 - total_width2_mae: 0.0568 - total_amp2_mae: 0.0463 - val_loss: 0.0945 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0721 - val_total_width2_loss: 0.0114 - val_total_amp2_loss: 0.0080 - val_Dense3_peak_number_mae: 0.0104 - val_total_center2_mae: 0.0963 - val_total_width2_mae: 0.0647 - val_total_amp2_mae: 0.0524
# Epoch 40/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0771 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0576 - total_width2_loss: 0.0102 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0107 - total_center2_mae: 0.0913 - total_width2_mae: 0.0577 - total_amp2_mae: 0.0463 - val_loss: 0.1528 - val_Dense3_peak_number_loss: 0.0069 - val_total_center2_loss: 0.1201 - val_total_width2_loss: 0.0162 - val_total_amp2_loss: 0.0097 - val_Dense3_peak_number_mae: 0.0303 - val_total_center2_mae: 0.1594 - val_total_width2_mae: 0.0781 - val_total_amp2_mae: 0.0589
# Epoch 41/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0760 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0569 - total_width2_loss: 0.0099 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0124 - total_center2_mae: 0.0916 - total_width2_mae: 0.0568 - total_amp2_mae: 0.0461 - val_loss: 0.0962 - val_Dense3_peak_number_loss: 0.0035 - val_total_center2_loss: 0.0747 - val_total_width2_loss: 0.0107 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0139 - val_total_center2_mae: 0.0915 - val_total_width2_mae: 0.0579 - val_total_amp2_mae: 0.0448
# Epoch 42/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0746 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0557 - total_width2_loss: 0.0098 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0128 - total_center2_mae: 0.0914 - total_width2_mae: 0.0562 - total_amp2_mae: 0.0458 - val_loss: 0.0769 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0582 - val_total_width2_loss: 0.0099 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0152 - val_total_center2_mae: 0.0860 - val_total_width2_mae: 0.0565 - val_total_amp2_mae: 0.0448
# Epoch 43/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0762 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0570 - total_width2_loss: 0.0099 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0127 - total_center2_mae: 0.0932 - total_width2_mae: 0.0566 - total_amp2_mae: 0.0459 - val_loss: 0.0724 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0546 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0073 - val_total_center2_mae: 0.0872 - val_total_width2_mae: 0.0556 - val_total_amp2_mae: 0.0445
# Epoch 44/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0744 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0555 - total_width2_loss: 0.0097 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0131 - total_center2_mae: 0.0927 - total_width2_mae: 0.0561 - total_amp2_mae: 0.0456 - val_loss: 0.0755 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0563 - val_total_width2_loss: 0.0102 - val_total_amp2_loss: 0.0075 - val_Dense3_peak_number_mae: 0.0075 - val_total_center2_mae: 0.0846 - val_total_width2_mae: 0.0559 - val_total_amp2_mae: 0.0503
# Epoch 46/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0748 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0558 - total_width2_loss: 0.0098 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0127 - total_center2_mae: 0.0925 - total_width2_mae: 0.0560 - total_amp2_mae: 0.0456 - val_loss: 0.0751 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0568 - val_total_width2_loss: 0.0096 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0134 - val_total_center2_mae: 0.0925 - val_total_width2_mae: 0.0569 - val_total_amp2_mae: 0.0458
# Epoch 47/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0711 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0527 - total_width2_loss: 0.0095 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0116 - total_center2_mae: 0.0908 - total_width2_mae: 0.0555 - total_amp2_mae: 0.0450 - val_loss: 0.0736 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0553 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0145 - val_total_center2_mae: 0.0854 - val_total_width2_mae: 0.0567 - val_total_amp2_mae: 0.0468
# Epoch 48/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0731 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0543 - total_width2_loss: 0.0096 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0126 - total_center2_mae: 0.0917 - total_width2_mae: 0.0556 - total_amp2_mae: 0.0453 - val_loss: 0.0729 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0537 - val_total_width2_loss: 0.0103 - val_total_amp2_loss: 0.0074 - val_Dense3_peak_number_mae: 0.0094 - val_total_center2_mae: 0.0748 - val_total_width2_mae: 0.0572 - val_total_amp2_mae: 0.0485
# Epoch 49/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0735 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0547 - total_width2_loss: 0.0097 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0121 - total_center2_mae: 0.0922 - total_width2_mae: 0.0557 - total_amp2_mae: 0.0454 - val_loss: 0.0755 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0563 - val_total_width2_loss: 0.0105 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0068 - val_total_center2_mae: 0.0800 - val_total_width2_mae: 0.0581 - val_total_amp2_mae: 0.0447
# Epoch 50/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0729 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0543 - total_width2_loss: 0.0096 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0122 - total_center2_mae: 0.0913 - total_width2_mae: 0.0554 - total_amp2_mae: 0.0449 - val_loss: 0.0763 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0579 - val_total_width2_loss: 0.0098 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0130 - val_total_center2_mae: 0.0920 - val_total_width2_mae: 0.0586 - val_total_amp2_mae: 0.0466
# Epoch 51/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0719 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0533 - total_width2_loss: 0.0095 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0120 - total_center2_mae: 0.0906 - total_width2_mae: 0.0554 - total_amp2_mae: 0.0450 - val_loss: 0.0765 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0574 - val_total_width2_loss: 0.0103 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0089 - val_total_center2_mae: 0.0857 - val_total_width2_mae: 0.0593 - val_total_amp2_mae: 0.0460
# Epoch 52/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0704 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0521 - total_width2_loss: 0.0094 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0110 - total_center2_mae: 0.0903 - total_width2_mae: 0.0551 - total_amp2_mae: 0.0451 - val_loss: 0.0730 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0536 - val_total_width2_loss: 0.0099 - val_total_amp2_loss: 0.0080 - val_Dense3_peak_number_mae: 0.0086 - val_total_center2_mae: 0.0904 - val_total_width2_mae: 0.0567 - val_total_amp2_mae: 0.0555
# Epoch 53/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0703 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0520 - total_width2_loss: 0.0094 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0110 - total_center2_mae: 0.0900 - total_width2_mae: 0.0551 - total_amp2_mae: 0.0452 - val_loss: 0.0745 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0561 - val_total_width2_loss: 0.0100 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0112 - val_total_center2_mae: 0.1008 - val_total_width2_mae: 0.0618 - val_total_amp2_mae: 0.0436
# Epoch 54/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0682 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0502 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0110 - total_center2_mae: 0.0882 - total_width2_mae: 0.0546 - total_amp2_mae: 0.0445 - val_loss: 0.0723 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0545 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0058 - val_total_center2_mae: 0.0794 - val_total_width2_mae: 0.0556 - val_total_amp2_mae: 0.0430
# Epoch 55/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0724 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0538 - total_width2_loss: 0.0095 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0114 - total_center2_mae: 0.0905 - total_width2_mae: 0.0552 - total_amp2_mae: 0.0449 - val_loss: 0.0849 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0647 - val_total_width2_loss: 0.0111 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0110 - val_total_center2_mae: 0.1007 - val_total_width2_mae: 0.0615 - val_total_amp2_mae: 0.0445
# Epoch 56/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0720 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0535 - total_width2_loss: 0.0095 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0108 - total_center2_mae: 0.0896 - total_width2_mae: 0.0550 - total_amp2_mae: 0.0446 - val_loss: 0.0762 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0581 - val_total_width2_loss: 0.0094 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0113 - val_total_center2_mae: 0.0930 - val_total_width2_mae: 0.0565 - val_total_amp2_mae: 0.0452
# Epoch 57/100
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0683 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0504 - total_width2_loss: 0.0092 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0107 - total_center2_mae: 0.0879 - total_width2_mae: 0.0542 - total_amp2_mae: 0.0442 - val_loss: 0.0742 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0551 - val_total_width2_loss: 0.0102 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0098 - val_total_center2_mae: 0.0797 - val_total_width2_mae: 0.0607 - val_total_amp2_mae: 0.0448
# Epoch 58/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0683 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0504 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0106 - total_center2_mae: 0.0881 - total_width2_mae: 0.0543 - total_amp2_mae: 0.0442 - val_loss: 0.0725 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0546 - val_total_width2_loss: 0.0092 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0107 - val_total_center2_mae: 0.0794 - val_total_width2_mae: 0.0531 - val_total_amp2_mae: 0.0434
# Epoch 59/100
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.0701 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0519 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0113 - total_center2_mae: 0.0893 - total_width2_mae: 0.0544 - total_amp2_mae: 0.0443 - val_loss: 0.0748 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0568 - val_total_width2_loss: 0.0096 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0067 - val_total_center2_mae: 0.0883 - val_total_width2_mae: 0.0582 - val_total_amp2_mae: 0.0436
# Epoch 60/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0674 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0497 - total_width2_loss: 0.0092 - total_amp2_loss: 0.0068 - Dense3_peak_number_mae: 0.0103 - total_center2_mae: 0.0881 - total_width2_mae: 0.0539 - total_amp2_mae: 0.0439 - val_loss: 0.0910 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0722 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0151 - val_total_center2_mae: 0.1285 - val_total_width2_mae: 0.0559 - val_total_amp2_mae: 0.0485
# Epoch 61/100
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0700 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0519 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0112 - total_center2_mae: 0.0886 - total_width2_mae: 0.0543 - total_amp2_mae: 0.0442 - val_loss: 0.0732 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0556 - val_total_width2_loss: 0.0093 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0084 - val_total_center2_mae: 0.0853 - val_total_width2_mae: 0.0538 - val_total_amp2_mae: 0.0437
# Epoch 62/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0699 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0518 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0106 - total_center2_mae: 0.0885 - total_width2_mae: 0.0543 - total_amp2_mae: 0.0440 - val_loss: 0.1949 - val_Dense3_peak_number_loss: 0.0058 - val_total_center2_loss: 0.1591 - val_total_width2_loss: 0.0191 - val_total_amp2_loss: 0.0108 - val_Dense3_peak_number_mae: 0.0313 - val_total_center2_mae: 0.2086 - val_total_width2_mae: 0.0874 - val_total_amp2_mae: 0.0659
# Epoch 63/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0664 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0488 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0068 - Dense3_peak_number_mae: 0.0102 - total_center2_mae: 0.0868 - total_width2_mae: 0.0536 - total_amp2_mae: 0.0436 - val_loss: 0.0686 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0512 - val_total_width2_loss: 0.0093 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0049 - val_total_center2_mae: 0.0783 - val_total_width2_mae: 0.0550 - val_total_amp2_mae: 0.0432
# Epoch 64/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0730 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0542 - total_width2_loss: 0.0097 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0108 - total_center2_mae: 0.0899 - total_width2_mae: 0.0554 - total_amp2_mae: 0.0443 - val_loss: 0.0702 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0530 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0071 - val_total_center2_mae: 0.0742 - val_total_width2_mae: 0.0529 - val_total_amp2_mae: 0.0425
# Epoch 65/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0655 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0480 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0103 - total_center2_mae: 0.0861 - total_width2_mae: 0.0535 - total_amp2_mae: 0.0434 - val_loss: 0.0692 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0517 - val_total_width2_loss: 0.0093 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0055 - val_total_center2_mae: 0.0777 - val_total_width2_mae: 0.0568 - val_total_amp2_mae: 0.0438
# Epoch 66/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0666 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0489 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0068 - Dense3_peak_number_mae: 0.0104 - total_center2_mae: 0.0869 - total_width2_mae: 0.0539 - total_amp2_mae: 0.0436 - val_loss: 0.0740 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0562 - val_total_width2_loss: 0.0093 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0112 - val_total_center2_mae: 0.0814 - val_total_width2_mae: 0.0532 - val_total_amp2_mae: 0.0446
# Epoch 67/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0670 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0493 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0068 - Dense3_peak_number_mae: 0.0103 - total_center2_mae: 0.0875 - total_width2_mae: 0.0538 - total_amp2_mae: 0.0435 - val_loss: 0.1275 - val_Dense3_peak_number_loss: 0.0030 - val_total_center2_loss: 0.1030 - val_total_width2_loss: 0.0135 - val_total_amp2_loss: 0.0081 - val_Dense3_peak_number_mae: 0.0128 - val_total_center2_mae: 0.1703 - val_total_width2_mae: 0.0714 - val_total_amp2_mae: 0.0524
# Epoch 68/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0698 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0517 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0068 - Dense3_peak_number_mae: 0.0106 - total_center2_mae: 0.0880 - total_width2_mae: 0.0541 - total_amp2_mae: 0.0438 - val_loss: 0.1554 - val_Dense3_peak_number_loss: 0.0063 - val_total_center2_loss: 0.1291 - val_total_width2_loss: 0.0122 - val_total_amp2_loss: 0.0078 - val_Dense3_peak_number_mae: 0.0117 - val_total_center2_mae: 0.1046 - val_total_width2_mae: 0.0582 - val_total_amp2_mae: 0.0474
# Epoch 69/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0666 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0490 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0097 - total_center2_mae: 0.0864 - total_width2_mae: 0.0533 - total_amp2_mae: 0.0431 - val_loss: 0.0730 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0555 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0069 - val_total_center2_mae: 0.0854 - val_total_width2_mae: 0.0520 - val_total_amp2_mae: 0.0445
# Epoch 70/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0641 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0469 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0095 - total_center2_mae: 0.0852 - total_width2_mae: 0.0531 - total_amp2_mae: 0.0431 - val_loss: 0.6673 - val_Dense3_peak_number_loss: 0.0363 - val_total_center2_loss: 0.5637 - val_total_width2_loss: 0.0441 - val_total_amp2_loss: 0.0232 - val_Dense3_peak_number_mae: 0.0807 - val_total_center2_mae: 0.2833 - val_total_width2_mae: 0.1159 - val_total_amp2_mae: 0.1031
# Epoch 71/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0674 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0496 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0068 - Dense3_peak_number_mae: 0.0107 - total_center2_mae: 0.0874 - total_width2_mae: 0.0537 - total_amp2_mae: 0.0434 - val_loss: 0.0908 - val_Dense3_peak_number_loss: 0.0024 - val_total_center2_loss: 0.0715 - val_total_width2_loss: 0.0100 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0163 - val_total_center2_mae: 0.1188 - val_total_width2_mae: 0.0562 - val_total_amp2_mae: 0.0426
# Epoch 72/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0633 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0459 - total_width2_loss: 0.0091 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0095 - total_center2_mae: 0.0847 - total_width2_mae: 0.0537 - total_amp2_mae: 0.0429 - val_loss: 0.0783 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0600 - val_total_width2_loss: 0.0096 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0076 - val_total_center2_mae: 0.0830 - val_total_width2_mae: 0.0559 - val_total_amp2_mae: 0.0440
# Epoch 73/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0646 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0472 - total_width2_loss: 0.0090 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0098 - total_center2_mae: 0.0853 - total_width2_mae: 0.0532 - total_amp2_mae: 0.0430 - val_loss: 0.0803 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0610 - val_total_width2_loss: 0.0099 - val_total_amp2_loss: 0.0077 - val_Dense3_peak_number_mae: 0.0132 - val_total_center2_mae: 0.1017 - val_total_width2_mae: 0.0581 - val_total_amp2_mae: 0.0518
# Epoch 74/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0872 - Dense3_peak_number_loss: 0.0032 - total_center2_loss: 0.0668 - total_width2_loss: 0.0101 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0116 - total_center2_mae: 0.0971 - total_width2_mae: 0.0560 - total_amp2_mae: 0.0448 - val_loss: 0.0871 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0679 - val_total_width2_loss: 0.0103 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0101 - val_total_center2_mae: 0.1094 - val_total_width2_mae: 0.0592 - val_total_amp2_mae: 0.0438
# Epoch 75/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0656 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0483 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0089 - total_center2_mae: 0.0851 - total_width2_mae: 0.0531 - total_amp2_mae: 0.0427 - val_loss: 0.0697 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0522 - val_total_width2_loss: 0.0094 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0064 - val_total_center2_mae: 0.0776 - val_total_width2_mae: 0.0546 - val_total_amp2_mae: 0.0427
# Epoch 76/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0648 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0475 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0088 - total_center2_mae: 0.0860 - total_width2_mae: 0.0533 - total_amp2_mae: 0.0430 - val_loss: 0.0702 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0529 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0054 - val_total_center2_mae: 0.0714 - val_total_width2_mae: 0.0530 - val_total_amp2_mae: 0.0429
# Epoch 77/100
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0644 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0472 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0085 - total_center2_mae: 0.0857 - total_width2_mae: 0.0531 - total_amp2_mae: 0.0429 - val_loss: 0.0679 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0508 - val_total_width2_loss: 0.0090 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0114 - val_total_center2_mae: 0.0729 - val_total_width2_mae: 0.0558 - val_total_amp2_mae: 0.0431
# Epoch 78/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0631 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0460 - total_width2_loss: 0.0088 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0088 - total_center2_mae: 0.0847 - total_width2_mae: 0.0530 - total_amp2_mae: 0.0428 - val_loss: 0.0669 - val_Dense3_peak_number_loss: 0.0012 - val_total_center2_loss: 0.0500 - val_total_width2_loss: 0.0092 - val_total_amp2_loss: 0.0066 - val_Dense3_peak_number_mae: 0.0043 - val_total_center2_mae: 0.0812 - val_total_width2_mae: 0.0576 - val_total_amp2_mae: 0.0426
# Epoch 79/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0628 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0458 - total_width2_loss: 0.0088 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0084 - total_center2_mae: 0.0853 - total_width2_mae: 0.0528 - total_amp2_mae: 0.0426 - val_loss: 0.0764 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0579 - val_total_width2_loss: 0.0101 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0086 - val_total_center2_mae: 0.0830 - val_total_width2_mae: 0.0633 - val_total_amp2_mae: 0.0442
# Epoch 80/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0651 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0477 - total_width2_loss: 0.0090 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0090 - total_center2_mae: 0.0860 - total_width2_mae: 0.0533 - total_amp2_mae: 0.0432 - val_loss: 0.0703 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0529 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0071 - val_total_center2_mae: 0.0825 - val_total_width2_mae: 0.0530 - val_total_amp2_mae: 0.0453
# Epoch 81/100
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0597 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0431 - total_width2_loss: 0.0086 - total_amp2_loss: 0.0065 - Dense3_peak_number_mae: 0.0075 - total_center2_mae: 0.0827 - total_width2_mae: 0.0523 - total_amp2_mae: 0.0422 - val_loss: 0.0710 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0536 - val_total_width2_loss: 0.0092 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0048 - val_total_center2_mae: 0.0795 - val_total_width2_mae: 0.0572 - val_total_amp2_mae: 0.0444
# Epoch 82/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0612 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0444 - total_width2_loss: 0.0087 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0082 - total_center2_mae: 0.0839 - total_width2_mae: 0.0526 - total_amp2_mae: 0.0425 - val_loss: 0.0659 - val_Dense3_peak_number_loss: 0.0011 - val_total_center2_loss: 0.0494 - val_total_width2_loss: 0.0089 - val_total_amp2_loss: 0.0065 - val_Dense3_peak_number_mae: 0.0065 - val_total_center2_mae: 0.0762 - val_total_width2_mae: 0.0566 - val_total_amp2_mae: 0.0419
# Epoch 83/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0627 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0457 - total_width2_loss: 0.0088 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0080 - total_center2_mae: 0.0844 - total_width2_mae: 0.0529 - total_amp2_mae: 0.0426 - val_loss: 0.0781 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0596 - val_total_width2_loss: 0.0097 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0120 - val_total_center2_mae: 0.0852 - val_total_width2_mae: 0.0575 - val_total_amp2_mae: 0.0426
# Epoch 84/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0628 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0458 - total_width2_loss: 0.0088 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0084 - total_center2_mae: 0.0842 - total_width2_mae: 0.0525 - total_amp2_mae: 0.0423 - val_loss: 0.0781 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0603 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0056 - val_total_center2_mae: 0.0869 - val_total_width2_mae: 0.0568 - val_total_amp2_mae: 0.0441
# Epoch 85/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0609 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0441 - total_width2_loss: 0.0087 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0077 - total_center2_mae: 0.0841 - total_width2_mae: 0.0523 - total_amp2_mae: 0.0424 - val_loss: 0.0699 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0526 - val_total_width2_loss: 0.0088 - val_total_amp2_loss: 0.0068 - val_Dense3_peak_number_mae: 0.0173 - val_total_center2_mae: 0.0794 - val_total_width2_mae: 0.0527 - val_total_amp2_mae: 0.0447
# Epoch 86/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0609 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0441 - total_width2_loss: 0.0087 - total_amp2_loss: 0.0065 - Dense3_peak_number_mae: 0.0080 - total_center2_mae: 0.0840 - total_width2_mae: 0.0524 - total_amp2_mae: 0.0423 - val_loss: 0.0669 - val_Dense3_peak_number_loss: 0.0012 - val_total_center2_loss: 0.0503 - val_total_width2_loss: 0.0088 - val_total_amp2_loss: 0.0066 - val_Dense3_peak_number_mae: 0.0050 - val_total_center2_mae: 0.0785 - val_total_width2_mae: 0.0531 - val_total_amp2_mae: 0.0421
# Epoch 87/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0629 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0459 - total_width2_loss: 0.0088 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0079 - total_center2_mae: 0.0848 - total_width2_mae: 0.0528 - total_amp2_mae: 0.0425 - val_loss: 0.0669 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0500 - val_total_width2_loss: 0.0088 - val_total_amp2_loss: 0.0066 - val_Dense3_peak_number_mae: 0.0074 - val_total_center2_mae: 0.0720 - val_total_width2_mae: 0.0517 - val_total_amp2_mae: 0.0426
# Epoch 88/100
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.1507 - Dense3_peak_number_loss: 0.0068 - total_center2_loss: 0.1189 - total_width2_loss: 0.0156 - total_amp2_loss: 0.0094 - Dense3_peak_number_mae: 0.0198 - total_center2_mae: 0.1525 - total_width2_mae: 0.0718 - total_amp2_mae: 0.0554 - val_loss: 0.0842 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0640 - val_total_width2_loss: 0.0109 - val_total_amp2_loss: 0.0074 - val_Dense3_peak_number_mae: 0.0057 - val_total_center2_mae: 0.1027 - val_total_width2_mae: 0.0600 - val_total_amp2_mae: 0.0465
# Epoch 89/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0777 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0579 - total_width2_loss: 0.0106 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0083 - total_center2_mae: 0.1045 - total_width2_mae: 0.0588 - total_amp2_mae: 0.0456 - val_loss: 0.0749 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0560 - val_total_width2_loss: 0.0102 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0086 - val_total_center2_mae: 0.0930 - val_total_width2_mae: 0.0571 - val_total_amp2_mae: 0.0464
# Epoch 90/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0726 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0538 - total_width2_loss: 0.0101 - total_amp2_loss: 0.0069 - Dense3_peak_number_mae: 0.0085 - total_center2_mae: 0.0973 - total_width2_mae: 0.0568 - total_amp2_mae: 0.0442 - val_loss: 0.1011 - val_Dense3_peak_number_loss: 0.0042 - val_total_center2_loss: 0.0779 - val_total_width2_loss: 0.0118 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0144 - val_total_center2_mae: 0.0955 - val_total_width2_mae: 0.0601 - val_total_amp2_mae: 0.0450
# Epoch 91/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0669 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0491 - total_width2_loss: 0.0095 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0086 - total_center2_mae: 0.0910 - total_width2_mae: 0.0548 - total_amp2_mae: 0.0432 - val_loss: 0.3014 - val_Dense3_peak_number_loss: 0.0148 - val_total_center2_loss: 0.2609 - val_total_width2_loss: 0.0171 - val_total_amp2_loss: 0.0086 - val_Dense3_peak_number_mae: 0.0706 - val_total_center2_mae: 0.2693 - val_total_width2_mae: 0.0741 - val_total_amp2_mae: 0.0519
# Epoch 92/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0645 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0472 - total_width2_loss: 0.0093 - total_amp2_loss: 0.0067 - Dense3_peak_number_mae: 0.0081 - total_center2_mae: 0.0884 - total_width2_mae: 0.0542 - total_amp2_mae: 0.0428 - val_loss: 0.0898 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0696 - val_total_width2_loss: 0.0113 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0066 - val_total_center2_mae: 0.1103 - val_total_width2_mae: 0.0641 - val_total_amp2_mae: 0.0469
# Epoch 93/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0648 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0474 - total_width2_loss: 0.0092 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0085 - total_center2_mae: 0.0875 - total_width2_mae: 0.0539 - total_amp2_mae: 0.0426 - val_loss: 0.0760 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0578 - val_total_width2_loss: 0.0094 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0101 - val_total_center2_mae: 0.0880 - val_total_width2_mae: 0.0556 - val_total_amp2_mae: 0.0454
# Epoch 94/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0621 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0451 - total_width2_loss: 0.0090 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0083 - total_center2_mae: 0.0855 - total_width2_mae: 0.0533 - total_amp2_mae: 0.0423 - val_loss: 0.0665 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0494 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0044 - val_total_center2_mae: 0.0753 - val_total_width2_mae: 0.0537 - val_total_amp2_mae: 0.0431
# Epoch 95/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0621 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0451 - total_width2_loss: 0.0090 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0081 - total_center2_mae: 0.0860 - total_width2_mae: 0.0532 - total_amp2_mae: 0.0423 - val_loss: 0.0668 - val_Dense3_peak_number_loss: 0.0012 - val_total_center2_loss: 0.0499 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0066 - val_Dense3_peak_number_mae: 0.0038 - val_total_center2_mae: 0.0795 - val_total_width2_mae: 0.0537 - val_total_amp2_mae: 0.0419
# Epoch 96/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0611 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0442 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0065 - Dense3_peak_number_mae: 0.0089 - total_center2_mae: 0.0866 - total_width2_mae: 0.0529 - total_amp2_mae: 0.0422 - val_loss: 0.0775 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0594 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0110 - val_total_center2_mae: 0.0972 - val_total_width2_mae: 0.0542 - val_total_amp2_mae: 0.0470
# Epoch 97/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0611 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0442 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0065 - Dense3_peak_number_mae: 0.0085 - total_center2_mae: 0.0860 - total_width2_mae: 0.0528 - total_amp2_mae: 0.0421 - val_loss: 0.0726 - val_Dense3_peak_number_loss: 0.0022 - val_total_center2_loss: 0.0547 - val_total_width2_loss: 0.0091 - val_total_amp2_loss: 0.0066 - val_Dense3_peak_number_mae: 0.0223 - val_total_center2_mae: 0.0813 - val_total_width2_mae: 0.0525 - val_total_amp2_mae: 0.0415
# Epoch 98/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0619 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0449 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0066 - Dense3_peak_number_mae: 0.0088 - total_center2_mae: 0.0874 - total_width2_mae: 0.0530 - total_amp2_mae: 0.0423 - val_loss: 0.0719 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0544 - val_total_width2_loss: 0.0092 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0058 - val_total_center2_mae: 0.0922 - val_total_width2_mae: 0.0541 - val_total_amp2_mae: 0.0435
# Epoch 99/100
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0620 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0450 - total_width2_loss: 0.0089 - total_amp2_loss: 0.0065 - Dense3_peak_number_mae: 0.0086 - total_center2_mae: 0.0862 - total_width2_mae: 0.0528 - total_amp2_mae: 0.0419 - val_loss: 0.0773 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0592 - val_total_width2_loss: 0.0096 - val_total_amp2_loss: 0.0067 - val_Dense3_peak_number_mae: 0.0075 - val_total_center2_mae: 0.0881 - val_total_width2_mae: 0.0565 - val_total_amp2_mae: 0.0430
# Epoch 100/100
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0594 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0427 - total_width2_loss: 0.0088 - total_amp2_loss: 0.0065 - Dense3_peak_number_mae: 0.0084 - total_center2_mae: 0.0844 - total_width2_mae: 0.0525 - total_amp2_mae: 0.0417 - val_loss: 0.0680 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0512 - val_total_width2_loss: 0.0088 - val_total_amp2_loss: 0.0065 - val_Dense3_peak_number_mae: 0.0059 - val_total_center2_mae: 0.0814 - val_total_width2_mae: 0.0508 - val_total_amp2_mae: 0.0413

# %%
test_graph.shape
# Out:
# (100000, 401, 1)

# %%
for key in models.history.keys():
    print(key)
# Out:
# loss
# Dense3_peak_number_loss
# total_center2_loss
# total_width2_loss
# total_amp2_loss
# Dense3_peak_number_mae
# total_center2_mae
# total_width2_mae
# total_amp2_mae
# val_loss
# val_Dense3_peak_number_loss
# val_total_center2_loss
# val_total_width2_loss
# val_total_amp2_loss
# val_Dense3_peak_number_mae
# val_total_center2_mae
# val_total_width2_mae
# val_total_amp2_mae

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp2_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (100000, 1)
# (100000, 3)
# (100000, 3)
# (100000, 3)

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,alpha = 0.7,color='gray',label = 'REAL')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'red',label='predict1')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'blue',label='predict2')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'green',label = 'predict3')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x)+
                y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x)+
                y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'black',label='predict_total')
    plt.grid(True)
    plt.legend()
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
    print('---------------')
    print('real_peak_number',test_peak_number[i])
    print('predict_peak_number',prediction[0][i])
# Out:
# real_center   [ 4.22027684  5.40905485 11.55720352]
# predict_center [ 4.316758 5.410202 11.500378 ]
# ---------------
# real_width    [0.53007741 0.82327543 0.65629519]
# predict_center [ 0.506281 0.7792067 0.6693956 ]
# ---------------
# real_amp      [0.87850098 0.58603946 0.54691306]
# predict_center [ 0.9085647 0.58565027 0.5377579 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.00504]
# real_center   [ 5.28605073 10.23780681 10.36679915]
# predict_center [ 5.288129 10.212107 10.394896 ]
# ---------------
# real_width    [0.52356667 1.6637154  0.76993815]
# predict_center [ 0.5038772 1.5507355 0.7425756 ]
# ---------------
# real_amp      [0.30736092 0.71421238 0.68100789]
# predict_center [ 0.3139053 0.79516023 0.649892 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0036278]
# real_center   [0.         4.49752746 5.96444561]
# predict_center [ 0.07640422 4.564771 5.9523067 ]
# ---------------
# real_width    [0.         0.39900653 0.84588452]
# predict_center [ -0.0014934838 0.3859508 0.800636 ]
# ---------------
# real_amp      [0.         0.45926132 1.09854382]
# predict_center [ -0.0049981177 0.4563017 1.1298136 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.001494]
# real_center   [ 0.          3.3047985  12.99352645]
# predict_center [ 0.044765726 3.3600233 12.890521 ]
# ---------------
# real_width    [0.         0.4478863  0.35088863]
# predict_center [ -0.005230874 0.41094425 0.39499438 ]
# ---------------
# real_amp      [0.         0.32086345 0.46099898]
# predict_center [ 0.0014839917 0.3062132 0.3726559 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9992578]
# real_center   [ 0.          4.8426485  11.55435647]
# predict_center [ 0.06072639 4.7341805 11.629601 ]
# ---------------
# real_width    [0.         1.31601144 1.64925784]
# predict_center [ -0.0038371384 1.331572 1.679285 ]
# ---------------
# real_amp      [0.         0.80830004 0.36808622]
# predict_center [ -0.0034312457 0.80601704 0.34864765 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.001397]
# real_center   [ 9.11117501 10.02581162 11.06552237]
# predict_center [ 9.299379 10.130529 11.243134 ]
# ---------------
# real_width    [1.57258002 1.63704521 1.6497351 ]
# predict_center [ 1.6893467 1.5325273 1.5303292 ]
# ---------------
# real_amp      [0.43383904 0.81651803 0.82199799]
# predict_center [ 0.594441 0.72750306 0.85548425 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0038326]
# real_center   [2.1124349  3.46346147 5.32328427]
# predict_center [ 2.482103 3.6863184 5.2798824 ]
# ---------------
# real_width    [1.81294985 0.99210987 1.79777542]
# predict_center [ 1.4314789 1.0591507 1.7569783 ]
# ---------------
# real_amp      [0.16358486 0.23556273 0.86744568]
# predict_center [ 0.18489017 0.24472153 0.9278331 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9968326]
# real_center   [0.         4.59307191 6.01879107]
# predict_center [ 0.06900738 4.6061044 5.9948006 ]
# ---------------
# real_width    [0.         0.36435987 1.2270683 ]
# predict_center [ -0.00044894218 0.4121901 1.2325225 ]
# ---------------
# real_amp      [0.         0.3420562  0.81788491]
# predict_center [ -0.0024299473 0.3196453 0.822586 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0019164]
# real_center   [ 0.          7.9519182  11.78001011]
# predict_center [ 0.055153444 7.967068 11.914127 ]
# ---------------
# real_width    [0.         1.29919315 0.30911976]
# predict_center [ 0.0028836578 1.32251 0.3320542 ]
# ---------------
# real_amp      [0.         0.9688613  0.38324308]
# predict_center [ -0.0061404854 0.9871399 0.27442774 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0019994]
# real_center   [ 7.39611371 11.38541982 12.5975426 ]
# predict_center [ 7.3475213 11.351952 12.668076 ]
# ---------------
# real_width    [1.31412796 1.68856817 0.55079655]
# predict_center [ 1.2585397 1.6643656 0.5594551 ]
# ---------------
# real_amp      [0.83277974 1.00069316 0.84496746]
# predict_center [ 0.84587127 0.9662955 0.92089003 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.005467]
# real_center   [3.0693817  3.96119973 8.0167427 ]
# predict_center [ 3.1820595 4.0405498 7.9766884 ]
# ---------------
# real_width    [1.66503023 0.34486068 1.64945117]
# predict_center [ 1.5332313 0.29347783 1.5878153 ]
# ---------------
# real_amp      [0.44934336 0.90800808 0.37361167]
# predict_center [ 0.59349185 0.86010075 0.30556458 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0027654]
# real_center   [ 5.02891449  6.11617453 11.81060695]
# predict_center [ 5.0804667 6.083897 11.82403 ]
# ---------------
# real_width    [0.78586065 1.70826778 1.07889383]
# predict_center [ 0.66016936 1.6920877 1.0191996 ]
# ---------------
# real_amp      [0.1202186  1.06748824 0.37421096]
# predict_center [ 0.12095393 1.0254564 0.39066944 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0048764]
# real_center   [6.32489051 6.3676705  9.95680784]
# predict_center [ 6.1654296 7.7940445 9.939051 ]
# ---------------
# real_width    [1.24102751 1.42493562 0.36778478]
# predict_center [ 1.3464229 0.93801796 0.37482685 ]
# ---------------
# real_amp      [0.12486871 0.29400373 0.63433201]
# predict_center [ 0.30519193 0.2530114 0.52811706 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9913006]
# real_center   [ 0.         10.99605454 11.03508472]
# predict_center [ 0.044903234 10.907896 11.124868 ]
# ---------------
# real_width    [0.         0.31831764 1.13505492]
# predict_center [ -0.010150909 0.38009286 1.1245987 ]
# ---------------
# real_amp      [0.         1.06211344 1.09051427]
# predict_center [ -0.016279802 0.9914667 1.0554266 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0019507]
# real_center   [0.         4.92825173 6.48574581]
# predict_center [ 0.07223776 4.938005 6.5490026 ]
# ---------------
# real_width    [0.         0.38443235 1.87049415]
# predict_center [ -0.00817439 0.37184802 1.7393999 ]
# ---------------
# real_amp      [0.         0.87340332 0.34363357]
# predict_center [ -0.0059093535 0.91173404 0.3328986 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0035572]
# real_center   [4.5990877  5.02017657 5.90633586]
# predict_center [ 4.5049205 5.348458 5.913355 ]
# ---------------
# real_width    [1.63288069 1.69424667 1.01230295]
# predict_center [ 1.5467702 1.4168059 1.026955 ]
# ---------------
# real_amp      [0.92968044 0.15186802 0.96511676]
# predict_center [ 0.75241894 0.4550925 0.8466978 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9892604]
# real_center   [4.91387817 8.92067754 9.1424057 ]
# predict_center [ 4.9971395 8.899689 9.466225 ]
# ---------------
# real_width    [0.33206284 0.93602344 1.59261149]
# predict_center [ 0.33100897 1.1019815 1.6445332 ]
# ---------------
# real_amp      [0.3044276  0.56082221 0.47185616]
# predict_center [ 0.31930244 0.8163224 0.22702217 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0010433]
# real_center   [ 0.          8.93206989 10.86473475]
# predict_center [ 0.06750637 8.911497 10.87874 ]
# ---------------
# real_width    [0.         1.54326027 0.7292138 ]
# predict_center [ 0.00043286383 1.5381776 0.71563315 ]
# ---------------
# real_amp      [0.         0.90378989 0.73664604]
# predict_center [ -0.010246828 0.9280704 0.76965487 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0019782]
# real_center   [ 0.          3.78696558 12.2950481 ]
# predict_center [ 0.06284326 3.8062024 12.334669 ]
# ---------------
# real_width    [0.         1.09888595 1.07603939]
# predict_center [ -0.0014936924 1.1122881 1.096777 ]
# ---------------
# real_amp      [0.         0.71861993 0.59122818]
# predict_center [ -0.0042577684 0.7098446 0.6058365 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0108156]
# real_center   [0.         7.1622197  8.37241109]
# predict_center [ 0.08928858 7.150829 8.378373 ]
# ---------------
# real_width    [0.         1.02515104 1.13988345]
# predict_center [ -0.00012217462 1.1174774 1.1531297 ]
# ---------------
# real_amp      [0.         0.58262315 0.25556177]
# predict_center [ 0.0004529804 0.6089098 0.26275155 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0019774]

# %%
plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")

# 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("P3HT Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0050461]], dtype=float32), array([[ 0.06713691, 10.343576  , 11.089895  ]], dtype=float32), array([[-0.01487088,  1.4818983 ,  0.83444   ]], dtype=float32), array([[-0.00302602,  0.4034118 ,  0.83005095]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
new_predict
# Out:
# [array([2.0050461], dtype=float32),
#  array([ 0.06713691, 10.343576  , 11.089895  ], dtype=float32),
#  array([-0.01487088,  1.4818983 ,  0.83444   ], dtype=float32),
#  array([-0.00302602,  0.4034118 ,  0.83005095], dtype=float32)]

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue',label = 'predict')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),label='predict1',color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),label = 'predict2',color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),label = 'predict3',color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()
plt.show()

# %%
print(new_predict[0],new_predict[1][2],new_predict[2][2],new_predict[3][2])
print(new_predict[0],new_predict[1][1],new_predict[2][1],new_predict[3][1])
print(new_predict[0],new_predict[1][0],new_predict[2][0],new_predict[3][0])
# Out:
# [2.0050461] 11.089895 0.83444 0.83005095
# [2.0050461] 10.343576 1.4818983 0.4034118
# [2.0050461] 0.067136906 -0.014870882 -0.0030260235

# %%
new_predict
# Out:
# [array([2.0050461], dtype=float32),
#  array([ 0.06713691, 10.343576  , 11.089895  ], dtype=float32),
#  array([-0.01487088,  1.4818983 ,  0.83444   ], dtype=float32),
#  array([-0.00302602,  0.4034118 ,  0.83005095], dtype=float32)]

# %%
new_predict[0]
# Out:
# array([2.0050461], dtype=float32)

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0071998]], dtype=float32), array([[0.09292655, 7.165294  , 8.051856  ]], dtype=float32), array([[0.00321536, 0.5264648 , 0.60322046]], dtype=float32), array([[0.00113218, 0.46575502, 0.98134553]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),label='predict_total',color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),label= 'predict1',color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),label='predict2',color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),label = 'predict3',color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()
plt.show()

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')

error_peak_number_total=0
for i in range(test_peak_number.shape[0]):
    error_peak_number_total = error_peak_number_total + (abs(prediction[0][i]-test_peak_number[i]))
print('error_peak_number_total = ',error_peak_number_total)
error_peak_number = error_peak_number_total/test_peak_number.shape[0]
print('error_peak_number =  ',error_peak_number)
print('\n')
# Out:
# error_center_total =  [8587.93374918 9698.49900643 6211.00407913]
# error_center =   [0.08587934 0.09698499 0.06211004]
#
#
# error_width_total =  [3627.10966076 6534.59905368 5179.13181929]
# error_width =   [0.0362711  0.06534599 0.05179132]
#
#
# error_amp_total =  [3078.82228594 5098.15029897 4285.45761904]
# error_amp =   [0.03078822 0.0509815  0.04285458]
#
#
# error_peak_number_total =  [572.74915]
# error_peak_number =   [0.00572749]

# %%
# 결론

# 왜자꾸 peak3개를 못맞추지.. 너무 낮아서 그런가..이런류의 데이터가 없어서 그런건가..
# 확실히 데이터 늘리니까 오차가 더 줄어들네

# %%
# real pes데이터2개에 각각 new_predict 프린드해노호
# 그래프 label 붙여서 legend 해주고
# reshape(10000000,)
# batch_size 50000개로
