# %%
# %ls
# Out:
# '2,3peak mix.ipynb'                    Untitled2.ipynb
# '5peak 3 para when it worksss.ipynb'   Untitled3.ipynb
# 'Fitting_with_noise (1).ipynb'         Untitled4.ipynb
#  ITO_O1s_bg.txt                        Untitled5.ipynb
#  ITO_O1s_exp.txt                       amp.csv
#  ITO_O1s_fitting.txt                   center.csv
#  ITO_O1s_p1.txt                        graph.csv
#  ITO_O1s_p2.txt                        labels.png
#  ITO_O1s_p3.txt                        model.png
#  P3HT_S2p_bg.txt                       model_shapes.png
#  P3HT_S2p_exp.txt                      peak_number.csv
#  P3HT_S2p_fitting.txt                  width.csv
#  P3HT_S2p_p1.txt                      '논문 수정.ipynb'
#  P3HT_S2p_p2.txt                      '데이터 얻기.ipynb'
#  PeakDetection.ipynb                  '저장된 데이터로 학습하기.ipynb'
#  Untitled.ipynb                       '저장된 데이터로 학습하기2.ipynb'
#  Untitled1.ipynb

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph.csv').values[:,1:]
center= pd.read_csv('center.csv').values[:,1:]
width= pd.read_csv('width.csv').values[:,1:]
amp= pd.read_csv('amp.csv').values[:,1:]
peak_number= pd.read_csv('peak_number.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(2000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 0.          6.08688456 11.0810396 ]
#  [ 5.07493349  8.25999368 11.36195096]
#  [ 0.          2.67516221 10.60419171]
#  [ 0.          5.54053864 12.23836258]
#  [ 0.          4.08422309  7.21849474]
#  [ 0.          7.30192691 12.34014272]
#  [ 0.          2.54016398  5.16493207]
#  [ 0.          4.67819908  6.09299318]
#  [ 4.90655934  5.13202252 10.34134357]
#  [ 0.          5.36008602  5.98285268]]
# [[0.         1.24062404 0.95374601]
#  [0.60456503 0.35785198 1.1738216 ]
#  [0.         1.17339162 1.12952083]
#  [0.         0.81456259 0.81987822]
#  [0.         0.81681444 1.70560007]
#  [0.         0.32207246 0.75414831]
#  [0.         0.30486538 1.895045  ]
#  [0.         0.59293989 0.4647601 ]
#  [1.46428848 1.12931752 1.8841104 ]
#  [0.         1.00584571 1.33599321]]
# [[0.         0.21158879 0.18180892]
#  [0.11125957 0.85593768 0.31159992]
#  [0.         0.59012228 0.71652582]
#  [0.         1.00856931 0.70388527]
#  [0.         0.94976759 0.16667863]
#  [0.         0.43501787 0.93207997]
#  [0.         0.8393851  0.5707349 ]
#  [0.         0.11555586 0.72638366]
#  [1.00347794 0.40013242 0.8164851 ]
#  [0.         0.10848772 1.08853046]]
# [2 3 2 2 2 2 2 2 3 2]
# (2000000, 3)
# (2000000, 3)
# (2000000, 3)
# (2000000,)
# (2000000, 401)
# [[ 1.65293992e-02 -1.56062971e-02 -8.67543953e-07 ...  2.55348472e-02
#   -3.85644720e-02  5.34629487e-04]
#  [ 1.77760845e-02 -1.43048937e-02  2.75018580e-03 ...  2.09525854e-02
#   -8.81444533e-03 -2.84847278e-02]
#  [ 1.36186941e-02 -1.15794033e-02  1.45041681e-02 ...  3.96018586e-02
#   -3.21144103e-03  8.85769143e-03]
#  ...
#  [-1.24151960e-02 -2.96612110e-02 -2.18882173e-02 ... -3.89587815e-02
#   -3.64336021e-02  2.78148435e-02]
#  [ 5.39405308e-03 -3.18972828e-02  3.10126407e-03 ...  1.12031471e-02
#   -4.49491273e-02  2.58940119e-03]
#  [-2.81865060e-02 -1.40640285e-02  3.61211482e-02 ... -1.77982928e-02
#   -8.35706460e-03  1.54521213e-02]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
#90:9:1
data_number=1000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (1800000, 401) (180000, 401) (20000, 401)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000,) (180000,) (20000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (1800000, 401, 1)
# (180000, 401, 1)
# (20000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
len(x)
# Out:
# 401

# %%
input_data = Input(shape = (len(x),1))
t = layers.Conv1D(128,100,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,50,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,20,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(16,10,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)

Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(10, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(100, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(60, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(100,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(60,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(100,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(60,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center3 = Dense(3, activation = 'linear',name = 'total_center3')(total_center2)


width_merge = concatenate([Dense3_peak_number,Dense3_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width3 = Dense(3, activation = 'linear',name = 'total_width3')(total_width2)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp3 = Dense(3, activation = 'linear',name = 'total_amp3')(total_amp2)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center3,total_width3,total_amp3])
print(model.summary())
plot_model(model)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 302, 128)     12928       input_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 151, 128)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 102, 128)     819328      max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 51, 128)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 32, 128)      327808      max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_6 (MaxPooling1D)  (None, 16, 128)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 7, 16)        20496       max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_7 (MaxPooling1D)  (None, 3, 16)        0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_1 (GlobalM (None, 16)           0           max_pooling1d_7[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          3400        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 100)          1700        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 100)          1700        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 100)          1700        global_max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 60)           6060        Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 60)           6060        Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 60)           6060        Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 10)           2010        Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           2440        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           2440        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           2440        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 50)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 50)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 50)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           2040        concatenate_3[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           2040        concatenate_4[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           2040        concatenate_5[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 40)           1640        total_center1[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 40)           1640        total_width1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 40)           1640        total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center3 (Dense)           (None, 3)            123         total_center2[0][0]
# __________________________________________________________________________________________________
# total_width3 (Dense)            (None, 3)            123         total_width2[0][0]
# __________________________________________________________________________________________________
# total_amp3 (Dense)              (None, 3)            123         total_amp2[0][0]
# ==================================================================================================
# Total params: 1,268,179
# Trainable params: 1,268,179
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center3' : 'mse',
                      'total_width3' : 'mse',
                      'total_amp3' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 1,
#                            'total_width3' : 0.5,
#                            'total_amp3' : 0.9,
#                             'Dense2_peak_number' :0.3 },
              metrics = ['mae'])

# %%
train_peak_number.shape
# Out:
# (1800000,)

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 50,
          batch_size = 1000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/50
# 1800/1800 [==============================] - 100s 56ms/step - loss: 3.2268 - Dense3_peak_number_loss: 0.2364 - total_center3_loss: 2.6766 - total_width3_loss: 0.2331 - total_amp3_loss: 0.0808 - Dense3_peak_number_mae: 0.3501 - total_center3_mae: 1.0826 - total_width3_mae: 0.4012 - total_amp3_mae: 0.2343 - val_loss: 1.3130 - val_Dense3_peak_number_loss: 0.0729 - val_total_center3_loss: 0.9749 - val_total_width3_loss: 0.1943 - val_total_amp3_loss: 0.0709 - val_Dense3_peak_number_mae: 0.2106 - val_total_center3_mae: 0.6231 - val_total_width3_mae: 0.3651 - val_total_amp3_mae: 0.2187
# Epoch 2/50
# 1800/1800 [==============================] - 100s 56ms/step - loss: 0.9559 - Dense3_peak_number_loss: 0.0345 - total_center3_loss: 0.6691 - total_width3_loss: 0.1834 - total_amp3_loss: 0.0690 - Dense3_peak_number_mae: 0.1126 - total_center3_mae: 0.4800 - total_width3_mae: 0.3424 - total_amp3_mae: 0.2105 - val_loss: 0.8757 - val_Dense3_peak_number_loss: 0.0213 - val_total_center3_loss: 0.6052 - val_total_width3_loss: 0.1804 - val_total_amp3_loss: 0.0688 - val_Dense3_peak_number_mae: 0.0802 - val_total_center3_mae: 0.4960 - val_total_width3_mae: 0.3420 - val_total_amp3_mae: 0.2098
# Epoch 3/50
# 1800/1800 [==============================] - 99s 55ms/step - loss: 0.6771 - Dense3_peak_number_loss: 0.0161 - total_center3_loss: 0.4177 - total_width3_loss: 0.1759 - total_amp3_loss: 0.0674 - Dense3_peak_number_mae: 0.0669 - total_center3_mae: 0.3646 - total_width3_mae: 0.3325 - total_amp3_mae: 0.2070 - val_loss: 0.5705 - val_Dense3_peak_number_loss: 0.0113 - val_total_center3_loss: 0.3204 - val_total_width3_loss: 0.1735 - val_total_amp3_loss: 0.0653 - val_Dense3_peak_number_mae: 0.0510 - val_total_center3_mae: 0.3216 - val_total_width3_mae: 0.3306 - val_total_amp3_mae: 0.2041
# Epoch 4/50
# 1800/1800 [==============================] - 98s 55ms/step - loss: 0.5608 - Dense3_peak_number_loss: 0.0116 - total_center3_loss: 0.3094 - total_width3_loss: 0.1731 - total_amp3_loss: 0.0667 - Dense3_peak_number_mae: 0.0539 - total_center3_mae: 0.3027 - total_width3_mae: 0.3291 - total_amp3_mae: 0.2052 - val_loss: 0.5396 - val_Dense3_peak_number_loss: 0.0100 - val_total_center3_loss: 0.2914 - val_total_width3_loss: 0.1722 - val_total_amp3_loss: 0.0661 - val_Dense3_peak_number_mae: 0.0595 - val_total_center3_mae: 0.3160 - val_total_width3_mae: 0.3279 - val_total_amp3_mae: 0.2035
# Epoch 5/50
# 1800/1800 [==============================] - 97s 54ms/step - loss: 0.5007 - Dense3_peak_number_loss: 0.0095 - total_center3_loss: 0.2554 - total_width3_loss: 0.1691 - total_amp3_loss: 0.0667 - Dense3_peak_number_mae: 0.0469 - total_center3_mae: 0.2688 - total_width3_mae: 0.3239 - total_amp3_mae: 0.2050 - val_loss: 0.4133 - val_Dense3_peak_number_loss: 0.0056 - val_total_center3_loss: 0.1794 - val_total_width3_loss: 0.1628 - val_total_amp3_loss: 0.0655 - val_Dense3_peak_number_mae: 0.0359 - val_total_center3_mae: 0.2158 - val_total_width3_mae: 0.3153 - val_total_amp3_mae: 0.2023
# Epoch 6/50
# 1800/1800 [==============================] - 97s 54ms/step - loss: 0.4515 - Dense3_peak_number_loss: 0.0074 - total_center3_loss: 0.2128 - total_width3_loss: 0.1644 - total_amp3_loss: 0.0669 - Dense3_peak_number_mae: 0.0398 - total_center3_mae: 0.2425 - total_width3_mae: 0.3174 - total_amp3_mae: 0.2051 - val_loss: 0.4658 - val_Dense3_peak_number_loss: 0.0079 - val_total_center3_loss: 0.2278 - val_total_width3_loss: 0.1628 - val_total_amp3_loss: 0.0672 - val_Dense3_peak_number_mae: 0.0491 - val_total_center3_mae: 0.2755 - val_total_width3_mae: 0.3154 - val_total_amp3_mae: 0.2054
# Epoch 7/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.3700 - Dense3_peak_number_loss: 0.0064 - total_center3_loss: 0.1858 - total_width3_loss: 0.1121 - total_amp3_loss: 0.0656 - Dense3_peak_number_mae: 0.0377 - total_center3_mae: 0.2243 - total_width3_mae: 0.2456 - total_amp3_mae: 0.2025 - val_loss: 0.3431 - val_Dense3_peak_number_loss: 0.0059 - val_total_center3_loss: 0.1693 - val_total_width3_loss: 0.1035 - val_total_amp3_loss: 0.0644 - val_Dense3_peak_number_mae: 0.0315 - val_total_center3_mae: 0.2090 - val_total_width3_mae: 0.2322 - val_total_amp3_mae: 0.1993
# Epoch 8/50
# 1800/1800 [==============================] - 96s 54ms/step - loss: 0.3319 - Dense3_peak_number_loss: 0.0055 - total_center3_loss: 0.1581 - total_width3_loss: 0.1034 - total_amp3_loss: 0.0649 - Dense3_peak_number_mae: 0.0340 - total_center3_mae: 0.2030 - total_width3_mae: 0.2329 - total_amp3_mae: 0.2008 - val_loss: 0.3100 - val_Dense3_peak_number_loss: 0.0044 - val_total_center3_loss: 0.1376 - val_total_width3_loss: 0.1037 - val_total_amp3_loss: 0.0644 - val_Dense3_peak_number_mae: 0.0298 - val_total_center3_mae: 0.1885 - val_total_width3_mae: 0.2324 - val_total_amp3_mae: 0.1999
# Epoch 9/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.3203 - Dense3_peak_number_loss: 0.0054 - total_center3_loss: 0.1477 - total_width3_loss: 0.1026 - total_amp3_loss: 0.0645 - Dense3_peak_number_mae: 0.0334 - total_center3_mae: 0.1945 - total_width3_mae: 0.2321 - total_amp3_mae: 0.1998 - val_loss: 0.2936 - val_Dense3_peak_number_loss: 0.0038 - val_total_center3_loss: 0.1273 - val_total_width3_loss: 0.0987 - val_total_amp3_loss: 0.0637 - val_Dense3_peak_number_mae: 0.0304 - val_total_center3_mae: 0.1711 - val_total_width3_mae: 0.2264 - val_total_amp3_mae: 0.1982
# Epoch 10/50
# 1800/1800 [==============================] - 90s 50ms/step - loss: 0.3098 - Dense3_peak_number_loss: 0.0052 - total_center3_loss: 0.1399 - total_width3_loss: 0.1005 - total_amp3_loss: 0.0642 - Dense3_peak_number_mae: 0.0320 - total_center3_mae: 0.1860 - total_width3_mae: 0.2292 - total_amp3_mae: 0.1990 - val_loss: 0.3069 - val_Dense3_peak_number_loss: 0.0046 - val_total_center3_loss: 0.1392 - val_total_width3_loss: 0.0989 - val_total_amp3_loss: 0.0642 - val_Dense3_peak_number_mae: 0.0300 - val_total_center3_mae: 0.1829 - val_total_width3_mae: 0.2289 - val_total_amp3_mae: 0.1986
# Epoch 11/50
# 1800/1800 [==============================] - 90s 50ms/step - loss: 0.2935 - Dense3_peak_number_loss: 0.0045 - total_center3_loss: 0.1279 - total_width3_loss: 0.0973 - total_amp3_loss: 0.0637 - Dense3_peak_number_mae: 0.0298 - total_center3_mae: 0.1786 - total_width3_mae: 0.2248 - total_amp3_mae: 0.1979 - val_loss: 0.2768 - val_Dense3_peak_number_loss: 0.0035 - val_total_center3_loss: 0.1157 - val_total_width3_loss: 0.0947 - val_total_amp3_loss: 0.0629 - val_Dense3_peak_number_mae: 0.0245 - val_total_center3_mae: 0.1736 - val_total_width3_mae: 0.2216 - val_total_amp3_mae: 0.1963
# Epoch 12/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2843 - Dense3_peak_number_loss: 0.0043 - total_center3_loss: 0.1216 - total_width3_loss: 0.0949 - total_amp3_loss: 0.0635 - Dense3_peak_number_mae: 0.0290 - total_center3_mae: 0.1737 - total_width3_mae: 0.2215 - total_amp3_mae: 0.1974 - val_loss: 0.3480 - val_Dense3_peak_number_loss: 0.0071 - val_total_center3_loss: 0.1694 - val_total_width3_loss: 0.1063 - val_total_amp3_loss: 0.0652 - val_Dense3_peak_number_mae: 0.0317 - val_total_center3_mae: 0.1973 - val_total_width3_mae: 0.2362 - val_total_amp3_mae: 0.1996
# Epoch 13/50
# 1800/1800 [==============================] - 91s 51ms/step - loss: 0.2790 - Dense3_peak_number_loss: 0.0042 - total_center3_loss: 0.1184 - total_width3_loss: 0.0932 - total_amp3_loss: 0.0632 - Dense3_peak_number_mae: 0.0282 - total_center3_mae: 0.1712 - total_width3_mae: 0.2194 - total_amp3_mae: 0.1968 - val_loss: 0.2673 - val_Dense3_peak_number_loss: 0.0032 - val_total_center3_loss: 0.1106 - val_total_width3_loss: 0.0904 - val_total_amp3_loss: 0.0631 - val_Dense3_peak_number_mae: 0.0266 - val_total_center3_mae: 0.1681 - val_total_width3_mae: 0.2174 - val_total_amp3_mae: 0.1964
# Epoch 14/50
# 1800/1800 [==============================] - 91s 50ms/step - loss: 0.2676 - Dense3_peak_number_loss: 0.0038 - total_center3_loss: 0.1106 - total_width3_loss: 0.0905 - total_amp3_loss: 0.0628 - Dense3_peak_number_mae: 0.0265 - total_center3_mae: 0.1648 - total_width3_mae: 0.2154 - total_amp3_mae: 0.1959 - val_loss: 0.2632 - val_Dense3_peak_number_loss: 0.0032 - val_total_center3_loss: 0.1074 - val_total_width3_loss: 0.0908 - val_total_amp3_loss: 0.0618 - val_Dense3_peak_number_mae: 0.0262 - val_total_center3_mae: 0.1640 - val_total_width3_mae: 0.2154 - val_total_amp3_mae: 0.1943
# Epoch 15/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.2635 - Dense3_peak_number_loss: 0.0037 - total_center3_loss: 0.1082 - total_width3_loss: 0.0891 - total_amp3_loss: 0.0625 - Dense3_peak_number_mae: 0.0265 - total_center3_mae: 0.1640 - total_width3_mae: 0.2136 - total_amp3_mae: 0.1953 - val_loss: 0.2487 - val_Dense3_peak_number_loss: 0.0028 - val_total_center3_loss: 0.0975 - val_total_width3_loss: 0.0866 - val_total_amp3_loss: 0.0617 - val_Dense3_peak_number_mae: 0.0220 - val_total_center3_mae: 0.1457 - val_total_width3_mae: 0.2106 - val_total_amp3_mae: 0.1944
# Epoch 16/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2552 - Dense3_peak_number_loss: 0.0034 - total_center3_loss: 0.1021 - total_width3_loss: 0.0874 - total_amp3_loss: 0.0622 - Dense3_peak_number_mae: 0.0253 - total_center3_mae: 0.1588 - total_width3_mae: 0.2113 - total_amp3_mae: 0.1947 - val_loss: 0.2708 - val_Dense3_peak_number_loss: 0.0031 - val_total_center3_loss: 0.1211 - val_total_width3_loss: 0.0851 - val_total_amp3_loss: 0.0615 - val_Dense3_peak_number_mae: 0.0263 - val_total_center3_mae: 0.1887 - val_total_width3_mae: 0.2070 - val_total_amp3_mae: 0.1934
# Epoch 17/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2521 - Dense3_peak_number_loss: 0.0033 - total_center3_loss: 0.1007 - total_width3_loss: 0.0862 - total_amp3_loss: 0.0619 - Dense3_peak_number_mae: 0.0248 - total_center3_mae: 0.1588 - total_width3_mae: 0.2095 - total_amp3_mae: 0.1940 - val_loss: 0.2546 - val_Dense3_peak_number_loss: 0.0038 - val_total_center3_loss: 0.1044 - val_total_width3_loss: 0.0847 - val_total_amp3_loss: 0.0617 - val_Dense3_peak_number_mae: 0.0312 - val_total_center3_mae: 0.1621 - val_total_width3_mae: 0.2078 - val_total_amp3_mae: 0.1941
# Epoch 18/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.2422 - Dense3_peak_number_loss: 0.0029 - total_center3_loss: 0.0934 - total_width3_loss: 0.0843 - total_amp3_loss: 0.0616 - Dense3_peak_number_mae: 0.0232 - total_center3_mae: 0.1519 - total_width3_mae: 0.2068 - total_amp3_mae: 0.1934 - val_loss: 0.2463 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.1009 - val_total_width3_loss: 0.0834 - val_total_amp3_loss: 0.0600 - val_Dense3_peak_number_mae: 0.0174 - val_total_center3_mae: 0.1445 - val_total_width3_mae: 0.2059 - val_total_amp3_mae: 0.1900
# Epoch 19/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2461 - Dense3_peak_number_loss: 0.0032 - total_center3_loss: 0.0971 - total_width3_loss: 0.0844 - total_amp3_loss: 0.0615 - Dense3_peak_number_mae: 0.0243 - total_center3_mae: 0.1555 - total_width3_mae: 0.2070 - total_amp3_mae: 0.1931 - val_loss: 0.2565 - val_Dense3_peak_number_loss: 0.0031 - val_total_center3_loss: 0.1062 - val_total_width3_loss: 0.0856 - val_total_amp3_loss: 0.0615 - val_Dense3_peak_number_mae: 0.0208 - val_total_center3_mae: 0.1527 - val_total_width3_mae: 0.2085 - val_total_amp3_mae: 0.1933
# Epoch 20/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2333 - Dense3_peak_number_loss: 0.0026 - total_center3_loss: 0.0874 - total_width3_loss: 0.0823 - total_amp3_loss: 0.0609 - Dense3_peak_number_mae: 0.0222 - total_center3_mae: 0.1482 - total_width3_mae: 0.2043 - total_amp3_mae: 0.1921 - val_loss: 0.2389 - val_Dense3_peak_number_loss: 0.0023 - val_total_center3_loss: 0.0943 - val_total_width3_loss: 0.0816 - val_total_amp3_loss: 0.0608 - val_Dense3_peak_number_mae: 0.0225 - val_total_center3_mae: 0.1546 - val_total_width3_mae: 0.2026 - val_total_amp3_mae: 0.1919
# Epoch 21/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2323 - Dense3_peak_number_loss: 0.0027 - total_center3_loss: 0.0874 - total_width3_loss: 0.0814 - total_amp3_loss: 0.0609 - Dense3_peak_number_mae: 0.0222 - total_center3_mae: 0.1489 - total_width3_mae: 0.2029 - total_amp3_mae: 0.1920 - val_loss: 0.2469 - val_Dense3_peak_number_loss: 0.0034 - val_total_center3_loss: 0.1016 - val_total_width3_loss: 0.0813 - val_total_amp3_loss: 0.0606 - val_Dense3_peak_number_mae: 0.0321 - val_total_center3_mae: 0.1486 - val_total_width3_mae: 0.2028 - val_total_amp3_mae: 0.1923
# Epoch 22/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2297 - Dense3_peak_number_loss: 0.0026 - total_center3_loss: 0.0857 - total_width3_loss: 0.0806 - total_amp3_loss: 0.0607 - Dense3_peak_number_mae: 0.0217 - total_center3_mae: 0.1476 - total_width3_mae: 0.2020 - total_amp3_mae: 0.1917 - val_loss: 0.2633 - val_Dense3_peak_number_loss: 0.0036 - val_total_center3_loss: 0.1154 - val_total_width3_loss: 0.0832 - val_total_amp3_loss: 0.0611 - val_Dense3_peak_number_mae: 0.0194 - val_total_center3_mae: 0.1581 - val_total_width3_mae: 0.2061 - val_total_amp3_mae: 0.1914
# Epoch 23/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2258 - Dense3_peak_number_loss: 0.0024 - total_center3_loss: 0.0832 - total_width3_loss: 0.0798 - total_amp3_loss: 0.0604 - Dense3_peak_number_mae: 0.0212 - total_center3_mae: 0.1456 - total_width3_mae: 0.2010 - total_amp3_mae: 0.1910 - val_loss: 0.2345 - val_Dense3_peak_number_loss: 0.0022 - val_total_center3_loss: 0.0921 - val_total_width3_loss: 0.0805 - val_total_amp3_loss: 0.0596 - val_Dense3_peak_number_mae: 0.0189 - val_total_center3_mae: 0.1442 - val_total_width3_mae: 0.2014 - val_total_amp3_mae: 0.1892
# Epoch 24/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2231 - Dense3_peak_number_loss: 0.0024 - total_center3_loss: 0.0811 - total_width3_loss: 0.0793 - total_amp3_loss: 0.0603 - Dense3_peak_number_mae: 0.0211 - total_center3_mae: 0.1446 - total_width3_mae: 0.2004 - total_amp3_mae: 0.1906 - val_loss: 0.2338 - val_Dense3_peak_number_loss: 0.0032 - val_total_center3_loss: 0.0928 - val_total_width3_loss: 0.0779 - val_total_amp3_loss: 0.0599 - val_Dense3_peak_number_mae: 0.0302 - val_total_center3_mae: 0.1340 - val_total_width3_mae: 0.1973 - val_total_amp3_mae: 0.1896
# Epoch 25/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2233 - Dense3_peak_number_loss: 0.0024 - total_center3_loss: 0.0819 - total_width3_loss: 0.0789 - total_amp3_loss: 0.0601 - Dense3_peak_number_mae: 0.0207 - total_center3_mae: 0.1450 - total_width3_mae: 0.1998 - total_amp3_mae: 0.1904 - val_loss: 0.2258 - val_Dense3_peak_number_loss: 0.0022 - val_total_center3_loss: 0.0872 - val_total_width3_loss: 0.0776 - val_total_amp3_loss: 0.0589 - val_Dense3_peak_number_mae: 0.0166 - val_total_center3_mae: 0.1367 - val_total_width3_mae: 0.1973 - val_total_amp3_mae: 0.1874
# Epoch 26/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.2194 - Dense3_peak_number_loss: 0.0024 - total_center3_loss: 0.0788 - total_width3_loss: 0.0782 - total_amp3_loss: 0.0600 - Dense3_peak_number_mae: 0.0207 - total_center3_mae: 0.1426 - total_width3_mae: 0.1989 - total_amp3_mae: 0.1901 - val_loss: 0.2259 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0884 - val_total_width3_loss: 0.0762 - val_total_amp3_loss: 0.0593 - val_Dense3_peak_number_mae: 0.0175 - val_total_center3_mae: 0.1450 - val_total_width3_mae: 0.1968 - val_total_amp3_mae: 0.1889
# Epoch 27/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.2147 - Dense3_peak_number_loss: 0.0022 - total_center3_loss: 0.0757 - total_width3_loss: 0.0770 - total_amp3_loss: 0.0598 - Dense3_peak_number_mae: 0.0202 - total_center3_mae: 0.1409 - total_width3_mae: 0.1971 - total_amp3_mae: 0.1897 - val_loss: 0.2259 - val_Dense3_peak_number_loss: 0.0025 - val_total_center3_loss: 0.0884 - val_total_width3_loss: 0.0757 - val_total_amp3_loss: 0.0593 - val_Dense3_peak_number_mae: 0.0192 - val_total_center3_mae: 0.1362 - val_total_width3_mae: 0.1937 - val_total_amp3_mae: 0.1891
# Epoch 28/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.2133 - Dense3_peak_number_loss: 0.0022 - total_center3_loss: 0.0750 - total_width3_loss: 0.0766 - total_amp3_loss: 0.0596 - Dense3_peak_number_mae: 0.0196 - total_center3_mae: 0.1401 - total_width3_mae: 0.1967 - total_amp3_mae: 0.1891 - val_loss: 0.2427 - val_Dense3_peak_number_loss: 0.0029 - val_total_center3_loss: 0.1004 - val_total_width3_loss: 0.0793 - val_total_amp3_loss: 0.0601 - val_Dense3_peak_number_mae: 0.0188 - val_total_center3_mae: 0.1528 - val_total_width3_mae: 0.2012 - val_total_amp3_mae: 0.1892
# Epoch 29/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2134 - Dense3_peak_number_loss: 0.0022 - total_center3_loss: 0.0753 - total_width3_loss: 0.0764 - total_amp3_loss: 0.0595 - Dense3_peak_number_mae: 0.0198 - total_center3_mae: 0.1407 - total_width3_mae: 0.1965 - total_amp3_mae: 0.1890 - val_loss: 0.2248 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0892 - val_total_width3_loss: 0.0744 - val_total_amp3_loss: 0.0591 - val_Dense3_peak_number_mae: 0.0220 - val_total_center3_mae: 0.1600 - val_total_width3_mae: 0.1929 - val_total_amp3_mae: 0.1889
# Epoch 30/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.2069 - Dense3_peak_number_loss: 0.0020 - total_center3_loss: 0.0705 - total_width3_loss: 0.0754 - total_amp3_loss: 0.0590 - Dense3_peak_number_mae: 0.0187 - total_center3_mae: 0.1369 - total_width3_mae: 0.1953 - total_amp3_mae: 0.1879 - val_loss: 0.2406 - val_Dense3_peak_number_loss: 0.0032 - val_total_center3_loss: 0.1009 - val_total_width3_loss: 0.0771 - val_total_amp3_loss: 0.0595 - val_Dense3_peak_number_mae: 0.0172 - val_total_center3_mae: 0.1417 - val_total_width3_mae: 0.1980 - val_total_amp3_mae: 0.1890
# Epoch 31/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2050 - Dense3_peak_number_loss: 0.0019 - total_center3_loss: 0.0695 - total_width3_loss: 0.0749 - total_amp3_loss: 0.0588 - Dense3_peak_number_mae: 0.0187 - total_center3_mae: 0.1357 - total_width3_mae: 0.1945 - total_amp3_mae: 0.1875 - val_loss: 0.2626 - val_Dense3_peak_number_loss: 0.0044 - val_total_center3_loss: 0.1216 - val_total_width3_loss: 0.0772 - val_total_amp3_loss: 0.0594 - val_Dense3_peak_number_mae: 0.0242 - val_total_center3_mae: 0.1545 - val_total_width3_mae: 0.1978 - val_total_amp3_mae: 0.1882
# Epoch 32/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.2051 - Dense3_peak_number_loss: 0.0020 - total_center3_loss: 0.0696 - total_width3_loss: 0.0746 - total_amp3_loss: 0.0590 - Dense3_peak_number_mae: 0.0192 - total_center3_mae: 0.1358 - total_width3_mae: 0.1943 - total_amp3_mae: 0.1879 - val_loss: 0.3646 - val_Dense3_peak_number_loss: 0.0093 - val_total_center3_loss: 0.2058 - val_total_width3_loss: 0.0852 - val_total_amp3_loss: 0.0643 - val_Dense3_peak_number_mae: 0.0262 - val_total_center3_mae: 0.1817 - val_total_width3_mae: 0.2089 - val_total_amp3_mae: 0.1979
# Epoch 33/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2042 - Dense3_peak_number_loss: 0.0020 - total_center3_loss: 0.0690 - total_width3_loss: 0.0743 - total_amp3_loss: 0.0589 - Dense3_peak_number_mae: 0.0187 - total_center3_mae: 0.1355 - total_width3_mae: 0.1939 - total_amp3_mae: 0.1877 - val_loss: 0.2518 - val_Dense3_peak_number_loss: 0.0030 - val_total_center3_loss: 0.1119 - val_total_width3_loss: 0.0776 - val_total_amp3_loss: 0.0592 - val_Dense3_peak_number_mae: 0.0185 - val_total_center3_mae: 0.1460 - val_total_width3_mae: 0.1981 - val_total_amp3_mae: 0.1887
# Epoch 34/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1989 - Dense3_peak_number_loss: 0.0018 - total_center3_loss: 0.0653 - total_width3_loss: 0.0734 - total_amp3_loss: 0.0584 - Dense3_peak_number_mae: 0.0181 - total_center3_mae: 0.1331 - total_width3_mae: 0.1926 - total_amp3_mae: 0.1867 - val_loss: 0.2356 - val_Dense3_peak_number_loss: 0.0025 - val_total_center3_loss: 0.0966 - val_total_width3_loss: 0.0779 - val_total_amp3_loss: 0.0586 - val_Dense3_peak_number_mae: 0.0182 - val_total_center3_mae: 0.1458 - val_total_width3_mae: 0.1987 - val_total_amp3_mae: 0.1866
# Epoch 35/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.2040 - Dense3_peak_number_loss: 0.0021 - total_center3_loss: 0.0694 - total_width3_loss: 0.0740 - total_amp3_loss: 0.0586 - Dense3_peak_number_mae: 0.0185 - total_center3_mae: 0.1362 - total_width3_mae: 0.1937 - total_amp3_mae: 0.1869 - val_loss: 0.2473 - val_Dense3_peak_number_loss: 0.0035 - val_total_center3_loss: 0.1031 - val_total_width3_loss: 0.0814 - val_total_amp3_loss: 0.0594 - val_Dense3_peak_number_mae: 0.0339 - val_total_center3_mae: 0.1693 - val_total_width3_mae: 0.2056 - val_total_amp3_mae: 0.1886
# Epoch 36/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1944 - Dense3_peak_number_loss: 0.0017 - total_center3_loss: 0.0622 - total_width3_loss: 0.0723 - total_amp3_loss: 0.0582 - Dense3_peak_number_mae: 0.0171 - total_center3_mae: 0.1307 - total_width3_mae: 0.1913 - total_amp3_mae: 0.1864 - val_loss: 0.2194 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0858 - val_total_width3_loss: 0.0735 - val_total_amp3_loss: 0.0583 - val_Dense3_peak_number_mae: 0.0170 - val_total_center3_mae: 0.1384 - val_total_width3_mae: 0.1942 - val_total_amp3_mae: 0.1867
# Epoch 37/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1974 - Dense3_peak_number_loss: 0.0018 - total_center3_loss: 0.0647 - total_width3_loss: 0.0728 - total_amp3_loss: 0.0581 - Dense3_peak_number_mae: 0.0177 - total_center3_mae: 0.1323 - total_width3_mae: 0.1923 - total_amp3_mae: 0.1859 - val_loss: 0.2148 - val_Dense3_peak_number_loss: 0.0018 - val_total_center3_loss: 0.0829 - val_total_width3_loss: 0.0718 - val_total_amp3_loss: 0.0583 - val_Dense3_peak_number_mae: 0.0153 - val_total_center3_mae: 0.1344 - val_total_width3_mae: 0.1897 - val_total_amp3_mae: 0.1861
# Epoch 38/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1938 - Dense3_peak_number_loss: 0.0017 - total_center3_loss: 0.0622 - total_width3_loss: 0.0721 - total_amp3_loss: 0.0578 - Dense3_peak_number_mae: 0.0173 - total_center3_mae: 0.1305 - total_width3_mae: 0.1913 - total_amp3_mae: 0.1853 - val_loss: 0.2427 - val_Dense3_peak_number_loss: 0.0046 - val_total_center3_loss: 0.1051 - val_total_width3_loss: 0.0742 - val_total_amp3_loss: 0.0587 - val_Dense3_peak_number_mae: 0.0284 - val_total_center3_mae: 0.1434 - val_total_width3_mae: 0.1930 - val_total_amp3_mae: 0.1880
# Epoch 39/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1948 - Dense3_peak_number_loss: 0.0018 - total_center3_loss: 0.0630 - total_width3_loss: 0.0723 - total_amp3_loss: 0.0577 - Dense3_peak_number_mae: 0.0175 - total_center3_mae: 0.1312 - total_width3_mae: 0.1916 - total_amp3_mae: 0.1852 - val_loss: 0.2365 - val_Dense3_peak_number_loss: 0.0029 - val_total_center3_loss: 0.0977 - val_total_width3_loss: 0.0768 - val_total_amp3_loss: 0.0592 - val_Dense3_peak_number_mae: 0.0200 - val_total_center3_mae: 0.1548 - val_total_width3_mae: 0.1982 - val_total_amp3_mae: 0.1879
# Epoch 40/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1928 - Dense3_peak_number_loss: 0.0017 - total_center3_loss: 0.0618 - total_width3_loss: 0.0716 - total_amp3_loss: 0.0577 - Dense3_peak_number_mae: 0.0172 - total_center3_mae: 0.1304 - total_width3_mae: 0.1908 - total_amp3_mae: 0.1851 - val_loss: 0.2142 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0833 - val_total_width3_loss: 0.0712 - val_total_amp3_loss: 0.0575 - val_Dense3_peak_number_mae: 0.0157 - val_total_center3_mae: 0.1298 - val_total_width3_mae: 0.1897 - val_total_amp3_mae: 0.1852
# Epoch 41/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1901 - Dense3_peak_number_loss: 0.0016 - total_center3_loss: 0.0598 - total_width3_loss: 0.0713 - total_amp3_loss: 0.0574 - Dense3_peak_number_mae: 0.0167 - total_center3_mae: 0.1286 - total_width3_mae: 0.1905 - total_amp3_mae: 0.1844 - val_loss: 0.2059 - val_Dense3_peak_number_loss: 0.0018 - val_total_center3_loss: 0.0772 - val_total_width3_loss: 0.0703 - val_total_amp3_loss: 0.0567 - val_Dense3_peak_number_mae: 0.0156 - val_total_center3_mae: 0.1231 - val_total_width3_mae: 0.1883 - val_total_amp3_mae: 0.1831
# Epoch 42/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1894 - Dense3_peak_number_loss: 0.0016 - total_center3_loss: 0.0593 - total_width3_loss: 0.0711 - total_amp3_loss: 0.0573 - Dense3_peak_number_mae: 0.0170 - total_center3_mae: 0.1286 - total_width3_mae: 0.1903 - total_amp3_mae: 0.1842 - val_loss: 0.2271 - val_Dense3_peak_number_loss: 0.0022 - val_total_center3_loss: 0.0930 - val_total_width3_loss: 0.0745 - val_total_amp3_loss: 0.0574 - val_Dense3_peak_number_mae: 0.0187 - val_total_center3_mae: 0.1462 - val_total_width3_mae: 0.1950 - val_total_amp3_mae: 0.1844
# Epoch 43/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1895 - Dense3_peak_number_loss: 0.0016 - total_center3_loss: 0.0597 - total_width3_loss: 0.0709 - total_amp3_loss: 0.0572 - Dense3_peak_number_mae: 0.0165 - total_center3_mae: 0.1291 - total_width3_mae: 0.1901 - total_amp3_mae: 0.1841 - val_loss: 0.2190 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0886 - val_total_width3_loss: 0.0714 - val_total_amp3_loss: 0.0571 - val_Dense3_peak_number_mae: 0.0151 - val_total_center3_mae: 0.1388 - val_total_width3_mae: 0.1902 - val_total_amp3_mae: 0.1848
# Epoch 44/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1862 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0572 - total_width3_loss: 0.0703 - total_amp3_loss: 0.0571 - Dense3_peak_number_mae: 0.0163 - total_center3_mae: 0.1264 - total_width3_mae: 0.1892 - total_amp3_mae: 0.1838 - val_loss: 0.2162 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0871 - val_total_width3_loss: 0.0704 - val_total_amp3_loss: 0.0567 - val_Dense3_peak_number_mae: 0.0158 - val_total_center3_mae: 0.1248 - val_total_width3_mae: 0.1890 - val_total_amp3_mae: 0.1833
# Epoch 45/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1856 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0569 - total_width3_loss: 0.0701 - total_amp3_loss: 0.0571 - Dense3_peak_number_mae: 0.0163 - total_center3_mae: 0.1263 - total_width3_mae: 0.1888 - total_amp3_mae: 0.1838 - val_loss: 0.2144 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0861 - val_total_width3_loss: 0.0701 - val_total_amp3_loss: 0.0560 - val_Dense3_peak_number_mae: 0.0155 - val_total_center3_mae: 0.1320 - val_total_width3_mae: 0.1886 - val_total_amp3_mae: 0.1819
# Epoch 46/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1846 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0565 - total_width3_loss: 0.0699 - total_amp3_loss: 0.0568 - Dense3_peak_number_mae: 0.0159 - total_center3_mae: 0.1256 - total_width3_mae: 0.1888 - total_amp3_mae: 0.1831 - val_loss: 0.2575 - val_Dense3_peak_number_loss: 0.0037 - val_total_center3_loss: 0.1226 - val_total_width3_loss: 0.0727 - val_total_amp3_loss: 0.0585 - val_Dense3_peak_number_mae: 0.0158 - val_total_center3_mae: 0.1435 - val_total_width3_mae: 0.1907 - val_total_amp3_mae: 0.1853
# Epoch 47/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1839 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0559 - total_width3_loss: 0.0698 - total_amp3_loss: 0.0567 - Dense3_peak_number_mae: 0.0162 - total_center3_mae: 0.1257 - total_width3_mae: 0.1887 - total_amp3_mae: 0.1830 - val_loss: 0.2020 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0761 - val_total_width3_loss: 0.0676 - val_total_amp3_loss: 0.0562 - val_Dense3_peak_number_mae: 0.0249 - val_total_center3_mae: 0.1205 - val_total_width3_mae: 0.1846 - val_total_amp3_mae: 0.1819
# Epoch 48/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1849 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0569 - total_width3_loss: 0.0697 - total_amp3_loss: 0.0568 - Dense3_peak_number_mae: 0.0160 - total_center3_mae: 0.1265 - total_width3_mae: 0.1885 - total_amp3_mae: 0.1833 - val_loss: 0.2107 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0819 - val_total_width3_loss: 0.0706 - val_total_amp3_loss: 0.0567 - val_Dense3_peak_number_mae: 0.0132 - val_total_center3_mae: 0.1349 - val_total_width3_mae: 0.1893 - val_total_amp3_mae: 0.1832
# Epoch 49/50
# 1800/1800 [==============================] - 93s 51ms/step - loss: 0.1820 - Dense3_peak_number_loss: 0.0014 - total_center3_loss: 0.0550 - total_width3_loss: 0.0689 - total_amp3_loss: 0.0567 - Dense3_peak_number_mae: 0.0157 - total_center3_mae: 0.1245 - total_width3_mae: 0.1875 - total_amp3_mae: 0.1829 - val_loss: 0.2109 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0823 - val_total_width3_loss: 0.0696 - val_total_amp3_loss: 0.0569 - val_Dense3_peak_number_mae: 0.0155 - val_total_center3_mae: 0.1309 - val_total_width3_mae: 0.1876 - val_total_amp3_mae: 0.1832
# Epoch 50/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1839 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0565 - total_width3_loss: 0.0691 - total_amp3_loss: 0.0568 - Dense3_peak_number_mae: 0.0158 - total_center3_mae: 0.1261 - total_width3_mae: 0.1877 - total_amp3_mae: 0.1832 - val_loss: 0.2013 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0767 - val_total_width3_loss: 0.0674 - val_total_amp3_loss: 0.0556 - val_Dense3_peak_number_mae: 0.0108 - val_total_center3_mae: 0.1198 - val_total_width3_mae: 0.1848 - val_total_amp3_mae: 0.1810

# %%
test_graph.shape
# Out:
# (20000, 401, 1)

# %%
for key in models.history.keys():
    print(key)
# Out:
# loss
# Dense3_peak_number_loss
# total_center3_loss
# total_width3_loss
# total_amp3_loss
# Dense3_peak_number_mae
# total_center3_mae
# total_width3_mae
# total_amp3_mae
# val_loss
# val_Dense3_peak_number_loss
# val_total_center3_loss
# val_total_width3_loss
# val_total_amp3_loss
# val_Dense3_peak_number_mae
# val_total_center3_mae
# val_total_width3_mae
# val_total_amp3_mae

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center3_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center3_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width3_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width3_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp3_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp3_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (20000, 10)
# (20000, 3)
# (20000, 3)
# (20000, 3)

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,color='black')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'blue')
    plt.grid(True)
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
# Out:
# real_center   [ 0.          5.71315308 11.91923309]
# predict_center [ 0.041291572 5.5532 11.896942 ]
# ---------------
# real_width    [0.         0.84337558 1.79121459]
# predict_center [ -0.0032861829 0.7716426 1.6227193 ]
# ---------------
# real_amp      [0.         0.88023975 1.04841723]
# predict_center [ -0.0051965155 0.70901626 0.9029958 ]
# real_center   [ 0.          6.39994478 12.93951819]
# predict_center [ 0.034462787 6.4850173 12.726681 ]
# ---------------
# real_width    [0.         1.65652237 0.93438808]
# predict_center [ -0.0041211396 1.6046457 0.5624931 ]
# ---------------
# real_amp      [0.         0.99348086 0.9478093 ]
# predict_center [ 0.008381061 0.8163334 0.58832866 ]
# real_center   [ 3.23631434  6.18606995 12.52827948]
# predict_center [ 3.3199632 6.155592 12.565233 ]
# ---------------
# real_width    [1.66278035 1.68069287 1.00126402]
# predict_center [ 1.5442812 1.3493748 1.2326022 ]
# ---------------
# real_amp      [0.17531519 0.19742663 0.9243484 ]
# predict_center [ 0.5913536 0.5929854 0.5686556 ]
# real_center   [ 0.          3.86715569 10.86221601]
# predict_center [ 0.014386393 3.8943155 10.965079 ]
# ---------------
# real_width    [0.         0.59165533 0.40581259]
# predict_center [ -0.00196746 0.5930957 0.5752763 ]
# ---------------
# real_amp      [0.         0.51955378 0.53934786]
# predict_center [ 0.0026741065 0.41183877 0.6539227 ]
# real_center   [ 0.          9.45233636 12.62868582]
# predict_center [ 0.025344945 9.361634 12.446439 ]
# ---------------
# real_width    [0.         1.44668865 1.87998592]
# predict_center [ -0.008069366 1.6554804 1.6096126 ]
# ---------------
# real_amp      [0.         0.91245941 0.36050666]
# predict_center [ -0.009534422 0.87241995 0.8105105 ]
# real_center   [0.         2.00332775 6.03248714]
# predict_center [ 4.378702e-05 2.225381 6.1201344 ]
# ---------------
# real_width    [0.         0.59737084 0.7272154 ]
# predict_center [ -0.0017304122 0.56646276 0.68651026 ]
# ---------------
# real_amp      [0.         0.90353073 0.66262424]
# predict_center [ 0.008383419 0.7126591 0.71665967 ]
# real_center   [ 0.         11.42268043 12.25882526]
# predict_center [ 0.025003172 11.587369 12.27371 ]
# ---------------
# real_width    [0.         0.75334379 1.47571775]
# predict_center [ -0.009229511 0.5338815 1.4302452 ]
# ---------------
# real_amp      [0.         0.59638167 0.17278906]
# predict_center [ 0.008525951 0.6826422 0.48646566 ]
# real_center   [ 2.57538501  2.73040878 12.45116549]
# predict_center [ 2.2773335 2.7112615 12.506296 ]
# ---------------
# real_width    [0.41405293 0.60919744 1.12779081]
# predict_center [ 0.7326547 0.47075456 1.1864666 ]
# ---------------
# real_amp      [0.5085511  0.80758984 0.70893355]
# predict_center [ 0.59569263 0.5742441 0.6151167 ]
# real_center   [ 2.9017155   7.54113871 10.03829508]
# predict_center [ 2.8587294 7.5368905 10.131084 ]
# ---------------
# real_width    [0.3609779 1.5868491 1.5857514]
# predict_center [ 0.88191926 1.5031271 1.0063525 ]
# ---------------
# real_amp      [0.9967733  0.57811673 0.29408781]
# predict_center [ 0.62440157 0.62958896 0.55477417 ]
# real_center   [5.70187413 6.47325447 7.95269075]
# predict_center [ 5.8501096 6.4351377 7.7883015 ]
# ---------------
# real_width    [0.35270478 1.15793397 1.67777024]
# predict_center [ 1.2782496 1.3832061 1.4934223 ]
# ---------------
# real_amp      [0.28978847 0.72433166 0.41654231]
# predict_center [ 0.5806629 0.5325086 0.5867544 ]
# real_center   [ 0.          4.21687094 12.34120659]
# predict_center [ 0.017272986 4.26627 12.338207 ]
# ---------------
# real_width    [0.         0.36773928 0.81390437]
# predict_center [ 0.042052567 0.44210315 0.5571418 ]
# ---------------
# real_amp      [0.         0.78705796 0.79347587]
# predict_center [ 0.007021319 0.70896935 0.87659407 ]
# real_center   [ 7.64690374  7.88672447 11.75998207]
# predict_center [ 7.5452714 8.297607 11.7985325 ]
# ---------------
# real_width    [1.57721792 0.35065511 1.76987164]
# predict_center [ 1.4886862 0.71311086 0.997247 ]
# ---------------
# real_amp      [0.15874303 0.52349397 0.94926077]
# predict_center [ 0.60376024 0.65731156 0.592095 ]
# real_center   [2.97550177 6.17211837 8.66438667]
# predict_center [ 3.234794 6.12778 8.497597 ]
# ---------------
# real_width    [1.63453699 0.70265382 0.91474209]
# predict_center [ 1.4526366 0.7076907 1.1039604 ]
# ---------------
# real_amp      [0.76022675 1.01366238 1.09569614]
# predict_center [ 0.6052035 0.6198383 0.589816 ]
# real_center   [ 0.          9.77946893 10.97017916]
# predict_center [ 0.01979319 9.939354 10.84263 ]
# ---------------
# real_width    [0.         0.39829634 1.05510464]
# predict_center [ -0.010104239 0.5522537 1.4771223 ]
# ---------------
# real_amp      [0.         1.01298834 0.78358955]
# predict_center [ 0.006118024 0.6269548 0.48647022 ]
# real_center   [ 3.8569353   4.12070216 12.11402843]
# predict_center [ 3.7950213 4.1339154 12.178549 ]
# ---------------
# real_width    [0.4981711  0.58429175 1.10961953]
# predict_center [ 0.82885957 0.6689387 1.2013977 ]
# ---------------
# real_amp      [0.83741193 0.49685655 0.19540706]
# predict_center [ 0.5723921 0.62305546 0.6033099 ]
# real_center   [2.4287244  8.00130851 8.73111697]
# predict_center [ 2.501717 8.1236 8.612796 ]
# ---------------
# real_width    [1.30205305 0.73029477 1.26629847]
# predict_center [ 1.2208953 0.58701384 1.4789248 ]
# ---------------
# real_amp      [0.414536   0.85436318 0.82462015]
# predict_center [ 0.585413 0.6722851 0.62516195 ]
# real_center   [0.         4.6604788  7.58096173]
# predict_center [ -0.0032757744 4.63505 7.368191 ]
# ---------------
# real_width    [0.         0.74087437 0.40953535]
# predict_center [ 0.008422092 0.6979981 0.71779716 ]
# ---------------
# real_amp      [0.         1.0195198  1.04926695]
# predict_center [ 0.010812953 0.8085205 0.8470216 ]
# real_center   [ 0.          4.61549707 12.73793585]
# predict_center [ 0.020980932 4.6421046 12.791452 ]
# ---------------
# real_width    [0.         1.11693444 1.17194019]
# predict_center [ -0.0023755431 1.0708885 1.1706305 ]
# ---------------
# real_amp      [0.         0.53062024 0.33579517]
# predict_center [ -0.0016391501 0.46028516 0.39287403 ]
# real_center   [ 5.12023748  5.84530511 10.99748078]
# predict_center [ 5.1431203 5.706847 10.853437 ]
# ---------------
# real_width    [1.34057725 0.74437628 1.38113455]
# predict_center [ 1.4468917 0.668463 1.2878315 ]
# ---------------
# real_amp      [0.84935913 0.70472954 0.46106577]
# predict_center [ 0.58927375 0.6717747 0.58577335 ]
# real_center   [ 8.0085005   8.9801749  11.72798113]
# predict_center [ 7.989905 8.741523 11.814584 ]
# ---------------
# real_width    [1.09531881 1.22843115 0.76551006]
# predict_center [ 0.8030673 1.4664941 0.8055218 ]
# ---------------
# real_amp      [0.71929417 0.23130514 0.83006498]
# predict_center [ 0.6254788 0.5877361 0.58741546 ]

# %%
plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")

# 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("P3HT Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0088172, 2.0000505, 2.0019102, 1.9900824, 2.0037224, 2.0024672,
#         1.9952447, 2.0004044, 2.004605 , 2.0021484]], dtype=float32), array([[ 0.01682345, 10.697281  , 11.090897  ]], dtype=float32), array([[-0.01148692,  1.5968254 ,  1.0744859 ]], dtype=float32), array([[0.00909487, 0.62358797, 0.6238164 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (10,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
# Out:
# Text(0.5, 1.0, 'Network fitting vs real XPS graph')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
# Out:
# Text(0.5, 1.0, 'Predict_peak1 vs Xps_peak1')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak2 vs Xps_peak2')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak3 vs Xps_peak3')

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0211093, 2.003799 , 2.0067067, 2.0105405, 2.0099454, 2.0168638,
#         2.0065913, 2.0249937, 2.0127728, 2.0177894]], dtype=float32), array([[7.8997165e-03, 7.4801936e+00, 8.4634695e+00]], dtype=float32), array([[-0.00340536,  0.5485997 ,  0.6422743 ]], dtype=float32), array([[0.0017523 , 0.6131245 , 0.53624886]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (10,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()

# %%
#model 에 peak_number에 각각 200층으로 총 2개로 하나 추가하고 추력값은 일단 10으로
# loss_weight은 다시 원래대로 설정해놨어
# 안되면 peak_number에 마지막출력층을 1으로 할거야
# 그리고 각각의 center,amp,width를 100,60,40이 아닌 200 100 40으로 해볼거야
# loss_weight의  peak_number와 amp를 올릴거야

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')
# Out:
# error_center_total =  [1737.6833828  3371.31274717 2143.24820671]
# error_center =   [0.08688417 0.16856564 0.10716241]
#
#
# error_width_total =  [2826.27849275 3824.87151467 4328.02596565]
# error_width =   [0.14131392 0.19124358 0.2164013 ]
#
#
# error_amp_total =  [2473.78975292 4234.98997852 4099.83870348]
# error_amp =   [0.12368949 0.2117495  0.20499194]

# %%
(abs(prediction[1][0]-test_center[0])+abs(prediction[1][1]-test_center[1]))/2
# Out:
# array([0.02408092, 0.03175016, 0.05051787])

# %%
# Out:
# 20000
