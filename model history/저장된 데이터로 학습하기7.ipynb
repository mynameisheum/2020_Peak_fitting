# %%
# %ls
# Out:
# '2,3peak mix.ipynb'                    Untitled4.ipynb
# '5peak 3 para when it worksss.ipynb'   Untitled5.ipynb
# 'Fitting_with_noise (1).ipynb'         amp.csv
#  ITO_O1s_bg.txt                        center.csv
#  ITO_O1s_exp.txt                       graph.csv
#  ITO_O1s_fitting.txt                   labels.png
#  ITO_O1s_p1.txt                        model.png
#  ITO_O1s_p2.txt                        model_shapes.png
#  ITO_O1s_p3.txt                        peak_number.csv
#  P3HT_S2p_bg.txt                       width.csv
#  P3HT_S2p_exp.txt                     '논문 수정.ipynb'
#  P3HT_S2p_fitting.txt                 '데이터 얻기.ipynb'
#  P3HT_S2p_p1.txt                      '저장된 데이터로 학습하기.ipynb'
#  P3HT_S2p_p2.txt                      '저장된 데이터로 학습하기2.ipynb'
#  PeakDetection.ipynb                  '저장된 데이터로 학습하기3.ipynb'
#  Untitled.ipynb                       '저장된 데이터로 학습하기4.ipynb'
#  Untitled1.ipynb                      '저장된 데이터로 학습하기5.ipynb'
#  Untitled2.ipynb                      '저장된 데이터로 학습하기6.ipynb'
#  Untitled3.ipynb                      '저장된 데이터로 학습하기7.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph.csv').values[:,1:]
center= pd.read_csv('center.csv').values[:,1:]
width= pd.read_csv('width.csv').values[:,1:]
amp= pd.read_csv('amp.csv').values[:,1:]
peak_number= pd.read_csv('peak_number.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(2000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 0.          6.08688456 11.0810396 ]
#  [ 5.07493349  8.25999368 11.36195096]
#  [ 0.          2.67516221 10.60419171]
#  [ 0.          5.54053864 12.23836258]
#  [ 0.          4.08422309  7.21849474]
#  [ 0.          7.30192691 12.34014272]
#  [ 0.          2.54016398  5.16493207]
#  [ 0.          4.67819908  6.09299318]
#  [ 4.90655934  5.13202252 10.34134357]
#  [ 0.          5.36008602  5.98285268]]
# [[0.         1.24062404 0.95374601]
#  [0.60456503 0.35785198 1.1738216 ]
#  [0.         1.17339162 1.12952083]
#  [0.         0.81456259 0.81987822]
#  [0.         0.81681444 1.70560007]
#  [0.         0.32207246 0.75414831]
#  [0.         0.30486538 1.895045  ]
#  [0.         0.59293989 0.4647601 ]
#  [1.46428848 1.12931752 1.8841104 ]
#  [0.         1.00584571 1.33599321]]
# [[0.         0.21158879 0.18180892]
#  [0.11125957 0.85593768 0.31159992]
#  [0.         0.59012228 0.71652582]
#  [0.         1.00856931 0.70388527]
#  [0.         0.94976759 0.16667863]
#  [0.         0.43501787 0.93207997]
#  [0.         0.8393851  0.5707349 ]
#  [0.         0.11555586 0.72638366]
#  [1.00347794 0.40013242 0.8164851 ]
#  [0.         0.10848772 1.08853046]]
# [2 3 2 2 2 2 2 2 3 2]
# (2000000, 3)
# (2000000, 3)
# (2000000, 3)
# (2000000,)
# (2000000, 401)
# [[ 1.65293992e-02 -1.56062971e-02 -8.67543953e-07 ...  2.55348472e-02
#   -3.85644720e-02  5.34629487e-04]
#  [ 1.77760845e-02 -1.43048937e-02  2.75018580e-03 ...  2.09525854e-02
#   -8.81444533e-03 -2.84847278e-02]
#  [ 1.36186941e-02 -1.15794033e-02  1.45041681e-02 ...  3.96018586e-02
#   -3.21144103e-03  8.85769143e-03]
#  ...
#  [-1.24151960e-02 -2.96612110e-02 -2.18882173e-02 ... -3.89587815e-02
#   -3.64336021e-02  2.78148435e-02]
#  [ 5.39405308e-03 -3.18972828e-02  3.10126407e-03 ...  1.12031471e-02
#   -4.49491273e-02  2.58940119e-03]
#  [-2.81865060e-02 -1.40640285e-02  3.61211482e-02 ... -1.77982928e-02
#   -8.35706460e-03  1.54521213e-02]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
#90:9:1
data_number=1000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (1800000, 401) (180000, 401) (20000, 401)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000,) (180000,) (20000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (1800000, 401, 1)
# (180000, 401, 1)
# (20000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
input_data = Input(shape = (len(x),1))
t = layers.Conv1D(128,100,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,50,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,20,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(16,10,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)

Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(1, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(200, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(100, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(200,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(100,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(200,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(100,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
center_Batchnormalization  = BatchNormalization()(total_center1)
# total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center2 = Dense(3, activation = 'linear',name = 'total_center2')(center_Batchnormalization)


width_merge = concatenate([Dense3_peak_number,Dense3_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
width_Batchnormalization  = BatchNormalization()(total_width1)
# total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width2= Dense(3, activation = 'linear',name = 'total_width2')(width_Batchnormalization)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
amp_Batchnormalization  = BatchNormalization()(total_amp1)
# total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp2 = Dense(3, activation = 'linear',name = 'total_amp2')(amp_Batchnormalization)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center2,total_width2,total_amp2])
print(model.summary())
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 302, 128)     12928       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 151, 128)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 102, 128)     819328      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 51, 128)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 32, 128)      327808      max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 16, 128)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 7, 16)        20496       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 3, 16)        0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 16)           0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 100)          20100       Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 100)          20100       Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 100)          20100       Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 1)            201         Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           4040        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           4040        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           4040        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           1680        concatenate[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           1680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           1680        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 40)           160         total_center1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 40)           160         total_width1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40)           160         total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 3)            123         batch_normalization[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 3)            123         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 3)            123         batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 1,312,870
# Trainable params: 1,312,630
# Non-trainable params: 240
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center2' : 'mse',
                      'total_width2' : 'mse',
                      'total_amp2' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 0.5,
#                            'total_width3' : 1,
#                            'total_amp3' : 1,
#                             'Dense3_peak_number' :1 },
              metrics = ['mae'])

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 50,
          batch_size = 1000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 5.1750 - Dense3_peak_number_loss: 0.0718 - total_center2_loss: 4.9481 - total_width2_loss: 0.1063 - total_amp2_loss: 0.0488 - Dense3_peak_number_mae: 0.1683 - total_center2_mae: 1.0360 - total_width2_mae: 0.2138 - total_amp2_mae: 0.1627 - val_loss: 0.4974 - val_Dense3_peak_number_loss: 0.0182 - val_total_center2_loss: 0.3975 - val_total_width2_loss: 0.0477 - val_total_amp2_loss: 0.0340 - val_Dense3_peak_number_mae: 0.0749 - val_total_center2_mae: 0.3586 - val_total_width2_mae: 0.1487 - val_total_amp2_mae: 0.1332
# Epoch 2/50
# 1800/1800 [==============================] - 96s 53ms/step - loss: 0.2956 - Dense3_peak_number_loss: 0.0143 - total_center2_loss: 0.2126 - total_width2_loss: 0.0398 - total_amp2_loss: 0.0288 - Dense3_peak_number_mae: 0.0659 - total_center2_mae: 0.2345 - total_width2_mae: 0.1326 - total_amp2_mae: 0.1220 - val_loss: 0.2472 - val_Dense3_peak_number_loss: 0.0112 - val_total_center2_loss: 0.1664 - val_total_width2_loss: 0.0416 - val_total_amp2_loss: 0.0280 - val_Dense3_peak_number_mae: 0.0574 - val_total_center2_mae: 0.1994 - val_total_width2_mae: 0.1409 - val_total_amp2_mae: 0.1230
# Epoch 3/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.2389 - Dense3_peak_number_loss: 0.0101 - total_center2_loss: 0.1709 - total_width2_loss: 0.0339 - total_amp2_loss: 0.0241 - Dense3_peak_number_mae: 0.0481 - total_center2_mae: 0.2047 - total_width2_mae: 0.1204 - total_amp2_mae: 0.1085 - val_loss: 0.3309 - val_Dense3_peak_number_loss: 0.0065 - val_total_center2_loss: 0.2664 - val_total_width2_loss: 0.0337 - val_total_amp2_loss: 0.0242 - val_Dense3_peak_number_mae: 0.0419 - val_total_center2_mae: 0.3524 - val_total_width2_mae: 0.1188 - val_total_amp2_mae: 0.1085
# Epoch 4/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.2042 - Dense3_peak_number_loss: 0.0074 - total_center2_loss: 0.1457 - total_width2_loss: 0.0300 - total_amp2_loss: 0.0212 - Dense3_peak_number_mae: 0.0396 - total_center2_mae: 0.1885 - total_width2_mae: 0.1121 - total_amp2_mae: 0.1005 - val_loss: 0.4973 - val_Dense3_peak_number_loss: 0.0268 - val_total_center2_loss: 0.3866 - val_total_width2_loss: 0.0570 - val_total_amp2_loss: 0.0269 - val_Dense3_peak_number_mae: 0.0602 - val_total_center2_mae: 0.2774 - val_total_width2_mae: 0.1586 - val_total_amp2_mae: 0.1175
# Epoch 5/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1925 - Dense3_peak_number_loss: 0.0065 - total_center2_loss: 0.1374 - total_width2_loss: 0.0287 - total_amp2_loss: 0.0199 - Dense3_peak_number_mae: 0.0361 - total_center2_mae: 0.1822 - total_width2_mae: 0.1091 - total_amp2_mae: 0.0966 - val_loss: 0.1669 - val_Dense3_peak_number_loss: 0.0045 - val_total_center2_loss: 0.1158 - val_total_width2_loss: 0.0257 - val_total_amp2_loss: 0.0209 - val_Dense3_peak_number_mae: 0.0272 - val_total_center2_mae: 0.1552 - val_total_width2_mae: 0.1052 - val_total_amp2_mae: 0.1026
# Epoch 6/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1727 - Dense3_peak_number_loss: 0.0052 - total_center2_loss: 0.1228 - total_width2_loss: 0.0265 - total_amp2_loss: 0.0183 - Dense3_peak_number_mae: 0.0314 - total_center2_mae: 0.1719 - total_width2_mae: 0.1039 - total_amp2_mae: 0.0919 - val_loss: 0.2122 - val_Dense3_peak_number_loss: 0.0062 - val_total_center2_loss: 0.1560 - val_total_width2_loss: 0.0308 - val_total_amp2_loss: 0.0193 - val_Dense3_peak_number_mae: 0.0359 - val_total_center2_mae: 0.1980 - val_total_width2_mae: 0.1199 - val_total_amp2_mae: 0.0993
# Epoch 7/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1626 - Dense3_peak_number_loss: 0.0049 - total_center2_loss: 0.1153 - total_width2_loss: 0.0251 - total_amp2_loss: 0.0173 - Dense3_peak_number_mae: 0.0311 - total_center2_mae: 0.1673 - total_width2_mae: 0.1006 - total_amp2_mae: 0.0888 - val_loss: 0.1600 - val_Dense3_peak_number_loss: 0.0040 - val_total_center2_loss: 0.1124 - val_total_width2_loss: 0.0241 - val_total_amp2_loss: 0.0195 - val_Dense3_peak_number_mae: 0.0387 - val_total_center2_mae: 0.1829 - val_total_width2_mae: 0.0999 - val_total_amp2_mae: 0.1011
# Epoch 8/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1497 - Dense3_peak_number_loss: 0.0041 - total_center2_loss: 0.1060 - total_width2_loss: 0.0232 - total_amp2_loss: 0.0164 - Dense3_peak_number_mae: 0.0254 - total_center2_mae: 0.1605 - total_width2_mae: 0.0961 - total_amp2_mae: 0.0861 - val_loss: 0.1892 - val_Dense3_peak_number_loss: 0.0036 - val_total_center2_loss: 0.1447 - val_total_width2_loss: 0.0241 - val_total_amp2_loss: 0.0168 - val_Dense3_peak_number_mae: 0.0271 - val_total_center2_mae: 0.2245 - val_total_width2_mae: 0.1034 - val_total_amp2_mae: 0.0884
# Epoch 9/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1409 - Dense3_peak_number_loss: 0.0037 - total_center2_loss: 0.0992 - total_width2_loss: 0.0223 - total_amp2_loss: 0.0158 - Dense3_peak_number_mae: 0.0229 - total_center2_mae: 0.1564 - total_width2_mae: 0.0940 - total_amp2_mae: 0.0839 - val_loss: 0.1400 - val_Dense3_peak_number_loss: 0.0033 - val_total_center2_loss: 0.0982 - val_total_width2_loss: 0.0223 - val_total_amp2_loss: 0.0162 - val_Dense3_peak_number_mae: 0.0181 - val_total_center2_mae: 0.1283 - val_total_width2_mae: 0.0936 - val_total_amp2_mae: 0.0872
# Epoch 10/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1344 - Dense3_peak_number_loss: 0.0034 - total_center2_loss: 0.0944 - total_width2_loss: 0.0213 - total_amp2_loss: 0.0153 - Dense3_peak_number_mae: 0.0216 - total_center2_mae: 0.1538 - total_width2_mae: 0.0916 - total_amp2_mae: 0.0824 - val_loss: 0.1383 - val_Dense3_peak_number_loss: 0.0038 - val_total_center2_loss: 0.0984 - val_total_width2_loss: 0.0213 - val_total_amp2_loss: 0.0148 - val_Dense3_peak_number_mae: 0.0200 - val_total_center2_mae: 0.1369 - val_total_width2_mae: 0.0956 - val_total_amp2_mae: 0.0787
# Epoch 11/50
# 1800/1800 [==============================] - 92s 51ms/step - loss: 0.1268 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0885 - total_width2_loss: 0.0205 - total_amp2_loss: 0.0147 - Dense3_peak_number_mae: 0.0203 - total_center2_mae: 0.1499 - total_width2_mae: 0.0893 - total_amp2_mae: 0.0803 - val_loss: 0.1284 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0936 - val_total_width2_loss: 0.0182 - val_total_amp2_loss: 0.0147 - val_Dense3_peak_number_mae: 0.0162 - val_total_center2_mae: 0.1798 - val_total_width2_mae: 0.0815 - val_total_amp2_mae: 0.0804
# Epoch 12/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1235 - Dense3_peak_number_loss: 0.0030 - total_center2_loss: 0.0860 - total_width2_loss: 0.0200 - total_amp2_loss: 0.0144 - Dense3_peak_number_mae: 0.0197 - total_center2_mae: 0.1491 - total_width2_mae: 0.0883 - total_amp2_mae: 0.0793 - val_loss: 0.1084 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0731 - val_total_width2_loss: 0.0187 - val_total_amp2_loss: 0.0146 - val_Dense3_peak_number_mae: 0.0120 - val_total_center2_mae: 0.1131 - val_total_width2_mae: 0.0856 - val_total_amp2_mae: 0.0833
# Epoch 13/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1179 - Dense3_peak_number_loss: 0.0028 - total_center2_loss: 0.0819 - total_width2_loss: 0.0192 - total_amp2_loss: 0.0140 - Dense3_peak_number_mae: 0.0181 - total_center2_mae: 0.1458 - total_width2_mae: 0.0862 - total_amp2_mae: 0.0778 - val_loss: 0.1312 - val_Dense3_peak_number_loss: 0.0025 - val_total_center2_loss: 0.0937 - val_total_width2_loss: 0.0196 - val_total_amp2_loss: 0.0155 - val_Dense3_peak_number_mae: 0.0174 - val_total_center2_mae: 0.1713 - val_total_width2_mae: 0.0874 - val_total_amp2_mae: 0.0851
# Epoch 14/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1129 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0779 - total_width2_loss: 0.0187 - total_amp2_loss: 0.0137 - Dense3_peak_number_mae: 0.0179 - total_center2_mae: 0.1427 - total_width2_mae: 0.0850 - total_amp2_mae: 0.0766 - val_loss: 0.1201 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0846 - val_total_width2_loss: 0.0194 - val_total_amp2_loss: 0.0132 - val_Dense3_peak_number_mae: 0.0130 - val_total_center2_mae: 0.1264 - val_total_width2_mae: 0.0870 - val_total_amp2_mae: 0.0785
# Epoch 15/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1085 - Dense3_peak_number_loss: 0.0025 - total_center2_loss: 0.0745 - total_width2_loss: 0.0181 - total_amp2_loss: 0.0133 - Dense3_peak_number_mae: 0.0168 - total_center2_mae: 0.1393 - total_width2_mae: 0.0832 - total_amp2_mae: 0.0751 - val_loss: 0.1427 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.1041 - val_total_width2_loss: 0.0217 - val_total_amp2_loss: 0.0146 - val_Dense3_peak_number_mae: 0.0168 - val_total_center2_mae: 0.1575 - val_total_width2_mae: 0.0951 - val_total_amp2_mae: 0.0794
# Epoch 16/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1041 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0709 - total_width2_loss: 0.0178 - total_amp2_loss: 0.0132 - Dense3_peak_number_mae: 0.0163 - total_center2_mae: 0.1382 - total_width2_mae: 0.0826 - total_amp2_mae: 0.0747 - val_loss: 0.1112 - val_Dense3_peak_number_loss: 0.0030 - val_total_center2_loss: 0.0756 - val_total_width2_loss: 0.0186 - val_total_amp2_loss: 0.0141 - val_Dense3_peak_number_mae: 0.0341 - val_total_center2_mae: 0.1357 - val_total_width2_mae: 0.0855 - val_total_amp2_mae: 0.0796
# Epoch 17/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1020 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0696 - total_width2_loss: 0.0173 - total_amp2_loss: 0.0128 - Dense3_peak_number_mae: 0.0161 - total_center2_mae: 0.1372 - total_width2_mae: 0.0814 - total_amp2_mae: 0.0735 - val_loss: 0.1386 - val_Dense3_peak_number_loss: 0.0044 - val_total_center2_loss: 0.0967 - val_total_width2_loss: 0.0235 - val_total_amp2_loss: 0.0140 - val_Dense3_peak_number_mae: 0.0273 - val_total_center2_mae: 0.1612 - val_total_width2_mae: 0.0984 - val_total_amp2_mae: 0.0802
# Epoch 18/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0986 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0666 - total_width2_loss: 0.0172 - total_amp2_loss: 0.0127 - Dense3_peak_number_mae: 0.0152 - total_center2_mae: 0.1355 - total_width2_mae: 0.0811 - total_amp2_mae: 0.0730 - val_loss: 0.1129 - val_Dense3_peak_number_loss: 0.0025 - val_total_center2_loss: 0.0779 - val_total_width2_loss: 0.0197 - val_total_amp2_loss: 0.0129 - val_Dense3_peak_number_mae: 0.0137 - val_total_center2_mae: 0.1142 - val_total_width2_mae: 0.0903 - val_total_amp2_mae: 0.0728
# Epoch 19/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0974 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0658 - total_width2_loss: 0.0169 - total_amp2_loss: 0.0126 - Dense3_peak_number_mae: 0.0154 - total_center2_mae: 0.1348 - total_width2_mae: 0.0800 - total_amp2_mae: 0.0723 - val_loss: 0.1182 - val_Dense3_peak_number_loss: 0.0027 - val_total_center2_loss: 0.0840 - val_total_width2_loss: 0.0189 - val_total_amp2_loss: 0.0125 - val_Dense3_peak_number_mae: 0.0190 - val_total_center2_mae: 0.1225 - val_total_width2_mae: 0.0859 - val_total_amp2_mae: 0.0722
# Epoch 20/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0950 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0640 - total_width2_loss: 0.0166 - total_amp2_loss: 0.0125 - Dense3_peak_number_mae: 0.0146 - total_center2_mae: 0.1339 - total_width2_mae: 0.0794 - total_amp2_mae: 0.0719 - val_loss: 0.0930 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0639 - val_total_width2_loss: 0.0152 - val_total_amp2_loss: 0.0121 - val_Dense3_peak_number_mae: 0.0171 - val_total_center2_mae: 0.1084 - val_total_width2_mae: 0.0753 - val_total_amp2_mae: 0.0711
# Epoch 21/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0929 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0621 - total_width2_loss: 0.0165 - total_amp2_loss: 0.0124 - Dense3_peak_number_mae: 0.0145 - total_center2_mae: 0.1318 - total_width2_mae: 0.0791 - total_amp2_mae: 0.0716 - val_loss: 0.1148 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0827 - val_total_width2_loss: 0.0173 - val_total_amp2_loss: 0.0132 - val_Dense3_peak_number_mae: 0.0085 - val_total_center2_mae: 0.1200 - val_total_width2_mae: 0.0815 - val_total_amp2_mae: 0.0765
# Epoch 22/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0888 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0590 - total_width2_loss: 0.0160 - total_amp2_loss: 0.0121 - Dense3_peak_number_mae: 0.0138 - total_center2_mae: 0.1301 - total_width2_mae: 0.0777 - total_amp2_mae: 0.0706 - val_loss: 0.1169 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0679 - val_total_width2_loss: 0.0179 - val_total_amp2_loss: 0.0297 - val_Dense3_peak_number_mae: 0.0071 - val_total_center2_mae: 0.1220 - val_total_width2_mae: 0.0885 - val_total_amp2_mae: 0.1266
# Epoch 23/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0860 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0568 - total_width2_loss: 0.0157 - total_amp2_loss: 0.0119 - Dense3_peak_number_mae: 0.0137 - total_center2_mae: 0.1278 - total_width2_mae: 0.0768 - total_amp2_mae: 0.0698 - val_loss: 0.1116 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0813 - val_total_width2_loss: 0.0160 - val_total_amp2_loss: 0.0129 - val_Dense3_peak_number_mae: 0.0084 - val_total_center2_mae: 0.1434 - val_total_width2_mae: 0.0796 - val_total_amp2_mae: 0.0723
# Epoch 24/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0923 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0612 - total_width2_loss: 0.0165 - total_amp2_loss: 0.0125 - Dense3_peak_number_mae: 0.0140 - total_center2_mae: 0.1322 - total_width2_mae: 0.0791 - total_amp2_mae: 0.0720 - val_loss: 0.1153 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0843 - val_total_width2_loss: 0.0166 - val_total_amp2_loss: 0.0126 - val_Dense3_peak_number_mae: 0.0130 - val_total_center2_mae: 0.1504 - val_total_width2_mae: 0.0776 - val_total_amp2_mae: 0.0718
# Epoch 25/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0837 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0548 - total_width2_loss: 0.0156 - total_amp2_loss: 0.0117 - Dense3_peak_number_mae: 0.0124 - total_center2_mae: 0.1277 - total_width2_mae: 0.0769 - total_amp2_mae: 0.0689 - val_loss: 0.1315 - val_Dense3_peak_number_loss: 0.0037 - val_total_center2_loss: 0.1000 - val_total_width2_loss: 0.0163 - val_total_amp2_loss: 0.0115 - val_Dense3_peak_number_mae: 0.0150 - val_total_center2_mae: 0.1602 - val_total_width2_mae: 0.0793 - val_total_amp2_mae: 0.0672
# Epoch 26/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0827 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0542 - total_width2_loss: 0.0152 - total_amp2_loss: 0.0117 - Dense3_peak_number_mae: 0.0124 - total_center2_mae: 0.1268 - total_width2_mae: 0.0755 - total_amp2_mae: 0.0688 - val_loss: 0.1276 - val_Dense3_peak_number_loss: 0.0036 - val_total_center2_loss: 0.0927 - val_total_width2_loss: 0.0184 - val_total_amp2_loss: 0.0130 - val_Dense3_peak_number_mae: 0.0129 - val_total_center2_mae: 0.1133 - val_total_width2_mae: 0.0851 - val_total_amp2_mae: 0.0746
# Epoch 27/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0778 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0503 - total_width2_loss: 0.0148 - total_amp2_loss: 0.0114 - Dense3_peak_number_mae: 0.0115 - total_center2_mae: 0.1228 - total_width2_mae: 0.0744 - total_amp2_mae: 0.0676 - val_loss: 0.1141 - val_Dense3_peak_number_loss: 0.0032 - val_total_center2_loss: 0.0820 - val_total_width2_loss: 0.0161 - val_total_amp2_loss: 0.0129 - val_Dense3_peak_number_mae: 0.0106 - val_total_center2_mae: 0.1221 - val_total_width2_mae: 0.0756 - val_total_amp2_mae: 0.0727
# Epoch 28/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0790 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0511 - total_width2_loss: 0.0150 - total_amp2_loss: 0.0114 - Dense3_peak_number_mae: 0.0119 - total_center2_mae: 0.1243 - total_width2_mae: 0.0749 - total_amp2_mae: 0.0678 - val_loss: 0.0971 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0701 - val_total_width2_loss: 0.0144 - val_total_amp2_loss: 0.0111 - val_Dense3_peak_number_mae: 0.0127 - val_total_center2_mae: 0.1137 - val_total_width2_mae: 0.0738 - val_total_amp2_mae: 0.0670
# Epoch 29/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0776 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0503 - total_width2_loss: 0.0146 - total_amp2_loss: 0.0113 - Dense3_peak_number_mae: 0.0115 - total_center2_mae: 0.1242 - total_width2_mae: 0.0739 - total_amp2_mae: 0.0674 - val_loss: 0.1478 - val_Dense3_peak_number_loss: 0.0054 - val_total_center2_loss: 0.1083 - val_total_width2_loss: 0.0202 - val_total_amp2_loss: 0.0139 - val_Dense3_peak_number_mae: 0.0279 - val_total_center2_mae: 0.1604 - val_total_width2_mae: 0.0891 - val_total_amp2_mae: 0.0792
# Epoch 30/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0766 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0496 - total_width2_loss: 0.0144 - total_amp2_loss: 0.0112 - Dense3_peak_number_mae: 0.0112 - total_center2_mae: 0.1233 - total_width2_mae: 0.0734 - total_amp2_mae: 0.0670 - val_loss: 0.1086 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0776 - val_total_width2_loss: 0.0162 - val_total_amp2_loss: 0.0129 - val_Dense3_peak_number_mae: 0.0095 - val_total_center2_mae: 0.1305 - val_total_width2_mae: 0.0769 - val_total_amp2_mae: 0.0744
# Epoch 31/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0739 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0474 - total_width2_loss: 0.0142 - total_amp2_loss: 0.0110 - Dense3_peak_number_mae: 0.0110 - total_center2_mae: 0.1216 - total_width2_mae: 0.0727 - total_amp2_mae: 0.0663 - val_loss: 0.1054 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0780 - val_total_width2_loss: 0.0143 - val_total_amp2_loss: 0.0112 - val_Dense3_peak_number_mae: 0.0085 - val_total_center2_mae: 0.1159 - val_total_width2_mae: 0.0718 - val_total_amp2_mae: 0.0664
# Epoch 32/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0739 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0474 - total_width2_loss: 0.0142 - total_amp2_loss: 0.0110 - Dense3_peak_number_mae: 0.0111 - total_center2_mae: 0.1223 - total_width2_mae: 0.0727 - total_amp2_mae: 0.0664 - val_loss: 0.0904 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0636 - val_total_width2_loss: 0.0149 - val_total_amp2_loss: 0.0106 - val_Dense3_peak_number_mae: 0.0080 - val_total_center2_mae: 0.1137 - val_total_width2_mae: 0.0737 - val_total_amp2_mae: 0.0633
# Epoch 33/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0725 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0463 - total_width2_loss: 0.0140 - total_amp2_loss: 0.0109 - Dense3_peak_number_mae: 0.0109 - total_center2_mae: 0.1214 - total_width2_mae: 0.0724 - total_amp2_mae: 0.0659 - val_loss: 0.0922 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0659 - val_total_width2_loss: 0.0141 - val_total_amp2_loss: 0.0108 - val_Dense3_peak_number_mae: 0.0058 - val_total_center2_mae: 0.1030 - val_total_width2_mae: 0.0727 - val_total_amp2_mae: 0.0642
# Epoch 34/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0716 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0454 - total_width2_loss: 0.0138 - total_amp2_loss: 0.0112 - Dense3_peak_number_mae: 0.0103 - total_center2_mae: 0.1203 - total_width2_mae: 0.0716 - total_amp2_mae: 0.0668 - val_loss: 0.0901 - val_Dense3_peak_number_loss: 0.0012 - val_total_center2_loss: 0.0628 - val_total_width2_loss: 0.0139 - val_total_amp2_loss: 0.0123 - val_Dense3_peak_number_mae: 0.0067 - val_total_center2_mae: 0.1051 - val_total_width2_mae: 0.0704 - val_total_amp2_mae: 0.0732
# Epoch 35/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0706 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0446 - total_width2_loss: 0.0139 - total_amp2_loss: 0.0109 - Dense3_peak_number_mae: 0.0102 - total_center2_mae: 0.1200 - total_width2_mae: 0.0719 - total_amp2_mae: 0.0658 - val_loss: 0.1076 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0792 - val_total_width2_loss: 0.0154 - val_total_amp2_loss: 0.0116 - val_Dense3_peak_number_mae: 0.0092 - val_total_center2_mae: 0.1447 - val_total_width2_mae: 0.0785 - val_total_amp2_mae: 0.0706
# Epoch 36/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0718 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0452 - total_width2_loss: 0.0144 - total_amp2_loss: 0.0110 - Dense3_peak_number_mae: 0.0103 - total_center2_mae: 0.1205 - total_width2_mae: 0.0734 - total_amp2_mae: 0.0661 - val_loss: 0.0967 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0683 - val_total_width2_loss: 0.0150 - val_total_amp2_loss: 0.0122 - val_Dense3_peak_number_mae: 0.0103 - val_total_center2_mae: 0.1115 - val_total_width2_mae: 0.0766 - val_total_amp2_mae: 0.0708
# Epoch 37/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0696 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0439 - total_width2_loss: 0.0137 - total_amp2_loss: 0.0108 - Dense3_peak_number_mae: 0.0103 - total_center2_mae: 0.1190 - total_width2_mae: 0.0712 - total_amp2_mae: 0.0652 - val_loss: 0.0960 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0704 - val_total_width2_loss: 0.0135 - val_total_amp2_loss: 0.0108 - val_Dense3_peak_number_mae: 0.0093 - val_total_center2_mae: 0.1181 - val_total_width2_mae: 0.0690 - val_total_amp2_mae: 0.0669
# Epoch 38/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0676 - Dense3_peak_number_loss: 0.0011 - total_center2_loss: 0.0424 - total_width2_loss: 0.0135 - total_amp2_loss: 0.0106 - Dense3_peak_number_mae: 0.0097 - total_center2_mae: 0.1184 - total_width2_mae: 0.0706 - total_amp2_mae: 0.0645 - val_loss: 0.0964 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0688 - val_total_width2_loss: 0.0149 - val_total_amp2_loss: 0.0112 - val_Dense3_peak_number_mae: 0.0076 - val_total_center2_mae: 0.1128 - val_total_width2_mae: 0.0733 - val_total_amp2_mae: 0.0681
# Epoch 39/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0667 - Dense3_peak_number_loss: 0.0010 - total_center2_loss: 0.0416 - total_width2_loss: 0.0135 - total_amp2_loss: 0.0105 - Dense3_peak_number_mae: 0.0084 - total_center2_mae: 0.1185 - total_width2_mae: 0.0705 - total_amp2_mae: 0.0642 - val_loss: 0.0906 - val_Dense3_peak_number_loss: 0.0012 - val_total_center2_loss: 0.0650 - val_total_width2_loss: 0.0137 - val_total_amp2_loss: 0.0106 - val_Dense3_peak_number_mae: 0.0076 - val_total_center2_mae: 0.1078 - val_total_width2_mae: 0.0699 - val_total_amp2_mae: 0.0637
# Epoch 40/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0655 - Dense3_peak_number_loss: 0.0010 - total_center2_loss: 0.0408 - total_width2_loss: 0.0132 - total_amp2_loss: 0.0105 - Dense3_peak_number_mae: 0.0091 - total_center2_mae: 0.1167 - total_width2_mae: 0.0697 - total_amp2_mae: 0.0640 - val_loss: 0.0898 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0638 - val_total_width2_loss: 0.0141 - val_total_amp2_loss: 0.0105 - val_Dense3_peak_number_mae: 0.0073 - val_total_center2_mae: 0.1047 - val_total_width2_mae: 0.0708 - val_total_amp2_mae: 0.0628
# Epoch 41/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0675 - Dense3_peak_number_loss: 0.0011 - total_center2_loss: 0.0423 - total_width2_loss: 0.0134 - total_amp2_loss: 0.0107 - Dense3_peak_number_mae: 0.0094 - total_center2_mae: 0.1187 - total_width2_mae: 0.0705 - total_amp2_mae: 0.0648 - val_loss: 0.1027 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0722 - val_total_width2_loss: 0.0148 - val_total_amp2_loss: 0.0136 - val_Dense3_peak_number_mae: 0.0074 - val_total_center2_mae: 0.1038 - val_total_width2_mae: 0.0719 - val_total_amp2_mae: 0.0800
# Epoch 42/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0645 - Dense3_peak_number_loss: 9.7539e-04 - total_center2_loss: 0.0399 - total_width2_loss: 0.0132 - total_amp2_loss: 0.0105 - Dense3_peak_number_mae: 0.0080 - total_center2_mae: 0.1175 - total_width2_mae: 0.0696 - total_amp2_mae: 0.0641 - val_loss: 0.0897 - val_Dense3_peak_number_loss: 0.0012 - val_total_center2_loss: 0.0636 - val_total_width2_loss: 0.0137 - val_total_amp2_loss: 0.0112 - val_Dense3_peak_number_mae: 0.0098 - val_total_center2_mae: 0.0981 - val_total_width2_mae: 0.0689 - val_total_amp2_mae: 0.0669
# Epoch 43/50
#   63/1800 [>.............................] - ETA: 1:27 - loss: 0.0559 - Dense3_peak_number_loss: 5.3029e-04 - total_center2_loss: 0.0335 - total_width2_loss: 0.0122 - total_amp2_loss: 0.0097 - Dense3_peak_number_mae: 0.0061 - total_center2_mae: 0.1166 - total_width2_mae: 0.0674 - total_amp2_mae: 0.0607
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0615 - Dense3_peak_number_loss: 9.4129e-04 - total_center2_loss: 0.0378 - total_width2_loss: 0.0127 - total_amp2_loss: 0.0100 - Dense3_peak_number_mae: 0.0072 - total_center2_mae: 0.1151 - total_width2_mae: 0.0684 - total_amp2_mae: 0.0623 - val_loss: 0.0886 - val_Dense3_peak_number_loss: 0.0011 - val_total_center2_loss: 0.0647 - val_total_width2_loss: 0.0128 - val_total_amp2_loss: 0.0100 - val_Dense3_peak_number_mae: 0.0036 - val_total_center2_mae: 0.1130 - val_total_width2_mae: 0.0667 - val_total_amp2_mae: 0.0606

# %%
test_graph.shape
# Out:
# (20000, 401, 1)

# %%
for key in models.history.keys():
    print(key)
# Out:
# loss
# Dense3_peak_number_loss
# total_center2_loss
# total_width2_loss
# total_amp2_loss
# Dense3_peak_number_mae
# total_center2_mae
# total_width2_mae
# total_amp2_mae
# val_loss
# val_Dense3_peak_number_loss
# val_total_center2_loss
# val_total_width2_loss
# val_total_amp2_loss
# val_Dense3_peak_number_mae
# val_total_center2_mae
# val_total_width2_mae
# val_total_amp2_mae

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp2_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (20000, 1)
# (20000, 3)
# (20000, 3)
# (20000, 3)

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,color='black')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'blue')
    plt.grid(True)
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
# Out:
# real_center   [ 0.          5.71315308 11.91923309]
# predict_center [ 0.012395218 5.735899 11.929952 ]
# ---------------
# real_width    [0.         0.84337558 1.79121459]
# predict_center [ 0.012596995 0.8812345 1.8515434 ]
# ---------------
# real_amp      [0.         0.88023975 1.04841723]
# predict_center [ 0.011880346 0.92024374 1.0362998 ]
# real_center   [ 0.          6.39994478 12.93951819]
# predict_center [ -0.00946717 6.4470186 13.074811 ]
# ---------------
# real_width    [0.         1.65652237 0.93438808]
# predict_center [ -0.008123517 1.727633 0.95595086 ]
# ---------------
# real_amp      [0.         0.99348086 0.9478093 ]
# predict_center [ 0.0034883171 1.0142882 0.9840314 ]
# real_center   [ 3.23631434  6.18606995 12.52827948]
# predict_center [ 3.2871094 6.5940237 12.654966 ]
# ---------------
# real_width    [1.66278035 1.68069287 1.00126402]
# predict_center [ 1.6653562 1.6469675 1.0396781 ]
# ---------------
# real_amp      [0.17531519 0.19742663 0.9243484 ]
# predict_center [ 0.15769093 0.21691911 0.85671806 ]
# real_center   [ 0.          3.86715569 10.86221601]
# predict_center [ -0.0022791475 3.99853 11.0344305 ]
# ---------------
# real_width    [0.         0.59165533 0.40581259]
# predict_center [ 0.00012129545 0.7290324 0.3529169 ]
# ---------------
# real_amp      [0.         0.51955378 0.53934786]
# predict_center [ 0.006077394 0.574648 0.6161661 ]
# real_center   [ 0.          9.45233636 12.62868582]
# predict_center [ -0.004301831 9.573843 12.698401 ]
# ---------------
# real_width    [0.         1.44668865 1.87998592]
# predict_center [ -0.0044828653 1.4156847 1.8327463 ]
# ---------------
# real_amp      [0.         0.91245941 0.36050666]
# predict_center [ 0.0067963004 0.92116797 0.35891366 ]
# real_center   [0.         2.00332775 6.03248714]
# predict_center [ -0.007858768 2.224398 6.218312 ]
# ---------------
# real_width    [0.         0.59737084 0.7272154 ]
# predict_center [ 0.010037914 0.6183795 0.6885259 ]
# ---------------
# real_amp      [0.         0.90353073 0.66262424]
# predict_center [ 0.0134784505 0.9502299 0.5947353 ]
# real_center   [ 0.         11.42268043 12.25882526]
# predict_center [ 0.01634653 11.5721245 12.555871 ]
# ---------------
# real_width    [0.         0.75334379 1.47571775]
# predict_center [ 0.008963048 0.7254318 1.4727931 ]
# ---------------
# real_amp      [0.         0.59638167 0.17278906]
# predict_center [ 0.0054804236 0.62168413 0.15936601 ]
# real_center   [ 2.57538501  2.73040878 12.45116549]
# predict_center [ 2.3715644 2.7620552 12.573415 ]
# ---------------
# real_width    [0.41405293 0.60919744 1.12779081]
# predict_center [ 0.5891839 0.66688144 1.1699839 ]
# ---------------
# real_amp      [0.5085511  0.80758984 0.70893355]
# predict_center [ 0.7206814 0.5951123 0.61222255 ]
# real_center   [ 2.9017155   7.54113871 10.03829508]
# predict_center [ 2.9726114 7.782761 10.043646 ]
# ---------------
# real_width    [0.3609779 1.5868491 1.5857514]
# predict_center [ 0.48402238 1.4573193 1.6142364 ]
# ---------------
# real_amp      [0.9967733  0.57811673 0.29408781]
# predict_center [ 1.0862354 0.7243969 0.16800126 ]
# real_center   [5.70187413 6.47325447 7.95269075]
# predict_center [ 5.6930676 6.538943 7.9572215 ]
# ---------------
# real_width    [0.35270478 1.15793397 1.67777024]
# predict_center [ 0.45647556 0.9924153 1.5759776 ]
# ---------------
# real_amp      [0.28978847 0.72433166 0.41654231]
# predict_center [ 0.32387322 0.5318436 0.34944993 ]
# real_center   [ 0.          4.21687094 12.34120659]
# predict_center [ -0.010567114 4.3876834 12.433169 ]
# ---------------
# real_width    [0.         0.36773928 0.81390437]
# predict_center [ 0.0017264485 0.4119388 0.7789213 ]
# ---------------
# real_amp      [0.         0.78705796 0.79347587]
# predict_center [ 0.0014666766 0.87708604 0.60849416 ]
# real_center   [ 7.64690374  7.88672447 11.75998207]
# predict_center [ 7.4631963 8.110536 12.037657 ]
# ---------------
# real_width    [1.57721792 0.35065511 1.76987164]
# predict_center [ 1.451628 0.38140595 1.8365057 ]
# ---------------
# real_amp      [0.15874303 0.52349397 0.94926077]
# predict_center [ 0.20200446 0.43858418 0.8603506 ]
# real_center   [2.97550177 6.17211837 8.66438667]
# predict_center [ 3.1138346 6.3838553 8.73014 ]
# ---------------
# real_width    [1.63453699 0.70265382 0.91474209]
# predict_center [ 1.7349131 0.765983 0.9048267 ]
# ---------------
# real_amp      [0.76022675 1.01366238 1.09569614]
# predict_center [ 0.7341423 1.0411241 1.0226247 ]
# real_center   [ 0.          9.77946893 10.97017916]
# predict_center [ -0.023288533 9.880243 11.090329 ]
# ---------------
# real_width    [0.         0.39829634 1.05510464]
# predict_center [ -0.0033963323 0.4345207 1.067404 ]
# ---------------
# real_amp      [0.         1.01298834 0.78358955]
# predict_center [ 0.00911288 1.1107754 0.6735832 ]
# real_center   [ 3.8569353   4.12070216 12.11402843]
# predict_center [ 3.8607953 4.1865964 12.162154 ]
# ---------------
# real_width    [0.4981711  0.58429175 1.10961953]
# predict_center [ 0.52190566 0.530903 1.139909 ]
# ---------------
# real_amp      [0.83741193 0.49685655 0.19540706]
# predict_center [ 0.6634525 0.5108557 0.15618454 ]
# real_center   [2.4287244  8.00130851 8.73111697]
# predict_center [ 2.5891438 8.095703 8.872891 ]
# ---------------
# real_width    [1.30205305 0.73029477 1.26629847]
# predict_center [ 1.2205226 0.8398386 1.0774229 ]
# ---------------
# real_amp      [0.414536   0.85436318 0.82462015]
# predict_center [ 0.33172733 0.8414937 0.7759248 ]
# real_center   [0.         4.6604788  7.58096173]
# predict_center [ -0.028449789 4.7782774 7.556539 ]
# ---------------
# real_width    [0.         0.74087437 0.40953535]
# predict_center [ 0.0012335777 0.7818849 0.42026678 ]
# ---------------
# real_amp      [0.         1.0195198  1.04926695]
# predict_center [ 0.022762954 1.0700167 1.0263888 ]
# real_center   [ 0.          4.61549707 12.73793585]
# predict_center [ -0.019591615 4.6945214 12.901546 ]
# ---------------
# real_width    [0.         1.11693444 1.17194019]
# predict_center [ -0.0019895434 1.0941097 1.1480575 ]
# ---------------
# real_amp      [0.         0.53062024 0.33579517]
# predict_center [ 0.0017416626 0.58921105 0.32695824 ]
# real_center   [ 5.12023748  5.84530511 10.99748078]
# predict_center [ 5.0843287 5.971868 11.024997 ]
# ---------------
# real_width    [1.34057725 0.74437628 1.38113455]
# predict_center [ 1.5428188 0.71389663 1.5601015 ]
# ---------------
# real_amp      [0.84935913 0.70472954 0.46106577]
# predict_center [ 0.90189165 0.69313043 0.5341017 ]
# real_center   [ 8.0085005   8.9801749  11.72798113]
# predict_center [ 7.856312 9.054348 11.925439 ]
# ---------------
# real_width    [1.09531881 1.22843115 0.76551006]
# predict_center [ 1.0509377 1.6002557 0.6992115 ]
# ---------------
# real_amp      [0.71929417 0.23130514 0.83006498]
# predict_center [ 0.6810407 0.17556226 0.76648766 ]

# %%
plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")

# 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("P3HT Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[1.9999511]], dtype=float32), array([[ 0.0664777, 10.30711  , 11.343616 ]], dtype=float32), array([[-0.01661795,  1.6444744 ,  0.6686214 ]], dtype=float32), array([[0.01546729, 0.25238392, 0.85145146]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
# Out:
# Text(0.5, 1.0, 'Network fitting vs real XPS graph')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
# Out:
# Text(0.5, 1.0, 'Predict_peak1 vs Xps_peak1')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak2 vs Xps_peak2')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak3 vs Xps_peak3')

# %%
new_predict[1][0],new_predict[2][0],new_predict[3][0]
# Out:
# (0.0664777, -0.016617954, 0.015467286)

# %%
new_predict[0][0]
# Out:
# 1.9999511

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[1.9980063]], dtype=float32), array([[0.05712387, 7.551557  , 8.2900095 ]], dtype=float32), array([[-0.00732465,  0.6648303 ,  0.6704347 ]], dtype=float32), array([[0.0223057 , 0.48378295, 1.0945596 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')

error_peak_number_total=0
for i in range(test_peak_number.shape[0]):
    error_peak_number_total = error_peak_number_total + (abs(prediction[0][i]-test_peak_number[i]))
print('error_peak_number_total = ',error_peak_number_total)
error_peak_number = error_peak_number_total/test_peak_number.shape[0]
print('error_peak_number =  ',error_peak_number)
print('\n')
# Out:
# error_center_total =  [1185.54550986 3648.00523253 2049.03822916]
# error_center =   [0.05927728 0.18240026 0.10245191]
#
#
# error_width_total =  [ 960.87754465 1729.17414384 1298.86591636]
# error_width =   [0.04804388 0.08645871 0.0649433 ]
#
#
# error_amp_total =  [ 844.14479263 1480.1560623  1296.94163131]
# error_amp =   [0.04220724 0.0740078  0.06484708]
#
#
# error_peak_number_total =  [72.98618]
# error_peak_number =   [0.00364931]

# %%
# 바꾼거

# total_centet,width,amp를 2층으로 하고 마지막에 batchnormalization 넣어봣음

# %%
# 수정할거
# 1.잔차연결
# 2. 데이터비율
# 3. 데이터 양

# %%
# 확인할거
# 효과 없으면 total_ center,width,amp 한번 줄이고 다시 ㄱㄱ

# %%
#느낀점

# 확실히 total쪽은 1~2개가 적전성
# total_width,amp는 효과가 0.1정도 나아졌고 center는 그대로..
# 이젠 total_center,width,amp를 한층더 줄여보자
