# %%
# %ls
# Out:
# '2,3peak mix.ipynb'
# '5peak 3 para when it worksss.ipynb'
# 'Fitting_with_noise (1).ipynb'
#  ITO_O1s_bg.txt
#  ITO_O1s_exp.txt
#  ITO_O1s_fitting.txt
#  ITO_O1s_p1.txt
#  ITO_O1s_p2.txt
#  ITO_O1s_p3.txt
#  P3HT_S2p_bg.txt
#  P3HT_S2p_exp.txt
#  P3HT_S2p_fitting.txt
#  P3HT_S2p_p1.txt
#  P3HT_S2p_p2.txt
#  PeakDetection.ipynb
#  Untitled.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  amp.csv
#  amp2.csv
#  center.csv
#  center2.csv
#  graph.csv
#  graph2.csv
#  labels.png
#  model.png
#  model_shapes.png
#  peak_number.csv
#  peak_number2.csv
#  width.csv
#  width2.csv
# '논문 수정.ipynb'
# '데이터 얻기.ipynb'
# '저장된 데이터로 학습하기.ipynb'
# '저장된 데이터로 학습하기10.ipynb'
# '저장된 데이터로 학습하기11.ipynb'
# '저장된 데이터로 학습하기12.ipynb'
# '저장된 데이터로 학습하기13.ipynb'
# '저장된 데이터로 학습하기14-model12(조언)가지고 newdata로 xps peak_number예측하기.ipynb'
# '저장된 데이터로 학습하기2.ipynb'
# '저장된 데이터로 학습하기3.ipynb'
# '저장된 데이터로 학습하기4.ipynb'
# '저장된 데이터로 학습하기5.ipynb'
# '저장된 데이터로 학습하기6.ipynb'
# '저장된 데이터로 학습하기7.ipynb'
# '저장된 데이터로 학습하기8.ipynb'
# '저장된 데이터로 학습하기9.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph2.csv').values[:,1:]
center= pd.read_csv('center2.csv').values[:,1:]
width= pd.read_csv('width2.csv').values[:,1:]
amp= pd.read_csv('amp2.csv').values[:,1:]
peak_number= pd.read_csv('peak_number2.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(2000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 7.23628242  9.1031437  10.57898085]
#  [ 0.          2.43554163  9.12126038]
#  [ 3.40748239  9.45706905 11.61820534]
#  [ 3.1754511   4.79469948  6.3127261 ]
#  [ 5.35551581  9.93852836 11.03579298]
#  [ 3.55326122  9.87372029 11.51668281]
#  [ 7.99388953  8.99423136  9.12088353]
#  [ 3.65355481  8.29226995 11.5034708 ]
#  [ 0.         11.19742168 12.61584358]
#  [ 2.87038552  6.34178783  6.6609155 ]]
# [[1.07870283 1.26852044 1.8868038 ]
#  [0.         0.39788549 0.54178743]
#  [0.49049834 0.32499028 1.68682634]
#  [1.34457341 1.67890077 1.87168139]
#  [1.65364093 1.58038344 1.06945469]
#  [0.60796769 1.5724838  0.79368063]
#  [0.7480385  1.3894889  0.84059086]
#  [0.39247518 1.60015601 1.05001412]
#  [0.         0.49510404 0.3439332 ]
#  [1.33089568 1.41367593 1.31920054]]
# [[0.10104416 0.24668157 0.46341479]
#  [0.         0.14188493 0.73247317]
#  [0.30481886 0.78295051 0.54565806]
#  [0.37823352 0.35937792 0.69279378]
#  [0.69623324 0.74397698 1.06301003]
#  [0.44158653 0.74610741 0.81255582]
#  [0.38347372 0.78058774 0.80978129]
#  [0.29559253 0.6722302  0.99848908]
#  [0.         0.16135274 0.47370952]
#  [0.94416374 0.56895351 0.94951967]]
# [3 2 3 3 3 3 3 3 2 3]
# (2000000, 3)
# (2000000, 3)
# (2000000, 3)
# (2000000,)
# (2000000, 401)
# [[ 0.02047835 -0.01728569 -0.03585374 ...  0.03232607 -0.01245597
#   -0.00105879]
#  [ 0.02829299 -0.00499789  0.01395422 ... -0.02841739 -0.01816228
#    0.01110934]
#  [ 0.03922567 -0.00338767  0.05301221 ... -0.04365896 -0.00383379
#    0.05729541]
#  ...
#  [-0.0036027   0.0272945   0.0217847  ... -0.00091456  0.01327614
#    0.0384471 ]
#  [-0.00172565  0.07166732  0.07645653 ... -0.0024148   0.02542897
#    0.04014354]
#  [ 0.00809359  0.00272062 -0.0238266  ... -0.01498386 -0.02516971
#    0.00063031]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
#90:9:1
data_number=1000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (1800000, 401) (180000, 401) (20000, 401)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000,) (180000,) (20000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (1800000, 401, 1)
# (180000, 401, 1)
# (20000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
input_data = Input(shape = (len(x), 1))

t = layers.Conv1D(32,100,strides=5,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(64,4,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,4,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(192,2,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)


Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(1, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(200, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(100, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(200,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(100,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(200,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(100,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
center_Batchnormalization  = BatchNormalization()(total_center1)
# total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center2 = Dense(3, activation = 'linear',name = 'total_center2')(center_Batchnormalization)


width_merge = concatenate([Dense3_peak_number,Dense3_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
width_Batchnormalization  = BatchNormalization()(total_width1)
# total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width2= Dense(3, activation = 'linear',name = 'total_width2')(width_Batchnormalization)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
amp_Batchnormalization  = BatchNormalization()(total_amp1)
# total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp2 = Dense(3, activation = 'linear',name = 'total_amp2')(amp_Batchnormalization)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center2,total_width2,total_amp2])
print(model.summary())
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 61, 32)       3232        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 30, 32)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 27, 64)       8256        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 13, 64)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 10, 128)      32896       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 5, 128)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 4, 192)       49344       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 2, 192)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 192)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 100)          20100       Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 100)          20100       Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 100)          20100       Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 1)            201         Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           4040        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           4040        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           4040        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           1680        concatenate[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           1680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           1680        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 40)           160         total_center1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 40)           160         total_width1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40)           160         total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 3)            123         batch_normalization[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 3)            123         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 3)            123         batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 366,838
# Trainable params: 366,598
# Non-trainable params: 240
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center2' : 'mse',
                      'total_width2' : 'mse',
                      'total_amp2' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 0.5,
#                            'total_width3' : 1,
#                            'total_amp3' : 1,
#                             'Dense3_peak_number' :1 },
              metrics = ['mae'])

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 50,
          batch_size = 1000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 5.1836 - Dense3_peak_number_loss: 0.1028 - total_center2_loss: 4.9511 - total_width2_loss: 0.0953 - total_amp2_loss: 0.0345 - Dense3_peak_number_mae: 0.2048 - total_center2_mae: 1.0788 - total_width2_mae: 0.2008 - total_amp2_mae: 0.1299 - val_loss: 0.4523 - val_Dense3_peak_number_loss: 0.0248 - val_total_center2_loss: 0.3443 - val_total_width2_loss: 0.0510 - val_total_amp2_loss: 0.0322 - val_Dense3_peak_number_mae: 0.0963 - val_total_center2_mae: 0.2964 - val_total_width2_mae: 0.1600 - val_total_amp2_mae: 0.1363
# Epoch 2/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.3455 - Dense3_peak_number_loss: 0.0183 - total_center2_loss: 0.2728 - total_width2_loss: 0.0363 - total_amp2_loss: 0.0181 - Dense3_peak_number_mae: 0.0734 - total_center2_mae: 0.2730 - total_width2_mae: 0.1243 - total_amp2_mae: 0.0903 - val_loss: 0.2650 - val_Dense3_peak_number_loss: 0.0100 - val_total_center2_loss: 0.2064 - val_total_width2_loss: 0.0313 - val_total_amp2_loss: 0.0173 - val_Dense3_peak_number_mae: 0.0486 - val_total_center2_mae: 0.2464 - val_total_width2_mae: 0.1217 - val_total_amp2_mae: 0.0902
# Epoch 3/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.2805 - Dense3_peak_number_loss: 0.0131 - total_center2_loss: 0.2207 - total_width2_loss: 0.0309 - total_amp2_loss: 0.0157 - Dense3_peak_number_mae: 0.0540 - total_center2_mae: 0.2368 - total_width2_mae: 0.1128 - total_amp2_mae: 0.0819 - val_loss: 0.2958 - val_Dense3_peak_number_loss: 0.0118 - val_total_center2_loss: 0.2361 - val_total_width2_loss: 0.0319 - val_total_amp2_loss: 0.0159 - val_Dense3_peak_number_mae: 0.0476 - val_total_center2_mae: 0.2405 - val_total_width2_mae: 0.1175 - val_total_amp2_mae: 0.0838
# Epoch 4/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.2435 - Dense3_peak_number_loss: 0.0108 - total_center2_loss: 0.1908 - total_width2_loss: 0.0275 - total_amp2_loss: 0.0144 - Dense3_peak_number_mae: 0.0467 - total_center2_mae: 0.2176 - total_width2_mae: 0.1057 - total_amp2_mae: 0.0772 - val_loss: 0.2600 - val_Dense3_peak_number_loss: 0.0065 - val_total_center2_loss: 0.2103 - val_total_width2_loss: 0.0292 - val_total_amp2_loss: 0.0140 - val_Dense3_peak_number_mae: 0.0292 - val_total_center2_mae: 0.2638 - val_total_width2_mae: 0.1141 - val_total_amp2_mae: 0.0801
# Epoch 5/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.2168 - Dense3_peak_number_loss: 0.0091 - total_center2_loss: 0.1694 - total_width2_loss: 0.0249 - total_amp2_loss: 0.0134 - Dense3_peak_number_mae: 0.0419 - total_center2_mae: 0.2037 - total_width2_mae: 0.0997 - total_amp2_mae: 0.0738 - val_loss: 0.2040 - val_Dense3_peak_number_loss: 0.0070 - val_total_center2_loss: 0.1596 - val_total_width2_loss: 0.0245 - val_total_amp2_loss: 0.0129 - val_Dense3_peak_number_mae: 0.0383 - val_total_center2_mae: 0.2065 - val_total_width2_mae: 0.1004 - val_total_amp2_mae: 0.0717
# Epoch 6/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.2017 - Dense3_peak_number_loss: 0.0085 - total_center2_loss: 0.1571 - total_width2_loss: 0.0233 - total_amp2_loss: 0.0128 - Dense3_peak_number_mae: 0.0405 - total_center2_mae: 0.1941 - total_width2_mae: 0.0959 - total_amp2_mae: 0.0714 - val_loss: 0.1935 - val_Dense3_peak_number_loss: 0.0068 - val_total_center2_loss: 0.1495 - val_total_width2_loss: 0.0246 - val_total_amp2_loss: 0.0125 - val_Dense3_peak_number_mae: 0.0335 - val_total_center2_mae: 0.1807 - val_total_width2_mae: 0.1005 - val_total_amp2_mae: 0.0708
# Epoch 7/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1851 - Dense3_peak_number_loss: 0.0075 - total_center2_loss: 0.1438 - total_width2_loss: 0.0217 - total_amp2_loss: 0.0121 - Dense3_peak_number_mae: 0.0364 - total_center2_mae: 0.1845 - total_width2_mae: 0.0920 - total_amp2_mae: 0.0689 - val_loss: 0.1968 - val_Dense3_peak_number_loss: 0.0067 - val_total_center2_loss: 0.1553 - val_total_width2_loss: 0.0216 - val_total_amp2_loss: 0.0132 - val_Dense3_peak_number_mae: 0.0405 - val_total_center2_mae: 0.1783 - val_total_width2_mae: 0.0936 - val_total_amp2_mae: 0.0721
# Epoch 8/50
# 1800/1800 [==============================] - 22s 12ms/step - loss: 0.1788 - Dense3_peak_number_loss: 0.0074 - total_center2_loss: 0.1388 - total_width2_loss: 0.0207 - total_amp2_loss: 0.0119 - Dense3_peak_number_mae: 0.0362 - total_center2_mae: 0.1815 - total_width2_mae: 0.0898 - total_amp2_mae: 0.0679 - val_loss: 0.1656 - val_Dense3_peak_number_loss: 0.0050 - val_total_center2_loss: 0.1294 - val_total_width2_loss: 0.0201 - val_total_amp2_loss: 0.0111 - val_Dense3_peak_number_mae: 0.0211 - val_total_center2_mae: 0.1577 - val_total_width2_mae: 0.0881 - val_total_amp2_mae: 0.0644
# Epoch 9/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1691 - Dense3_peak_number_loss: 0.0069 - total_center2_loss: 0.1309 - total_width2_loss: 0.0198 - total_amp2_loss: 0.0115 - Dense3_peak_number_mae: 0.0347 - total_center2_mae: 0.1748 - total_width2_mae: 0.0875 - total_amp2_mae: 0.0667 - val_loss: 0.1674 - val_Dense3_peak_number_loss: 0.0047 - val_total_center2_loss: 0.1310 - val_total_width2_loss: 0.0203 - val_total_amp2_loss: 0.0114 - val_Dense3_peak_number_mae: 0.0197 - val_total_center2_mae: 0.1798 - val_total_width2_mae: 0.0899 - val_total_amp2_mae: 0.0662
# Epoch 10/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1610 - Dense3_peak_number_loss: 0.0064 - total_center2_loss: 0.1245 - total_width2_loss: 0.0190 - total_amp2_loss: 0.0111 - Dense3_peak_number_mae: 0.0319 - total_center2_mae: 0.1702 - total_width2_mae: 0.0853 - total_amp2_mae: 0.0650 - val_loss: 0.2131 - val_Dense3_peak_number_loss: 0.0079 - val_total_center2_loss: 0.1720 - val_total_width2_loss: 0.0210 - val_total_amp2_loss: 0.0122 - val_Dense3_peak_number_mae: 0.0253 - val_total_center2_mae: 0.1978 - val_total_width2_mae: 0.0899 - val_total_amp2_mae: 0.0712
# Epoch 11/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1528 - Dense3_peak_number_loss: 0.0058 - total_center2_loss: 0.1178 - total_width2_loss: 0.0183 - total_amp2_loss: 0.0109 - Dense3_peak_number_mae: 0.0294 - total_center2_mae: 0.1656 - total_width2_mae: 0.0835 - total_amp2_mae: 0.0643 - val_loss: 0.1820 - val_Dense3_peak_number_loss: 0.0053 - val_total_center2_loss: 0.1468 - val_total_width2_loss: 0.0185 - val_total_amp2_loss: 0.0113 - val_Dense3_peak_number_mae: 0.0187 - val_total_center2_mae: 0.1905 - val_total_width2_mae: 0.0818 - val_total_amp2_mae: 0.0647
# Epoch 12/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1468 - Dense3_peak_number_loss: 0.0054 - total_center2_loss: 0.1130 - total_width2_loss: 0.0178 - total_amp2_loss: 0.0107 - Dense3_peak_number_mae: 0.0265 - total_center2_mae: 0.1620 - total_width2_mae: 0.0821 - total_amp2_mae: 0.0634 - val_loss: 0.1793 - val_Dense3_peak_number_loss: 0.0051 - val_total_center2_loss: 0.1452 - val_total_width2_loss: 0.0181 - val_total_amp2_loss: 0.0109 - val_Dense3_peak_number_mae: 0.0224 - val_total_center2_mae: 0.1712 - val_total_width2_mae: 0.0810 - val_total_amp2_mae: 0.0639
# Epoch 13/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1428 - Dense3_peak_number_loss: 0.0052 - total_center2_loss: 0.1096 - total_width2_loss: 0.0174 - total_amp2_loss: 0.0106 - Dense3_peak_number_mae: 0.0247 - total_center2_mae: 0.1596 - total_width2_mae: 0.0812 - total_amp2_mae: 0.0627 - val_loss: 0.1486 - val_Dense3_peak_number_loss: 0.0045 - val_total_center2_loss: 0.1143 - val_total_width2_loss: 0.0190 - val_total_amp2_loss: 0.0107 - val_Dense3_peak_number_mae: 0.0177 - val_total_center2_mae: 0.1549 - val_total_width2_mae: 0.0863 - val_total_amp2_mae: 0.0636
# Epoch 14/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1383 - Dense3_peak_number_loss: 0.0049 - total_center2_loss: 0.1060 - total_width2_loss: 0.0170 - total_amp2_loss: 0.0104 - Dense3_peak_number_mae: 0.0238 - total_center2_mae: 0.1565 - total_width2_mae: 0.0801 - total_amp2_mae: 0.0622 - val_loss: 0.1486 - val_Dense3_peak_number_loss: 0.0049 - val_total_center2_loss: 0.1157 - val_total_width2_loss: 0.0175 - val_total_amp2_loss: 0.0105 - val_Dense3_peak_number_mae: 0.0194 - val_total_center2_mae: 0.1632 - val_total_width2_mae: 0.0792 - val_total_amp2_mae: 0.0629
# Epoch 15/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1326 - Dense3_peak_number_loss: 0.0045 - total_center2_loss: 0.1014 - total_width2_loss: 0.0165 - total_amp2_loss: 0.0101 - Dense3_peak_number_mae: 0.0215 - total_center2_mae: 0.1538 - total_width2_mae: 0.0785 - total_amp2_mae: 0.0611 - val_loss: 0.1486 - val_Dense3_peak_number_loss: 0.0051 - val_total_center2_loss: 0.1164 - val_total_width2_loss: 0.0166 - val_total_amp2_loss: 0.0105 - val_Dense3_peak_number_mae: 0.0183 - val_total_center2_mae: 0.1499 - val_total_width2_mae: 0.0754 - val_total_amp2_mae: 0.0635
# Epoch 16/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1295 - Dense3_peak_number_loss: 0.0045 - total_center2_loss: 0.0987 - total_width2_loss: 0.0163 - total_amp2_loss: 0.0101 - Dense3_peak_number_mae: 0.0211 - total_center2_mae: 0.1520 - total_width2_mae: 0.0782 - total_amp2_mae: 0.0608 - val_loss: 0.1623 - val_Dense3_peak_number_loss: 0.0067 - val_total_center2_loss: 0.1267 - val_total_width2_loss: 0.0183 - val_total_amp2_loss: 0.0105 - val_Dense3_peak_number_mae: 0.0346 - val_total_center2_mae: 0.1533 - val_total_width2_mae: 0.0817 - val_total_amp2_mae: 0.0637
# Epoch 17/50
# 1800/1800 [==============================] - 22s 12ms/step - loss: 0.1287 - Dense3_peak_number_loss: 0.0046 - total_center2_loss: 0.0981 - total_width2_loss: 0.0161 - total_amp2_loss: 0.0100 - Dense3_peak_number_mae: 0.0220 - total_center2_mae: 0.1521 - total_width2_mae: 0.0775 - total_amp2_mae: 0.0605 - val_loss: 0.1591 - val_Dense3_peak_number_loss: 0.0050 - val_total_center2_loss: 0.1263 - val_total_width2_loss: 0.0178 - val_total_amp2_loss: 0.0100 - val_Dense3_peak_number_mae: 0.0221 - val_total_center2_mae: 0.1783 - val_total_width2_mae: 0.0812 - val_total_amp2_mae: 0.0599
# Epoch 18/50
# 1800/1800 [==============================] - 22s 12ms/step - loss: 0.1227 - Dense3_peak_number_loss: 0.0042 - total_center2_loss: 0.0931 - total_width2_loss: 0.0156 - total_amp2_loss: 0.0098 - Dense3_peak_number_mae: 0.0202 - total_center2_mae: 0.1477 - total_width2_mae: 0.0764 - total_amp2_mae: 0.0597 - val_loss: 0.3126 - val_Dense3_peak_number_loss: 0.0120 - val_total_center2_loss: 0.2636 - val_total_width2_loss: 0.0220 - val_total_amp2_loss: 0.0149 - val_Dense3_peak_number_mae: 0.0506 - val_total_center2_mae: 0.2103 - val_total_width2_mae: 0.0930 - val_total_amp2_mae: 0.0837
# Epoch 19/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1210 - Dense3_peak_number_loss: 0.0041 - total_center2_loss: 0.0917 - total_width2_loss: 0.0154 - total_amp2_loss: 0.0097 - Dense3_peak_number_mae: 0.0196 - total_center2_mae: 0.1477 - total_width2_mae: 0.0758 - total_amp2_mae: 0.0594 - val_loss: 0.1577 - val_Dense3_peak_number_loss: 0.0059 - val_total_center2_loss: 0.1256 - val_total_width2_loss: 0.0161 - val_total_amp2_loss: 0.0101 - val_Dense3_peak_number_mae: 0.0220 - val_total_center2_mae: 0.1479 - val_total_width2_mae: 0.0774 - val_total_amp2_mae: 0.0616
# Epoch 20/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1166 - Dense3_peak_number_loss: 0.0039 - total_center2_loss: 0.0878 - total_width2_loss: 0.0152 - total_amp2_loss: 0.0096 - Dense3_peak_number_mae: 0.0188 - total_center2_mae: 0.1434 - total_width2_mae: 0.0753 - total_amp2_mae: 0.0591 - val_loss: 0.1379 - val_Dense3_peak_number_loss: 0.0041 - val_total_center2_loss: 0.1001 - val_total_width2_loss: 0.0201 - val_total_amp2_loss: 0.0136 - val_Dense3_peak_number_mae: 0.0169 - val_total_center2_mae: 0.1179 - val_total_width2_mae: 0.0922 - val_total_amp2_mae: 0.0765
# Epoch 21/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1157 - Dense3_peak_number_loss: 0.0038 - total_center2_loss: 0.0874 - total_width2_loss: 0.0149 - total_amp2_loss: 0.0095 - Dense3_peak_number_mae: 0.0188 - total_center2_mae: 0.1443 - total_width2_mae: 0.0743 - total_amp2_mae: 0.0585 - val_loss: 0.2158 - val_Dense3_peak_number_loss: 0.0055 - val_total_center2_loss: 0.1813 - val_total_width2_loss: 0.0184 - val_total_amp2_loss: 0.0106 - val_Dense3_peak_number_mae: 0.0192 - val_total_center2_mae: 0.1771 - val_total_width2_mae: 0.0867 - val_total_amp2_mae: 0.0624
# Epoch 22/50
# 1800/1800 [==============================] - 22s 12ms/step - loss: 0.1133 - Dense3_peak_number_loss: 0.0038 - total_center2_loss: 0.0851 - total_width2_loss: 0.0149 - total_amp2_loss: 0.0095 - Dense3_peak_number_mae: 0.0189 - total_center2_mae: 0.1424 - total_width2_mae: 0.0742 - total_amp2_mae: 0.0583 - val_loss: 0.1389 - val_Dense3_peak_number_loss: 0.0044 - val_total_center2_loss: 0.1083 - val_total_width2_loss: 0.0163 - val_total_amp2_loss: 0.0100 - val_Dense3_peak_number_mae: 0.0135 - val_total_center2_mae: 0.1401 - val_total_width2_mae: 0.0789 - val_total_amp2_mae: 0.0610
# Epoch 23/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1103 - Dense3_peak_number_loss: 0.0035 - total_center2_loss: 0.0828 - total_width2_loss: 0.0146 - total_amp2_loss: 0.0094 - Dense3_peak_number_mae: 0.0177 - total_center2_mae: 0.1405 - total_width2_mae: 0.0734 - total_amp2_mae: 0.0579 - val_loss: 0.1383 - val_Dense3_peak_number_loss: 0.0044 - val_total_center2_loss: 0.1075 - val_total_width2_loss: 0.0160 - val_total_amp2_loss: 0.0105 - val_Dense3_peak_number_mae: 0.0225 - val_total_center2_mae: 0.1377 - val_total_width2_mae: 0.0754 - val_total_amp2_mae: 0.0633
# Epoch 24/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1101 - Dense3_peak_number_loss: 0.0037 - total_center2_loss: 0.0826 - total_width2_loss: 0.0145 - total_amp2_loss: 0.0093 - Dense3_peak_number_mae: 0.0178 - total_center2_mae: 0.1412 - total_width2_mae: 0.0732 - total_amp2_mae: 0.0578 - val_loss: 0.1646 - val_Dense3_peak_number_loss: 0.0077 - val_total_center2_loss: 0.1287 - val_total_width2_loss: 0.0178 - val_total_amp2_loss: 0.0104 - val_Dense3_peak_number_mae: 0.0284 - val_total_center2_mae: 0.1365 - val_total_width2_mae: 0.0797 - val_total_amp2_mae: 0.0610
# Epoch 25/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1073 - Dense3_peak_number_loss: 0.0035 - total_center2_loss: 0.0803 - total_width2_loss: 0.0143 - total_amp2_loss: 0.0092 - Dense3_peak_number_mae: 0.0181 - total_center2_mae: 0.1392 - total_width2_mae: 0.0724 - total_amp2_mae: 0.0573 - val_loss: 0.1284 - val_Dense3_peak_number_loss: 0.0039 - val_total_center2_loss: 0.0991 - val_total_width2_loss: 0.0160 - val_total_amp2_loss: 0.0093 - val_Dense3_peak_number_mae: 0.0202 - val_total_center2_mae: 0.1324 - val_total_width2_mae: 0.0778 - val_total_amp2_mae: 0.0580
# Epoch 26/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1065 - Dense3_peak_number_loss: 0.0034 - total_center2_loss: 0.0797 - total_width2_loss: 0.0142 - total_amp2_loss: 0.0092 - Dense3_peak_number_mae: 0.0167 - total_center2_mae: 0.1389 - total_width2_mae: 0.0723 - total_amp2_mae: 0.0571 - val_loss: 0.1220 - val_Dense3_peak_number_loss: 0.0037 - val_total_center2_loss: 0.0950 - val_total_width2_loss: 0.0143 - val_total_amp2_loss: 0.0090 - val_Dense3_peak_number_mae: 0.0138 - val_total_center2_mae: 0.1294 - val_total_width2_mae: 0.0709 - val_total_amp2_mae: 0.0540
# Epoch 27/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1053 - Dense3_peak_number_loss: 0.0033 - total_center2_loss: 0.0788 - total_width2_loss: 0.0141 - total_amp2_loss: 0.0091 - Dense3_peak_number_mae: 0.0167 - total_center2_mae: 0.1374 - total_width2_mae: 0.0721 - total_amp2_mae: 0.0568 - val_loss: 0.1169 - val_Dense3_peak_number_loss: 0.0031 - val_total_center2_loss: 0.0865 - val_total_width2_loss: 0.0149 - val_total_amp2_loss: 0.0124 - val_Dense3_peak_number_mae: 0.0127 - val_total_center2_mae: 0.1152 - val_total_width2_mae: 0.0736 - val_total_amp2_mae: 0.0768
# Epoch 28/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.1023 - Dense3_peak_number_loss: 0.0032 - total_center2_loss: 0.0762 - total_width2_loss: 0.0138 - total_amp2_loss: 0.0090 - Dense3_peak_number_mae: 0.0163 - total_center2_mae: 0.1346 - total_width2_mae: 0.0709 - total_amp2_mae: 0.0564 - val_loss: 0.1429 - val_Dense3_peak_number_loss: 0.0053 - val_total_center2_loss: 0.1113 - val_total_width2_loss: 0.0163 - val_total_amp2_loss: 0.0099 - val_Dense3_peak_number_mae: 0.0195 - val_total_center2_mae: 0.1557 - val_total_width2_mae: 0.0764 - val_total_amp2_mae: 0.0598
# Epoch 29/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.1018 - Dense3_peak_number_loss: 0.0033 - total_center2_loss: 0.0756 - total_width2_loss: 0.0139 - total_amp2_loss: 0.0090 - Dense3_peak_number_mae: 0.0165 - total_center2_mae: 0.1352 - total_width2_mae: 0.0714 - total_amp2_mae: 0.0563 - val_loss: 0.1514 - val_Dense3_peak_number_loss: 0.0043 - val_total_center2_loss: 0.1211 - val_total_width2_loss: 0.0168 - val_total_amp2_loss: 0.0093 - val_Dense3_peak_number_mae: 0.0172 - val_total_center2_mae: 0.1789 - val_total_width2_mae: 0.0799 - val_total_amp2_mae: 0.0554
# Epoch 30/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0997 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0739 - total_width2_loss: 0.0137 - total_amp2_loss: 0.0090 - Dense3_peak_number_mae: 0.0155 - total_center2_mae: 0.1338 - total_width2_mae: 0.0710 - total_amp2_mae: 0.0562 - val_loss: 0.1340 - val_Dense3_peak_number_loss: 0.0043 - val_total_center2_loss: 0.1047 - val_total_width2_loss: 0.0152 - val_total_amp2_loss: 0.0098 - val_Dense3_peak_number_mae: 0.0223 - val_total_center2_mae: 0.1359 - val_total_width2_mae: 0.0724 - val_total_amp2_mae: 0.0597
# Epoch 31/50
# 1800/1800 [==============================] - 22s 12ms/step - loss: 0.0997 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0739 - total_width2_loss: 0.0137 - total_amp2_loss: 0.0090 - Dense3_peak_number_mae: 0.0156 - total_center2_mae: 0.1345 - total_width2_mae: 0.0710 - total_amp2_mae: 0.0566 - val_loss: 0.1197 - val_Dense3_peak_number_loss: 0.0036 - val_total_center2_loss: 0.0918 - val_total_width2_loss: 0.0146 - val_total_amp2_loss: 0.0097 - val_Dense3_peak_number_mae: 0.0113 - val_total_center2_mae: 0.1279 - val_total_width2_mae: 0.0717 - val_total_amp2_mae: 0.0592
# Epoch 32/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0994 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0738 - total_width2_loss: 0.0135 - total_amp2_loss: 0.0090 - Dense3_peak_number_mae: 0.0158 - total_center2_mae: 0.1346 - total_width2_mae: 0.0703 - total_amp2_mae: 0.0563 - val_loss: 0.1200 - val_Dense3_peak_number_loss: 0.0033 - val_total_center2_loss: 0.0934 - val_total_width2_loss: 0.0139 - val_total_amp2_loss: 0.0094 - val_Dense3_peak_number_mae: 0.0142 - val_total_center2_mae: 0.1136 - val_total_width2_mae: 0.0691 - val_total_amp2_mae: 0.0577
# Epoch 33/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.0965 - Dense3_peak_number_loss: 0.0030 - total_center2_loss: 0.0714 - total_width2_loss: 0.0133 - total_amp2_loss: 0.0088 - Dense3_peak_number_mae: 0.0155 - total_center2_mae: 0.1328 - total_width2_mae: 0.0697 - total_amp2_mae: 0.0555 - val_loss: 0.1538 - val_Dense3_peak_number_loss: 0.0058 - val_total_center2_loss: 0.1230 - val_total_width2_loss: 0.0154 - val_total_amp2_loss: 0.0097 - val_Dense3_peak_number_mae: 0.0199 - val_total_center2_mae: 0.1122 - val_total_width2_mae: 0.0719 - val_total_amp2_mae: 0.0593
# Epoch 34/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.0963 - Dense3_peak_number_loss: 0.0030 - total_center2_loss: 0.0712 - total_width2_loss: 0.0133 - total_amp2_loss: 0.0088 - Dense3_peak_number_mae: 0.0149 - total_center2_mae: 0.1324 - total_width2_mae: 0.0697 - total_amp2_mae: 0.0555 - val_loss: 0.1324 - val_Dense3_peak_number_loss: 0.0045 - val_total_center2_loss: 0.1032 - val_total_width2_loss: 0.0152 - val_total_amp2_loss: 0.0095 - val_Dense3_peak_number_mae: 0.0133 - val_total_center2_mae: 0.1338 - val_total_width2_mae: 0.0742 - val_total_amp2_mae: 0.0575
# Epoch 35/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.0935 - Dense3_peak_number_loss: 0.0029 - total_center2_loss: 0.0686 - total_width2_loss: 0.0132 - total_amp2_loss: 0.0087 - Dense3_peak_number_mae: 0.0149 - total_center2_mae: 0.1307 - total_width2_mae: 0.0695 - total_amp2_mae: 0.0552 - val_loss: 0.1598 - val_Dense3_peak_number_loss: 0.0049 - val_total_center2_loss: 0.1304 - val_total_width2_loss: 0.0152 - val_total_amp2_loss: 0.0094 - val_Dense3_peak_number_mae: 0.0197 - val_total_center2_mae: 0.1628 - val_total_width2_mae: 0.0752 - val_total_amp2_mae: 0.0564
# Epoch 36/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0957 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0706 - total_width2_loss: 0.0132 - total_amp2_loss: 0.0087 - Dense3_peak_number_mae: 0.0153 - total_center2_mae: 0.1330 - total_width2_mae: 0.0695 - total_amp2_mae: 0.0552 - val_loss: 0.1214 - val_Dense3_peak_number_loss: 0.0037 - val_total_center2_loss: 0.0934 - val_total_width2_loss: 0.0139 - val_total_amp2_loss: 0.0104 - val_Dense3_peak_number_mae: 0.0114 - val_total_center2_mae: 0.1109 - val_total_width2_mae: 0.0677 - val_total_amp2_mae: 0.0644
# Epoch 37/50
# 1800/1800 [==============================] - 24s 14ms/step - loss: 0.0909 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0667 - total_width2_loss: 0.0129 - total_amp2_loss: 0.0086 - Dense3_peak_number_mae: 0.0139 - total_center2_mae: 0.1297 - total_width2_mae: 0.0685 - total_amp2_mae: 0.0546 - val_loss: 0.1423 - val_Dense3_peak_number_loss: 0.0042 - val_total_center2_loss: 0.1133 - val_total_width2_loss: 0.0150 - val_total_amp2_loss: 0.0098 - val_Dense3_peak_number_mae: 0.0198 - val_total_center2_mae: 0.1488 - val_total_width2_mae: 0.0722 - val_total_amp2_mae: 0.0598
# Epoch 38/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0906 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0663 - total_width2_loss: 0.0129 - total_amp2_loss: 0.0086 - Dense3_peak_number_mae: 0.0140 - total_center2_mae: 0.1288 - total_width2_mae: 0.0687 - total_amp2_mae: 0.0546 - val_loss: 0.1834 - val_Dense3_peak_number_loss: 0.0037 - val_total_center2_loss: 0.1555 - val_total_width2_loss: 0.0145 - val_total_amp2_loss: 0.0097 - val_Dense3_peak_number_mae: 0.0170 - val_total_center2_mae: 0.2631 - val_total_width2_mae: 0.0723 - val_total_amp2_mae: 0.0601
# Epoch 39/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0896 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0655 - total_width2_loss: 0.0128 - total_amp2_loss: 0.0086 - Dense3_peak_number_mae: 0.0137 - total_center2_mae: 0.1291 - total_width2_mae: 0.0683 - total_amp2_mae: 0.0546 - val_loss: 0.1112 - val_Dense3_peak_number_loss: 0.0030 - val_total_center2_loss: 0.0857 - val_total_width2_loss: 0.0137 - val_total_amp2_loss: 0.0088 - val_Dense3_peak_number_mae: 0.0140 - val_total_center2_mae: 0.1049 - val_total_width2_mae: 0.0685 - val_total_amp2_mae: 0.0538
# Epoch 40/50
# 1800/1800 [==============================] - 22s 12ms/step - loss: 0.0890 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0649 - total_width2_loss: 0.0129 - total_amp2_loss: 0.0086 - Dense3_peak_number_mae: 0.0138 - total_center2_mae: 0.1287 - total_width2_mae: 0.0684 - total_amp2_mae: 0.0544 - val_loss: 0.1248 - val_Dense3_peak_number_loss: 0.0036 - val_total_center2_loss: 0.0983 - val_total_width2_loss: 0.0139 - val_total_amp2_loss: 0.0090 - val_Dense3_peak_number_mae: 0.0119 - val_total_center2_mae: 0.1131 - val_total_width2_mae: 0.0688 - val_total_amp2_mae: 0.0550
# Epoch 41/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.0871 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0633 - total_width2_loss: 0.0127 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0133 - total_center2_mae: 0.1268 - total_width2_mae: 0.0683 - total_amp2_mae: 0.0542 - val_loss: 0.1072 - val_Dense3_peak_number_loss: 0.0033 - val_total_center2_loss: 0.0820 - val_total_width2_loss: 0.0132 - val_total_amp2_loss: 0.0087 - val_Dense3_peak_number_mae: 0.0123 - val_total_center2_mae: 0.1070 - val_total_width2_mae: 0.0682 - val_total_amp2_mae: 0.0540
# Epoch 42/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0888 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0649 - total_width2_loss: 0.0127 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0131 - total_center2_mae: 0.1282 - total_width2_mae: 0.0680 - total_amp2_mae: 0.0543 - val_loss: 0.1134 - val_Dense3_peak_number_loss: 0.0031 - val_total_center2_loss: 0.0882 - val_total_width2_loss: 0.0132 - val_total_amp2_loss: 0.0088 - val_Dense3_peak_number_mae: 0.0121 - val_total_center2_mae: 0.1242 - val_total_width2_mae: 0.0687 - val_total_amp2_mae: 0.0544
# Epoch 43/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.0867 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0630 - total_width2_loss: 0.0126 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0132 - total_center2_mae: 0.1266 - total_width2_mae: 0.0677 - total_amp2_mae: 0.0540 - val_loss: 0.1082 - val_Dense3_peak_number_loss: 0.0030 - val_total_center2_loss: 0.0835 - val_total_width2_loss: 0.0129 - val_total_amp2_loss: 0.0089 - val_Dense3_peak_number_mae: 0.0120 - val_total_center2_mae: 0.1157 - val_total_width2_mae: 0.0646 - val_total_amp2_mae: 0.0547
# Epoch 44/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0854 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0620 - total_width2_loss: 0.0125 - total_amp2_loss: 0.0084 - Dense3_peak_number_mae: 0.0122 - total_center2_mae: 0.1261 - total_width2_mae: 0.0674 - total_amp2_mae: 0.0537 - val_loss: 0.1327 - val_Dense3_peak_number_loss: 0.0051 - val_total_center2_loss: 0.1053 - val_total_width2_loss: 0.0136 - val_total_amp2_loss: 0.0087 - val_Dense3_peak_number_mae: 0.0159 - val_total_center2_mae: 0.1325 - val_total_width2_mae: 0.0651 - val_total_amp2_mae: 0.0535
# Epoch 45/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0866 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0630 - total_width2_loss: 0.0125 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0132 - total_center2_mae: 0.1275 - total_width2_mae: 0.0677 - total_amp2_mae: 0.0540 - val_loss: 0.1159 - val_Dense3_peak_number_loss: 0.0031 - val_total_center2_loss: 0.0899 - val_total_width2_loss: 0.0138 - val_total_amp2_loss: 0.0091 - val_Dense3_peak_number_mae: 0.0161 - val_total_center2_mae: 0.1317 - val_total_width2_mae: 0.0705 - val_total_amp2_mae: 0.0563
# Epoch 46/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0845 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0611 - total_width2_loss: 0.0125 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0126 - total_center2_mae: 0.1262 - total_width2_mae: 0.0675 - total_amp2_mae: 0.0541 - val_loss: 0.1227 - val_Dense3_peak_number_loss: 0.0035 - val_total_center2_loss: 0.0972 - val_total_width2_loss: 0.0134 - val_total_amp2_loss: 0.0086 - val_Dense3_peak_number_mae: 0.0152 - val_total_center2_mae: 0.1159 - val_total_width2_mae: 0.0689 - val_total_amp2_mae: 0.0524
# Epoch 47/50
# 1800/1800 [==============================] - 23s 13ms/step - loss: 0.0851 - Dense3_peak_number_loss: 0.0025 - total_center2_loss: 0.0618 - total_width2_loss: 0.0125 - total_amp2_loss: 0.0084 - Dense3_peak_number_mae: 0.0126 - total_center2_mae: 0.1271 - total_width2_mae: 0.0674 - total_amp2_mae: 0.0538 - val_loss: 0.1094 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0847 - val_total_width2_loss: 0.0130 - val_total_amp2_loss: 0.0088 - val_Dense3_peak_number_mae: 0.0090 - val_total_center2_mae: 0.1163 - val_total_width2_mae: 0.0652 - val_total_amp2_mae: 0.0556
# Epoch 48/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0842 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0610 - total_width2_loss: 0.0124 - total_amp2_loss: 0.0084 - Dense3_peak_number_mae: 0.0122 - total_center2_mae: 0.1260 - total_width2_mae: 0.0671 - total_amp2_mae: 0.0535 - val_loss: 0.1145 - val_Dense3_peak_number_loss: 0.0033 - val_total_center2_loss: 0.0886 - val_total_width2_loss: 0.0138 - val_total_amp2_loss: 0.0088 - val_Dense3_peak_number_mae: 0.0141 - val_total_center2_mae: 0.0998 - val_total_width2_mae: 0.0706 - val_total_amp2_mae: 0.0552
# Epoch 49/50
# 1800/1800 [==============================] - 24s 13ms/step - loss: 0.0826 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0596 - total_width2_loss: 0.0123 - total_amp2_loss: 0.0083 - Dense3_peak_number_mae: 0.0122 - total_center2_mae: 0.1253 - total_width2_mae: 0.0669 - total_amp2_mae: 0.0534 - val_loss: 0.1120 - val_Dense3_peak_number_loss: 0.0035 - val_total_center2_loss: 0.0863 - val_total_width2_loss: 0.0136 - val_total_amp2_loss: 0.0086 - val_Dense3_peak_number_mae: 0.0138 - val_total_center2_mae: 0.1182 - val_total_width2_mae: 0.0687 - val_total_amp2_mae: 0.0528
# Epoch 50/50
# 1800/1800 [==============================] - 25s 14ms/step - loss: 0.0806 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0577 - total_width2_loss: 0.0122 - total_amp2_loss: 0.0083 - Dense3_peak_number_mae: 0.0116 - total_center2_mae: 0.1230 - total_width2_mae: 0.0666 - total_amp2_mae: 0.0532 - val_loss: 0.1315 - val_Dense3_peak_number_loss: 0.0041 - val_total_center2_loss: 0.1034 - val_total_width2_loss: 0.0139 - val_total_amp2_loss: 0.0101 - val_Dense3_peak_number_mae: 0.0139 - val_total_center2_mae: 0.1190 - val_total_width2_mae: 0.0711 - val_total_amp2_mae: 0.0628

# %%
test_graph.shape
# Out:
# (20000, 401, 1)

# %%
for key in models.history.keys():
    print(key)
# Out:
# loss
# Dense3_peak_number_loss
# total_center2_loss
# total_width2_loss
# total_amp2_loss
# Dense3_peak_number_mae
# total_center2_mae
# total_width2_mae
# total_amp2_mae
# val_loss
# val_Dense3_peak_number_loss
# val_total_center2_loss
# val_total_width2_loss
# val_total_amp2_loss
# val_Dense3_peak_number_mae
# val_total_center2_mae
# val_total_width2_mae
# val_total_amp2_mae

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp2_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (20000, 1)
# (20000, 3)
# (20000, 3)
# (20000, 3)

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,color='black')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'blue')
    plt.grid(True)
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
# Out:
# real_center   [ 9.60415956 11.14668092 11.47912189]
# predict_center [ 9.525492 10.832947 11.642315 ]
# ---------------
# real_width    [1.5890307  0.85169246 1.80413822]
# predict_center [ 1.5595031 0.95746386 1.3205261 ]
# ---------------
# real_amp      [0.89910869 0.73511122 0.32534025]
# predict_center [ 0.7343803 0.8754359 0.37200764 ]
# real_center   [ 4.96442796  6.20641811 11.64795119]
# predict_center [ 4.9652185 6.005128 11.412106 ]
# ---------------
# real_width    [1.29285544 1.48210664 1.20326619]
# predict_center [ 1.1811569 1.5555484 1.1314162 ]
# ---------------
# real_amp      [0.31264192 0.74429022 0.85930796]
# predict_center [ 0.28064215 0.7101437 0.7360037 ]
# real_center   [ 5.51560991  8.52452149 10.41021735]
# predict_center [ 5.6481533 8.606627 10.51245 ]
# ---------------
# real_width    [0.51572416 1.43398868 1.04389991]
# predict_center [ 0.59747624 1.5401666 1.0304648 ]
# ---------------
# real_amp      [0.33507966 0.33422976 0.51064052]
# predict_center [ 0.3467205 0.25996098 0.42517844 ]
# real_center   [0.         4.63807082 9.179333  ]
# predict_center [ 0.06630404 4.7442307 9.316178 ]
# ---------------
# real_width    [0.         1.5730631  0.74295865]
# predict_center [ 0.0732564 1.5674314 0.7362455 ]
# ---------------
# real_amp      [0.         0.77412159 0.96199287]
# predict_center [ 0.02598697 0.68908876 0.9755775 ]
# real_center   [0.         5.64066106 5.76226905]
# predict_center [ -0.053878948 5.7645583 6.016058 ]
# ---------------
# real_width    [0.         0.4972611  0.46414198]
# predict_center [ 0.027185887 0.38625735 0.37532243 ]
# ---------------
# real_amp      [0.         0.50943635 0.76748974]
# predict_center [ -0.0027638078 0.5071864 0.7427267 ]
# real_center   [ 0.          3.90915718 12.27854934]
# predict_center [ -0.06468058 4.090602 12.354896 ]
# ---------------
# real_width    [0.         1.27703819 1.68513974]
# predict_center [ 0.026471756 1.3062167 1.6633915 ]
# ---------------
# real_amp      [0.         0.7451384  0.44802234]
# predict_center [ 0.01127705 0.6763235 0.368549 ]
# real_center   [ 7.6388852  10.11514939 12.8605928 ]
# predict_center [ 7.5889196 10.133319 12.786678 ]
# ---------------
# real_width    [1.56748375 1.81764189 1.20375018]
# predict_center [ 1.4917178 1.7838304 1.1818613 ]
# ---------------
# real_amp      [0.97129856 0.33405169 0.73139226]
# predict_center [ 0.8861783 0.2605781 0.7781942 ]
# real_center   [ 0.          3.37818559 12.09577425]
# predict_center [ -0.07372369 3.4222946 12.155962 ]
# ---------------
# real_width    [0.         1.87067398 0.81372486]
# predict_center [ 0.02090583 1.864222 0.8195802 ]
# ---------------
# real_amp      [0.         1.05479242 0.57061607]
# predict_center [ 0.0009779632 0.9417682 0.6309147 ]
# real_center   [ 3.7208107   8.9248449  10.63085428]
# predict_center [ 3.8847675 8.946462 10.61841 ]
# ---------------
# real_width    [1.51614646 1.69568145 1.64873491]
# predict_center [ 1.5234334 1.6055782 1.7412624 ]
# ---------------
# real_amp      [0.97773525 0.40634786 0.43663805]
# predict_center [ 0.92620265 0.37159795 0.31721953 ]
# real_center   [0.         5.51444568 6.48623474]
# predict_center [ -0.09356968 5.516167 6.476757 ]
# ---------------
# real_width    [0.         0.70318896 0.69384366]
# predict_center [ 0.03175448 0.6773472 0.6034303 ]
# ---------------
# real_amp      [0.         0.72671767 0.74398204]
# predict_center [ 0.0057941973 0.70666134 0.67282283 ]
# real_center   [ 2.540612    6.2784285  12.29935321]
# predict_center [ 2.7370365 6.5548463 12.4500475 ]
# ---------------
# real_width    [0.49306503 0.57231099 1.14411432]
# predict_center [ 0.57145655 0.56770635 1.1638172 ]
# ---------------
# real_amp      [0.75234188 0.84439897 0.99688958]
# predict_center [ 0.68544006 0.77268046 1.0371733 ]
# real_center   [0.         6.31350636 8.63548535]
# predict_center [ -0.06344469 6.25919 8.726294 ]
# ---------------
# real_width    [0.         0.51092489 1.15916812]
# predict_center [ 0.044720523 0.5449114 1.1705681 ]
# ---------------
# real_amp      [0.         0.38276314 0.15176049]
# predict_center [ 0.014771104 0.31526166 0.20442063 ]
# real_center   [ 5.07960001  5.80143235 11.0101233 ]
# predict_center [ 5.1165514 5.9644413 11.075371 ]
# ---------------
# real_width    [1.19449069 1.14746491 1.58724255]
# predict_center [ 1.1451982 1.222616 1.4385868 ]
# ---------------
# real_amp      [0.58981853 0.79872797 0.34342458]
# predict_center [ 0.48816693 0.77106357 0.33011705 ]
# real_center   [ 2.60128723  5.96781092 12.23197636]
# predict_center [ 2.778305 6.0504875 12.235777 ]
# ---------------
# real_width    [1.05279236 0.39847303 1.03464265]
# predict_center [ 0.99349487 0.35133445 0.97909486 ]
# ---------------
# real_amp      [0.14400444 0.74509149 0.14666933]
# predict_center [ 0.27692837 0.68090785 0.11148067 ]
# real_center   [2.19807278 5.24895259 8.27560166]
# predict_center [ 2.328983 5.350322 8.36674 ]
# ---------------
# real_width    [0.88217427 0.90077778 0.64992968]
# predict_center [ 0.86938256 0.93832284 0.58442914 ]
# ---------------
# real_amp      [0.39760543 0.44608045 0.34842074]
# predict_center [ 0.34567523 0.48236346 0.3520498 ]
# real_center   [3.122331   5.3895395  7.02704367]
# predict_center [ 3.304597 5.480921 6.91628 ]
# ---------------
# real_width    [0.8947933  0.87098084 1.2845657 ]
# predict_center [ 0.8959408 0.84999067 1.2866064 ]
# ---------------
# real_amp      [0.4056828  0.58882564 0.25084836]
# predict_center [ 0.427634 0.54552567 0.203248 ]
# real_center   [ 2.18125735  8.50025896 10.71814646]
# predict_center [ 2.2928872 8.586295 10.808016 ]
# ---------------
# real_width    [0.50688787 0.36827209 1.45118755]
# predict_center [ 0.6378127 0.3294428 1.3297833 ]
# ---------------
# real_amp      [0.70556444 0.83061579 0.87528447]
# predict_center [ 0.73485476 0.73750806 0.89463353 ]
# real_center   [11.32216731 12.21592149 12.47563656]
# predict_center [ 11.124994 11.753789 12.581913 ]
# ---------------
# real_width    [1.72407881 0.43107301 1.55151203]
# predict_center [ 1.6660235 0.68721086 1.1043979 ]
# ---------------
# real_amp      [0.94865709 0.4982627  0.43874788]
# predict_center [ 0.68349785 0.56780523 0.59485316 ]
# real_center   [0.         2.73232357 6.5297939 ]
# predict_center [ -0.078317985 2.8019955 6.576377 ]
# ---------------
# real_width    [0.         0.63888079 1.11955369]
# predict_center [ 0.02869612 0.6057128 1.0900424 ]
# ---------------
# real_amp      [0.         0.98549499 0.47172307]
# predict_center [ 0.00017340481 0.9394773 0.49079847 ]
# real_center   [0.         2.15586652 7.31919592]
# predict_center [ -0.07377009 2.1454737 7.407654 ]
# ---------------
# real_width    [0.         1.66125493 0.97064836]
# predict_center [ 0.03009285 1.7804494 0.9185568 ]
# ---------------
# real_amp      [0.         0.50443459 0.35768513]
# predict_center [ 0.013626128 0.38336146 0.3448121 ]

# %%
plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")

# 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("P3HT Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.006077]], dtype=float32), array([[-0.25881857, 11.138528  , 11.461908  ]], dtype=float32), array([[-0.00959374,  1.5924907 ,  0.8104352 ]], dtype=float32), array([[0.04923164, 0.25227654, 0.7119303 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
# Out:
# Text(0.5, 1.0, 'Network fitting vs real XPS graph')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
# Out:
# Text(0.5, 1.0, 'Predict_peak1 vs Xps_peak1')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak2 vs Xps_peak2')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak3 vs Xps_peak3')

# %%
new_predict[1][0],new_predict[2][0],new_predict[3][0]
# Out:
# (-0.25881857, -0.00959374, 0.04923164)

# %%
new_predict[0][0]
# Out:
# 2.006077

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.006077]], dtype=float32), array([[-0.32972497,  7.447927  ,  8.236985  ]], dtype=float32), array([[0.02531074, 0.48116112, 0.62876964]], dtype=float32), array([[0.01258963, 0.46617156, 0.8539388 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')

error_peak_number_total=0
for i in range(test_peak_number.shape[0]):
    error_peak_number_total = error_peak_number_total + (abs(prediction[0][i]-test_peak_number[i]))
print('error_peak_number_total = ',error_peak_number_total)
error_peak_number = error_peak_number_total/test_peak_number.shape[0]
print('error_peak_number =  ',error_peak_number)
print('\n')
# Out:
# error_center_total =  [2565.6437716  2586.87196346 1877.25396085]
# error_center =   [0.12828219 0.1293436  0.0938627 ]
#
#
# error_width_total =  [1180.72902744 1599.45065048 1477.06018782]
# error_width =   [0.05903645 0.07997253 0.07385301]
#
#
# error_amp_total =  [ 879.53798591 1587.17521657 1273.30000653]
# error_amp =   [0.0439769  0.07935876 0.063665  ]
#
#
# error_peak_number_total =  [261.10095]
# error_peak_number =   [0.01305505]

# %%
#수정한거

# 새로운 데이터 200만개로 학습함

# %%
#할거

# 교수님꺼 model로 내 저장된 data1로 예측해보기

# %%
#예상할거

# xps의 3peak를 3개로 맞췄으면 좋겠다-> data의 부족인거같음

# %%
#결과

# 맞추지못함..
