# %%
# %ls
# Out:
# '2,3peak mix.ipynb'                    Untitled5.ipynb
# '5peak 3 para when it worksss.ipynb'   amp.csv
# 'Fitting_with_noise (1).ipynb'         center.csv
#  ITO_O1s_bg.txt                        graph.csv
#  ITO_O1s_exp.txt                       labels.png
#  ITO_O1s_fitting.txt                   model.png
#  ITO_O1s_p1.txt                        model_shapes.png
#  ITO_O1s_p2.txt                        peak_number.csv
#  ITO_O1s_p3.txt                        width.csv
#  P3HT_S2p_bg.txt                      '논문 수정.ipynb'
#  P3HT_S2p_exp.txt                     '데이터 얻기.ipynb'
#  P3HT_S2p_fitting.txt                 '저장된 데이터로 학습하기.ipynb'
#  P3HT_S2p_p1.txt                      '저장된 데이터로 학습하기2.ipynb'
#  P3HT_S2p_p2.txt                      '저장된 데이터로 학습하기3.ipynb'
#  PeakDetection.ipynb                  '저장된 데이터로 학습하기4.ipynb'
#  Untitled.ipynb                       '저장된 데이터로 학습하기5.ipynb'
#  Untitled1.ipynb                      '저장된 데이터로 학습하기6.ipynb'
#  Untitled2.ipynb                      '저장된 데이터로 학습하기7.ipynb'
#  Untitled3.ipynb                      '저장된 데이터로 학습하기8.ipynb'
#  Untitled4.ipynb                      '저장된 데이터로 학습하기9.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph.csv').values[:,1:]
center= pd.read_csv('center.csv').values[:,1:]
width= pd.read_csv('width.csv').values[:,1:]
amp= pd.read_csv('amp.csv').values[:,1:]
peak_number= pd.read_csv('peak_number.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(2000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 0.          6.08688456 11.0810396 ]
#  [ 5.07493349  8.25999368 11.36195096]
#  [ 0.          2.67516221 10.60419171]
#  [ 0.          5.54053864 12.23836258]
#  [ 0.          4.08422309  7.21849474]
#  [ 0.          7.30192691 12.34014272]
#  [ 0.          2.54016398  5.16493207]
#  [ 0.          4.67819908  6.09299318]
#  [ 4.90655934  5.13202252 10.34134357]
#  [ 0.          5.36008602  5.98285268]]
# [[0.         1.24062404 0.95374601]
#  [0.60456503 0.35785198 1.1738216 ]
#  [0.         1.17339162 1.12952083]
#  [0.         0.81456259 0.81987822]
#  [0.         0.81681444 1.70560007]
#  [0.         0.32207246 0.75414831]
#  [0.         0.30486538 1.895045  ]
#  [0.         0.59293989 0.4647601 ]
#  [1.46428848 1.12931752 1.8841104 ]
#  [0.         1.00584571 1.33599321]]
# [[0.         0.21158879 0.18180892]
#  [0.11125957 0.85593768 0.31159992]
#  [0.         0.59012228 0.71652582]
#  [0.         1.00856931 0.70388527]
#  [0.         0.94976759 0.16667863]
#  [0.         0.43501787 0.93207997]
#  [0.         0.8393851  0.5707349 ]
#  [0.         0.11555586 0.72638366]
#  [1.00347794 0.40013242 0.8164851 ]
#  [0.         0.10848772 1.08853046]]
# [2 3 2 2 2 2 2 2 3 2]
# (2000000, 3)
# (2000000, 3)
# (2000000, 3)
# (2000000,)
# (2000000, 401)
# [[ 1.65293992e-02 -1.56062971e-02 -8.67543953e-07 ...  2.55348472e-02
#   -3.85644720e-02  5.34629487e-04]
#  [ 1.77760845e-02 -1.43048937e-02  2.75018580e-03 ...  2.09525854e-02
#   -8.81444533e-03 -2.84847278e-02]
#  [ 1.36186941e-02 -1.15794033e-02  1.45041681e-02 ...  3.96018586e-02
#   -3.21144103e-03  8.85769143e-03]
#  ...
#  [-1.24151960e-02 -2.96612110e-02 -2.18882173e-02 ... -3.89587815e-02
#   -3.64336021e-02  2.78148435e-02]
#  [ 5.39405308e-03 -3.18972828e-02  3.10126407e-03 ...  1.12031471e-02
#   -4.49491273e-02  2.58940119e-03]
#  [-2.81865060e-02 -1.40640285e-02  3.61211482e-02 ... -1.77982928e-02
#   -8.35706460e-03  1.54521213e-02]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
#90:9:1
data_number=1000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (1800000, 401) (180000, 401) (20000, 401)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000,) (180000,) (20000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (1800000, 401, 1)
# (180000, 401, 1)
# (20000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
input_data = Input(shape = (len(x),1))
t = layers.Conv1D(128,100,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,50,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,20,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(16,10,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)

Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(1, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(200, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(100, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(200,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(100,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(200,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(100,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center,Dense1_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
center_Batchnormalization  = BatchNormalization()(total_center1)
# total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center2 = Dense(3, activation = 'linear',name = 'total_center2')(center_Batchnormalization)


width_merge = concatenate([Dense3_peak_number,Dense3_width,Dense1_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
width_Batchnormalization  = BatchNormalization()(total_width1)
# total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width2= Dense(3, activation = 'linear',name = 'total_width2')(width_Batchnormalization)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp,Dense1_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
amp_Batchnormalization  = BatchNormalization()(total_amp1)
# total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp2 = Dense(3, activation = 'linear',name = 'total_amp2')(amp_Batchnormalization)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center2,total_width2,total_amp2])
print(model.summary())
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 302, 128)     12928       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 151, 128)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 102, 128)     819328      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 51, 128)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 32, 128)      327808      max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 16, 128)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 7, 16)        20496       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 3, 16)        0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 16)           0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 100)          20100       Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 100)          20100       Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 100)          20100       Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 1)            201         Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           4040        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           4040        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           4040        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 241)          0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
#                                                                  Dense1_center[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 241)          0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
#                                                                  Dense1_width[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 241)          0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
#                                                                  Dense1_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           9680        concatenate[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           9680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           9680        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 40)           160         total_center1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 40)           160         total_width1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40)           160         total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 3)            123         batch_normalization[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 3)            123         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 3)            123         batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 1,336,870
# Trainable params: 1,336,630
# Non-trainable params: 240
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center2' : 'mse',
                      'total_width2' : 'mse',
                      'total_amp2' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 0.5,
#                            'total_width3' : 1,
#                            'total_amp3' : 1,
#                             'Dense3_peak_number' :1 },
              metrics = ['mae'])

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 50,
          batch_size = 1000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 5.2805 - Dense3_peak_number_loss: 0.0781 - total_center2_loss: 5.0039 - total_width2_loss: 0.1312 - total_amp2_loss: 0.0673 - Dense3_peak_number_mae: 0.1753 - total_center2_mae: 1.0678 - total_width2_mae: 0.2540 - total_amp2_mae: 0.2054 - val_loss: 0.6123 - val_Dense3_peak_number_loss: 0.0294 - val_total_center2_loss: 0.4341 - val_total_width2_loss: 0.0859 - val_total_amp2_loss: 0.0629 - val_Dense3_peak_number_mae: 0.0958 - val_total_center2_mae: 0.3570 - val_total_width2_mae: 0.2137 - val_total_amp2_mae: 0.1938
# Epoch 2/50
# 1800/1800 [==============================] - 96s 54ms/step - loss: 0.3620 - Dense3_peak_number_loss: 0.0120 - total_center2_loss: 0.2357 - total_width2_loss: 0.0602 - total_amp2_loss: 0.0541 - Dense3_peak_number_mae: 0.0521 - total_center2_mae: 0.2585 - total_width2_mae: 0.1702 - total_amp2_mae: 0.1802 - val_loss: 0.4212 - val_Dense3_peak_number_loss: 0.0081 - val_total_center2_loss: 0.2925 - val_total_width2_loss: 0.0654 - val_total_amp2_loss: 0.0552 - val_Dense3_peak_number_mae: 0.0525 - val_total_center2_mae: 0.3589 - val_total_width2_mae: 0.1787 - val_total_amp2_mae: 0.1798
# Epoch 3/50
# 1800/1800 [==============================] - 96s 53ms/step - loss: 0.3083 - Dense3_peak_number_loss: 0.0087 - total_center2_loss: 0.1948 - total_width2_loss: 0.0527 - total_amp2_loss: 0.0521 - Dense3_peak_number_mae: 0.0411 - total_center2_mae: 0.2288 - total_width2_mae: 0.1564 - total_amp2_mae: 0.1753 - val_loss: 0.2892 - val_Dense3_peak_number_loss: 0.0058 - val_total_center2_loss: 0.1841 - val_total_width2_loss: 0.0496 - val_total_amp2_loss: 0.0497 - val_Dense3_peak_number_mae: 0.0281 - val_total_center2_mae: 0.2228 - val_total_width2_mae: 0.1478 - val_total_amp2_mae: 0.1728
# Epoch 4/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.2527 - Dense3_peak_number_loss: 0.0074 - total_center2_loss: 0.1647 - total_width2_loss: 0.0416 - total_amp2_loss: 0.0391 - Dense3_peak_number_mae: 0.0382 - total_center2_mae: 0.2072 - total_width2_mae: 0.1370 - total_amp2_mae: 0.1468 - val_loss: 0.2062 - val_Dense3_peak_number_loss: 0.0035 - val_total_center2_loss: 0.1293 - val_total_width2_loss: 0.0363 - val_total_amp2_loss: 0.0371 - val_Dense3_peak_number_mae: 0.0188 - val_total_center2_mae: 0.1886 - val_total_width2_mae: 0.1271 - val_total_amp2_mae: 0.1428
# Epoch 5/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.2208 - Dense3_peak_number_loss: 0.0061 - total_center2_loss: 0.1423 - total_width2_loss: 0.0355 - total_amp2_loss: 0.0370 - Dense3_peak_number_mae: 0.0350 - total_center2_mae: 0.1915 - total_width2_mae: 0.1253 - total_amp2_mae: 0.1409 - val_loss: 0.1952 - val_Dense3_peak_number_loss: 0.0045 - val_total_center2_loss: 0.1222 - val_total_width2_loss: 0.0334 - val_total_amp2_loss: 0.0350 - val_Dense3_peak_number_mae: 0.0272 - val_total_center2_mae: 0.1817 - val_total_width2_mae: 0.1205 - val_total_amp2_mae: 0.1348
# Epoch 6/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.2141 - Dense3_peak_number_loss: 0.0060 - total_center2_loss: 0.1377 - total_width2_loss: 0.0340 - total_amp2_loss: 0.0364 - Dense3_peak_number_mae: 0.0346 - total_center2_mae: 0.1867 - total_width2_mae: 0.1223 - total_amp2_mae: 0.1391 - val_loss: 0.2030 - val_Dense3_peak_number_loss: 0.0044 - val_total_center2_loss: 0.1322 - val_total_width2_loss: 0.0317 - val_total_amp2_loss: 0.0347 - val_Dense3_peak_number_mae: 0.0330 - val_total_center2_mae: 0.1797 - val_total_width2_mae: 0.1172 - val_total_amp2_mae: 0.1347
# Epoch 7/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1921 - Dense3_peak_number_loss: 0.0047 - total_center2_loss: 0.1215 - total_width2_loss: 0.0308 - total_amp2_loss: 0.0351 - Dense3_peak_number_mae: 0.0279 - total_center2_mae: 0.1749 - total_width2_mae: 0.1157 - total_amp2_mae: 0.1355 - val_loss: 0.1873 - val_Dense3_peak_number_loss: 0.0042 - val_total_center2_loss: 0.1167 - val_total_width2_loss: 0.0324 - val_total_amp2_loss: 0.0339 - val_Dense3_peak_number_mae: 0.0292 - val_total_center2_mae: 0.1734 - val_total_width2_mae: 0.1204 - val_total_amp2_mae: 0.1322
# Epoch 8/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1788 - Dense3_peak_number_loss: 0.0041 - total_center2_loss: 0.1113 - total_width2_loss: 0.0291 - total_amp2_loss: 0.0342 - Dense3_peak_number_mae: 0.0263 - total_center2_mae: 0.1672 - total_width2_mae: 0.1122 - total_amp2_mae: 0.1331 - val_loss: 0.2402 - val_Dense3_peak_number_loss: 0.0067 - val_total_center2_loss: 0.1659 - val_total_width2_loss: 0.0330 - val_total_amp2_loss: 0.0346 - val_Dense3_peak_number_mae: 0.0340 - val_total_center2_mae: 0.1889 - val_total_width2_mae: 0.1187 - val_total_amp2_mae: 0.1320
# Epoch 9/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1739 - Dense3_peak_number_loss: 0.0040 - total_center2_loss: 0.1076 - total_width2_loss: 0.0285 - total_amp2_loss: 0.0338 - Dense3_peak_number_mae: 0.0260 - total_center2_mae: 0.1651 - total_width2_mae: 0.1107 - total_amp2_mae: 0.1320 - val_loss: 0.2106 - val_Dense3_peak_number_loss: 0.0036 - val_total_center2_loss: 0.1394 - val_total_width2_loss: 0.0325 - val_total_amp2_loss: 0.0351 - val_Dense3_peak_number_mae: 0.0277 - val_total_center2_mae: 0.2163 - val_total_width2_mae: 0.1238 - val_total_amp2_mae: 0.1353
# Epoch 10/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1610 - Dense3_peak_number_loss: 0.0033 - total_center2_loss: 0.0978 - total_width2_loss: 0.0269 - total_amp2_loss: 0.0330 - Dense3_peak_number_mae: 0.0239 - total_center2_mae: 0.1586 - total_width2_mae: 0.1073 - total_amp2_mae: 0.1298 - val_loss: 0.2843 - val_Dense3_peak_number_loss: 0.0101 - val_total_center2_loss: 0.2043 - val_total_width2_loss: 0.0332 - val_total_amp2_loss: 0.0367 - val_Dense3_peak_number_mae: 0.0493 - val_total_center2_mae: 0.2188 - val_total_width2_mae: 0.1214 - val_total_amp2_mae: 0.1408
# Epoch 11/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1577 - Dense3_peak_number_loss: 0.0033 - total_center2_loss: 0.0955 - total_width2_loss: 0.0264 - total_amp2_loss: 0.0325 - Dense3_peak_number_mae: 0.0233 - total_center2_mae: 0.1562 - total_width2_mae: 0.1061 - total_amp2_mae: 0.1282 - val_loss: 0.1476 - val_Dense3_peak_number_loss: 0.0025 - val_total_center2_loss: 0.0852 - val_total_width2_loss: 0.0281 - val_total_amp2_loss: 0.0319 - val_Dense3_peak_number_mae: 0.0180 - val_total_center2_mae: 0.1361 - val_total_width2_mae: 0.1132 - val_total_amp2_mae: 0.1280
# Epoch 12/50
# 1800/1800 [==============================] - 96s 53ms/step - loss: 0.1527 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0918 - total_width2_loss: 0.0258 - total_amp2_loss: 0.0320 - Dense3_peak_number_mae: 0.0234 - total_center2_mae: 0.1538 - total_width2_mae: 0.1049 - total_amp2_mae: 0.1271 - val_loss: 0.1533 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0949 - val_total_width2_loss: 0.0241 - val_total_amp2_loss: 0.0321 - val_Dense3_peak_number_mae: 0.0245 - val_total_center2_mae: 0.1604 - val_total_width2_mae: 0.1004 - val_total_amp2_mae: 0.1259
# Epoch 13/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1470 - Dense3_peak_number_loss: 0.0029 - total_center2_loss: 0.0874 - total_width2_loss: 0.0252 - total_amp2_loss: 0.0315 - Dense3_peak_number_mae: 0.0227 - total_center2_mae: 0.1507 - total_width2_mae: 0.1037 - total_amp2_mae: 0.1255 - val_loss: 0.1345 - val_Dense3_peak_number_loss: 0.0024 - val_total_center2_loss: 0.0776 - val_total_width2_loss: 0.0238 - val_total_amp2_loss: 0.0308 - val_Dense3_peak_number_mae: 0.0103 - val_total_center2_mae: 0.1200 - val_total_width2_mae: 0.0997 - val_total_amp2_mae: 0.1235
# Epoch 14/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1443 - Dense3_peak_number_loss: 0.0028 - total_center2_loss: 0.0857 - total_width2_loss: 0.0247 - total_amp2_loss: 0.0312 - Dense3_peak_number_mae: 0.0223 - total_center2_mae: 0.1499 - total_width2_mae: 0.1027 - total_amp2_mae: 0.1247 - val_loss: 0.1548 - val_Dense3_peak_number_loss: 0.0037 - val_total_center2_loss: 0.0897 - val_total_width2_loss: 0.0271 - val_total_amp2_loss: 0.0342 - val_Dense3_peak_number_mae: 0.0357 - val_total_center2_mae: 0.1305 - val_total_width2_mae: 0.1137 - val_total_amp2_mae: 0.1298
# Epoch 15/50
# 1800/1800 [==============================] - 96s 53ms/step - loss: 0.1398 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0821 - total_width2_loss: 0.0242 - total_amp2_loss: 0.0309 - Dense3_peak_number_mae: 0.0220 - total_center2_mae: 0.1471 - total_width2_mae: 0.1018 - total_amp2_mae: 0.1239 - val_loss: 0.1429 - val_Dense3_peak_number_loss: 0.0035 - val_total_center2_loss: 0.0846 - val_total_width2_loss: 0.0233 - val_total_amp2_loss: 0.0315 - val_Dense3_peak_number_mae: 0.0301 - val_total_center2_mae: 0.1311 - val_total_width2_mae: 0.0998 - val_total_amp2_mae: 0.1251
# Epoch 16/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1336 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0774 - total_width2_loss: 0.0236 - total_amp2_loss: 0.0302 - Dense3_peak_number_mae: 0.0202 - total_center2_mae: 0.1439 - total_width2_mae: 0.1003 - total_amp2_mae: 0.1221 - val_loss: 0.1479 - val_Dense3_peak_number_loss: 0.0031 - val_total_center2_loss: 0.0880 - val_total_width2_loss: 0.0268 - val_total_amp2_loss: 0.0299 - val_Dense3_peak_number_mae: 0.0262 - val_total_center2_mae: 0.1391 - val_total_width2_mae: 0.1085 - val_total_amp2_mae: 0.1195
# Epoch 17/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1311 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0756 - total_width2_loss: 0.0232 - total_amp2_loss: 0.0300 - Dense3_peak_number_mae: 0.0194 - total_center2_mae: 0.1431 - total_width2_mae: 0.0994 - total_amp2_mae: 0.1213 - val_loss: 0.1501 - val_Dense3_peak_number_loss: 0.0034 - val_total_center2_loss: 0.0931 - val_total_width2_loss: 0.0242 - val_total_amp2_loss: 0.0293 - val_Dense3_peak_number_mae: 0.0272 - val_total_center2_mae: 0.1602 - val_total_width2_mae: 0.1001 - val_total_amp2_mae: 0.1180
# Epoch 18/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1298 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0746 - total_width2_loss: 0.0231 - total_amp2_loss: 0.0297 - Dense3_peak_number_mae: 0.0200 - total_center2_mae: 0.1426 - total_width2_mae: 0.0993 - total_amp2_mae: 0.1208 - val_loss: 0.1272 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0736 - val_total_width2_loss: 0.0227 - val_total_amp2_loss: 0.0290 - val_Dense3_peak_number_mae: 0.0110 - val_total_center2_mae: 0.1197 - val_total_width2_mae: 0.0973 - val_total_amp2_mae: 0.1183
# Epoch 19/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1253 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0711 - total_width2_loss: 0.0227 - total_amp2_loss: 0.0294 - Dense3_peak_number_mae: 0.0186 - total_center2_mae: 0.1397 - total_width2_mae: 0.0984 - total_amp2_mae: 0.1199 - val_loss: 0.1347 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0770 - val_total_width2_loss: 0.0262 - val_total_amp2_loss: 0.0300 - val_Dense3_peak_number_mae: 0.0071 - val_total_center2_mae: 0.1393 - val_total_width2_mae: 0.1096 - val_total_amp2_mae: 0.1223
# Epoch 20/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1263 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0718 - total_width2_loss: 0.0229 - total_amp2_loss: 0.0294 - Dense3_peak_number_mae: 0.0195 - total_center2_mae: 0.1408 - total_width2_mae: 0.0990 - total_amp2_mae: 0.1198 - val_loss: 0.1219 - val_Dense3_peak_number_loss: 0.0022 - val_total_center2_loss: 0.0691 - val_total_width2_loss: 0.0225 - val_total_amp2_loss: 0.0281 - val_Dense3_peak_number_mae: 0.0233 - val_total_center2_mae: 0.1088 - val_total_width2_mae: 0.0991 - val_total_amp2_mae: 0.1165
# Epoch 21/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1193 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0664 - total_width2_loss: 0.0222 - total_amp2_loss: 0.0289 - Dense3_peak_number_mae: 0.0175 - total_center2_mae: 0.1367 - total_width2_mae: 0.0971 - total_amp2_mae: 0.1184 - val_loss: 0.1265 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0728 - val_total_width2_loss: 0.0217 - val_total_amp2_loss: 0.0303 - val_Dense3_peak_number_mae: 0.0121 - val_total_center2_mae: 0.1141 - val_total_width2_mae: 0.0942 - val_total_amp2_mae: 0.1224
# Epoch 22/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1210 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0680 - total_width2_loss: 0.0222 - total_amp2_loss: 0.0288 - Dense3_peak_number_mae: 0.0178 - total_center2_mae: 0.1386 - total_width2_mae: 0.0973 - total_amp2_mae: 0.1181 - val_loss: 0.1664 - val_Dense3_peak_number_loss: 0.0030 - val_total_center2_loss: 0.1062 - val_total_width2_loss: 0.0263 - val_total_amp2_loss: 0.0309 - val_Dense3_peak_number_mae: 0.0183 - val_total_center2_mae: 0.1676 - val_total_width2_mae: 0.1073 - val_total_amp2_mae: 0.1249
# Epoch 23/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1180 - Dense3_peak_number_loss: 0.0019 - total_center2_loss: 0.0654 - total_width2_loss: 0.0220 - total_amp2_loss: 0.0286 - Dense3_peak_number_mae: 0.0167 - total_center2_mae: 0.1367 - total_width2_mae: 0.0968 - total_amp2_mae: 0.1177 - val_loss: 0.1447 - val_Dense3_peak_number_loss: 0.0055 - val_total_center2_loss: 0.0850 - val_total_width2_loss: 0.0249 - val_total_amp2_loss: 0.0292 - val_Dense3_peak_number_mae: 0.0455 - val_total_center2_mae: 0.1348 - val_total_width2_mae: 0.1020 - val_total_amp2_mae: 0.1180
# Epoch 24/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1114 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0601 - total_width2_loss: 0.0215 - total_amp2_loss: 0.0282 - Dense3_peak_number_mae: 0.0148 - total_center2_mae: 0.1332 - total_width2_mae: 0.0958 - total_amp2_mae: 0.1166 - val_loss: 0.1543 - val_Dense3_peak_number_loss: 0.0037 - val_total_center2_loss: 0.0983 - val_total_width2_loss: 0.0233 - val_total_amp2_loss: 0.0291 - val_Dense3_peak_number_mae: 0.0161 - val_total_center2_mae: 0.1408 - val_total_width2_mae: 0.0964 - val_total_amp2_mae: 0.1179
# Epoch 25/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1142 - Dense3_peak_number_loss: 0.0018 - total_center2_loss: 0.0621 - total_width2_loss: 0.0218 - total_amp2_loss: 0.0285 - Dense3_peak_number_mae: 0.0163 - total_center2_mae: 0.1338 - total_width2_mae: 0.0964 - total_amp2_mae: 0.1176 - val_loss: 0.1242 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0709 - val_total_width2_loss: 0.0231 - val_total_amp2_loss: 0.0281 - val_Dense3_peak_number_mae: 0.0182 - val_total_center2_mae: 0.1112 - val_total_width2_mae: 0.0998 - val_total_amp2_mae: 0.1158
# Epoch 26/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1113 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0601 - total_width2_loss: 0.0214 - total_amp2_loss: 0.0282 - Dense3_peak_number_mae: 0.0161 - total_center2_mae: 0.1341 - total_width2_mae: 0.0954 - total_amp2_mae: 0.1164 - val_loss: 0.1321 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0791 - val_total_width2_loss: 0.0223 - val_total_amp2_loss: 0.0287 - val_Dense3_peak_number_mae: 0.0154 - val_total_center2_mae: 0.1246 - val_total_width2_mae: 0.0967 - val_total_amp2_mae: 0.1176
# Epoch 27/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1089 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0582 - total_width2_loss: 0.0212 - total_amp2_loss: 0.0280 - Dense3_peak_number_mae: 0.0145 - total_center2_mae: 0.1316 - total_width2_mae: 0.0951 - total_amp2_mae: 0.1158 - val_loss: 0.1201 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0703 - val_total_width2_loss: 0.0209 - val_total_amp2_loss: 0.0272 - val_Dense3_peak_number_mae: 0.0079 - val_total_center2_mae: 0.1099 - val_total_width2_mae: 0.0923 - val_total_amp2_mae: 0.1135
# Epoch 28/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1081 - Dense3_peak_number_loss: 0.0017 - total_center2_loss: 0.0575 - total_width2_loss: 0.0210 - total_amp2_loss: 0.0278 - Dense3_peak_number_mae: 0.0149 - total_center2_mae: 0.1310 - total_width2_mae: 0.0946 - total_amp2_mae: 0.1154 - val_loss: 0.1211 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0692 - val_total_width2_loss: 0.0217 - val_total_amp2_loss: 0.0282 - val_Dense3_peak_number_mae: 0.0137 - val_total_center2_mae: 0.1056 - val_total_width2_mae: 0.0941 - val_total_amp2_mae: 0.1164
# Epoch 29/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1052 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0550 - total_width2_loss: 0.0209 - total_amp2_loss: 0.0276 - Dense3_peak_number_mae: 0.0147 - total_center2_mae: 0.1300 - total_width2_mae: 0.0944 - total_amp2_mae: 0.1149 - val_loss: 0.1214 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0706 - val_total_width2_loss: 0.0212 - val_total_amp2_loss: 0.0279 - val_Dense3_peak_number_mae: 0.0091 - val_total_center2_mae: 0.1130 - val_total_width2_mae: 0.0946 - val_total_amp2_mae: 0.1154
# Epoch 30/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1058 - Dense3_peak_number_loss: 0.0016 - total_center2_loss: 0.0549 - total_width2_loss: 0.0212 - total_amp2_loss: 0.0281 - Dense3_peak_number_mae: 0.0130 - total_center2_mae: 0.1295 - total_width2_mae: 0.0950 - total_amp2_mae: 0.1160 - val_loss: 0.1426 - val_Dense3_peak_number_loss: 0.0028 - val_total_center2_loss: 0.0831 - val_total_width2_loss: 0.0262 - val_total_amp2_loss: 0.0305 - val_Dense3_peak_number_mae: 0.0248 - val_total_center2_mae: 0.1179 - val_total_width2_mae: 0.1094 - val_total_amp2_mae: 0.1221
# Epoch 31/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1037 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0539 - total_width2_loss: 0.0206 - total_amp2_loss: 0.0276 - Dense3_peak_number_mae: 0.0137 - total_center2_mae: 0.1283 - total_width2_mae: 0.0937 - total_amp2_mae: 0.1147 - val_loss: 0.1247 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0748 - val_total_width2_loss: 0.0207 - val_total_amp2_loss: 0.0270 - val_Dense3_peak_number_mae: 0.0151 - val_total_center2_mae: 0.1203 - val_total_width2_mae: 0.0928 - val_total_amp2_mae: 0.1116
# Epoch 32/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1029 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0535 - total_width2_loss: 0.0205 - total_amp2_loss: 0.0274 - Dense3_peak_number_mae: 0.0134 - total_center2_mae: 0.1281 - total_width2_mae: 0.0934 - total_amp2_mae: 0.1142 - val_loss: 0.1172 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0679 - val_total_width2_loss: 0.0202 - val_total_amp2_loss: 0.0273 - val_Dense3_peak_number_mae: 0.0134 - val_total_center2_mae: 0.1125 - val_total_width2_mae: 0.0920 - val_total_amp2_mae: 0.1125
# Epoch 33/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1011 - Dense3_peak_number_loss: 0.0015 - total_center2_loss: 0.0522 - total_width2_loss: 0.0203 - total_amp2_loss: 0.0271 - Dense3_peak_number_mae: 0.0132 - total_center2_mae: 0.1277 - total_width2_mae: 0.0930 - total_amp2_mae: 0.1133 - val_loss: 0.1139 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0656 - val_total_width2_loss: 0.0200 - val_total_amp2_loss: 0.0267 - val_Dense3_peak_number_mae: 0.0071 - val_total_center2_mae: 0.0963 - val_total_width2_mae: 0.0895 - val_total_amp2_mae: 0.1117
# Epoch 34/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.1012 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0519 - total_width2_loss: 0.0208 - total_amp2_loss: 0.0272 - Dense3_peak_number_mae: 0.0126 - total_center2_mae: 0.1281 - total_width2_mae: 0.0943 - total_amp2_mae: 0.1135 - val_loss: 0.1174 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0682 - val_total_width2_loss: 0.0210 - val_total_amp2_loss: 0.0268 - val_Dense3_peak_number_mae: 0.0078 - val_total_center2_mae: 0.1084 - val_total_width2_mae: 0.0971 - val_total_amp2_mae: 0.1134
# Epoch 35/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0992 - Dense3_peak_number_loss: 0.0014 - total_center2_loss: 0.0506 - total_width2_loss: 0.0202 - total_amp2_loss: 0.0270 - Dense3_peak_number_mae: 0.0121 - total_center2_mae: 0.1256 - total_width2_mae: 0.0929 - total_amp2_mae: 0.1129 - val_loss: 0.1204 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0705 - val_total_width2_loss: 0.0210 - val_total_amp2_loss: 0.0272 - val_Dense3_peak_number_mae: 0.0137 - val_total_center2_mae: 0.1024 - val_total_width2_mae: 0.0929 - val_total_amp2_mae: 0.1139
# Epoch 36/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0982 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0497 - total_width2_loss: 0.0202 - total_amp2_loss: 0.0271 - Dense3_peak_number_mae: 0.0125 - total_center2_mae: 0.1268 - total_width2_mae: 0.0927 - total_amp2_mae: 0.1132 - val_loss: 0.1247 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0734 - val_total_width2_loss: 0.0216 - val_total_amp2_loss: 0.0279 - val_Dense3_peak_number_mae: 0.0107 - val_total_center2_mae: 0.1036 - val_total_width2_mae: 0.0947 - val_total_amp2_mae: 0.1147
# Epoch 37/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0984 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0500 - total_width2_loss: 0.0200 - total_amp2_loss: 0.0270 - Dense3_peak_number_mae: 0.0123 - total_center2_mae: 0.1261 - total_width2_mae: 0.0924 - total_amp2_mae: 0.1131 - val_loss: 0.1259 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0753 - val_total_width2_loss: 0.0211 - val_total_amp2_loss: 0.0276 - val_Dense3_peak_number_mae: 0.0104 - val_total_center2_mae: 0.1125 - val_total_width2_mae: 0.0927 - val_total_amp2_mae: 0.1145
# Epoch 38/50
# 1800/1800 [==============================] - 96s 53ms/step - loss: 0.0963 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0485 - total_width2_loss: 0.0198 - total_amp2_loss: 0.0267 - Dense3_peak_number_mae: 0.0123 - total_center2_mae: 0.1256 - total_width2_mae: 0.0919 - total_amp2_mae: 0.1123 - val_loss: 0.1337 - val_Dense3_peak_number_loss: 0.0032 - val_total_center2_loss: 0.0819 - val_total_width2_loss: 0.0216 - val_total_amp2_loss: 0.0271 - val_Dense3_peak_number_mae: 0.0293 - val_total_center2_mae: 0.1054 - val_total_width2_mae: 0.0954 - val_total_amp2_mae: 0.1136
# Epoch 39/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0946 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0471 - total_width2_loss: 0.0197 - total_amp2_loss: 0.0267 - Dense3_peak_number_mae: 0.0117 - total_center2_mae: 0.1237 - total_width2_mae: 0.0915 - total_amp2_mae: 0.1121 - val_loss: 0.1466 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0932 - val_total_width2_loss: 0.0232 - val_total_amp2_loss: 0.0279 - val_Dense3_peak_number_mae: 0.0074 - val_total_center2_mae: 0.1370 - val_total_width2_mae: 0.1000 - val_total_amp2_mae: 0.1152
# Epoch 40/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0946 - Dense3_peak_number_loss: 0.0013 - total_center2_loss: 0.0471 - total_width2_loss: 0.0196 - total_amp2_loss: 0.0266 - Dense3_peak_number_mae: 0.0114 - total_center2_mae: 0.1235 - total_width2_mae: 0.0912 - total_amp2_mae: 0.1119 - val_loss: 0.1657 - val_Dense3_peak_number_loss: 0.0051 - val_total_center2_loss: 0.1081 - val_total_width2_loss: 0.0248 - val_total_amp2_loss: 0.0276 - val_Dense3_peak_number_mae: 0.0270 - val_total_center2_mae: 0.1317 - val_total_width2_mae: 0.0986 - val_total_amp2_mae: 0.1119
# Epoch 41/50
# 1800/1800 [==============================] - 96s 53ms/step - loss: 0.0917 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0450 - total_width2_loss: 0.0192 - total_amp2_loss: 0.0263 - Dense3_peak_number_mae: 0.0108 - total_center2_mae: 0.1227 - total_width2_mae: 0.0906 - total_amp2_mae: 0.1111 - val_loss: 0.1302 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0798 - val_total_width2_loss: 0.0215 - val_total_amp2_loss: 0.0272 - val_Dense3_peak_number_mae: 0.0067 - val_total_center2_mae: 0.1073 - val_total_width2_mae: 0.0948 - val_total_amp2_mae: 0.1130
# Epoch 42/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0925 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0455 - total_width2_loss: 0.0194 - total_amp2_loss: 0.0264 - Dense3_peak_number_mae: 0.0116 - total_center2_mae: 0.1233 - total_width2_mae: 0.0909 - total_amp2_mae: 0.1113 - val_loss: 0.1157 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0674 - val_total_width2_loss: 0.0200 - val_total_amp2_loss: 0.0266 - val_Dense3_peak_number_mae: 0.0095 - val_total_center2_mae: 0.1184 - val_total_width2_mae: 0.0912 - val_total_amp2_mae: 0.1104
# Epoch 43/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0925 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0457 - total_width2_loss: 0.0193 - total_amp2_loss: 0.0263 - Dense3_peak_number_mae: 0.0106 - total_center2_mae: 0.1227 - total_width2_mae: 0.0906 - total_amp2_mae: 0.1111 - val_loss: 0.1153 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0682 - val_total_width2_loss: 0.0190 - val_total_amp2_loss: 0.0266 - val_Dense3_peak_number_mae: 0.0123 - val_total_center2_mae: 0.1006 - val_total_width2_mae: 0.0872 - val_total_amp2_mae: 0.1114
# Epoch 44/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0903 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0439 - total_width2_loss: 0.0191 - total_amp2_loss: 0.0261 - Dense3_peak_number_mae: 0.0108 - total_center2_mae: 0.1215 - total_width2_mae: 0.0902 - total_amp2_mae: 0.1102 - val_loss: 0.1204 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0724 - val_total_width2_loss: 0.0198 - val_total_amp2_loss: 0.0266 - val_Dense3_peak_number_mae: 0.0103 - val_total_center2_mae: 0.1036 - val_total_width2_mae: 0.0902 - val_total_amp2_mae: 0.1123
# Epoch 45/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0895 - Dense3_peak_number_loss: 0.0012 - total_center2_loss: 0.0431 - total_width2_loss: 0.0191 - total_amp2_loss: 0.0261 - Dense3_peak_number_mae: 0.0108 - total_center2_mae: 0.1195 - total_width2_mae: 0.0901 - total_amp2_mae: 0.1104 - val_loss: 0.1153 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0680 - val_total_width2_loss: 0.0196 - val_total_amp2_loss: 0.0261 - val_Dense3_peak_number_mae: 0.0119 - val_total_center2_mae: 0.0982 - val_total_width2_mae: 0.0892 - val_total_amp2_mae: 0.1089
# Epoch 46/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0914 - Dense3_peak_number_loss: 0.0010 - total_center2_loss: 0.0444 - total_width2_loss: 0.0197 - total_amp2_loss: 0.0263 - Dense3_peak_number_mae: 0.0094 - total_center2_mae: 0.1232 - total_width2_mae: 0.0915 - total_amp2_mae: 0.1108 - val_loss: 0.1650 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0914 - val_total_width2_loss: 0.0429 - val_total_amp2_loss: 0.0286 - val_Dense3_peak_number_mae: 0.0077 - val_total_center2_mae: 0.1340 - val_total_width2_mae: 0.1530 - val_total_amp2_mae: 0.1158
# Epoch 47/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0919 - Dense3_peak_number_loss: 0.0011 - total_center2_loss: 0.0445 - total_width2_loss: 0.0199 - total_amp2_loss: 0.0265 - Dense3_peak_number_mae: 0.0109 - total_center2_mae: 0.1228 - total_width2_mae: 0.0925 - total_amp2_mae: 0.1115 - val_loss: 0.1263 - val_Dense3_peak_number_loss: 0.0027 - val_total_center2_loss: 0.0761 - val_total_width2_loss: 0.0207 - val_total_amp2_loss: 0.0269 - val_Dense3_peak_number_mae: 0.0100 - val_total_center2_mae: 0.1084 - val_total_width2_mae: 0.0901 - val_total_amp2_mae: 0.1104
# Epoch 48/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0874 - Dense3_peak_number_loss: 9.9142e-04 - total_center2_loss: 0.0418 - total_width2_loss: 0.0188 - total_amp2_loss: 0.0259 - Dense3_peak_number_mae: 0.0104 - total_center2_mae: 0.1199 - total_width2_mae: 0.0894 - total_amp2_mae: 0.1095 - val_loss: 0.1105 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0654 - val_total_width2_loss: 0.0187 - val_total_amp2_loss: 0.0251 - val_Dense3_peak_number_mae: 0.0089 - val_total_center2_mae: 0.0998 - val_total_width2_mae: 0.0861 - val_total_amp2_mae: 0.1057
# Epoch 49/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0885 - Dense3_peak_number_loss: 0.0011 - total_center2_loss: 0.0426 - total_width2_loss: 0.0189 - total_amp2_loss: 0.0259 - Dense3_peak_number_mae: 0.0098 - total_center2_mae: 0.1198 - total_width2_mae: 0.0895 - total_amp2_mae: 0.1097 - val_loss: 0.1139 - val_Dense3_peak_number_loss: 0.0013 - val_total_center2_loss: 0.0671 - val_total_width2_loss: 0.0193 - val_total_amp2_loss: 0.0260 - val_Dense3_peak_number_mae: 0.0054 - val_total_center2_mae: 0.1021 - val_total_width2_mae: 0.0910 - val_total_amp2_mae: 0.1087
# Epoch 50/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.0842 - Dense3_peak_number_loss: 0.0010 - total_center2_loss: 0.0395 - total_width2_loss: 0.0183 - total_amp2_loss: 0.0254 - Dense3_peak_number_mae: 0.0101 - total_center2_mae: 0.1180 - total_width2_mae: 0.0880 - total_amp2_mae: 0.1082 - val_loss: 0.1499 - val_Dense3_peak_number_loss: 0.0025 - val_total_center2_loss: 0.0996 - val_total_width2_loss: 0.0207 - val_total_amp2_loss: 0.0271 - val_Dense3_peak_number_mae: 0.0124 - val_total_center2_mae: 0.1340 - val_total_width2_mae: 0.0941 - val_total_amp2_mae: 0.1124

# %%
test_graph.shape
# Out:
# (20000, 401, 1)

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp2_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (20000, 1)
# (20000, 3)
# (20000, 3)
# (20000, 3)

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,color='black')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'blue')
    plt.grid(True)
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
# Out:
# real_center   [ 0.          5.71315308 11.91923309]
# predict_center [ 0.94554514 6.701967 12.011297 ]
# ---------------
# real_width    [0.         0.84337558 1.79121459]
# predict_center [ 0.17178538 1.0497136 1.7606549 ]
# ---------------
# real_amp      [0.         0.88023975 1.04841723]
# predict_center [ 0.19582365 0.87447053 0.85070133 ]
# real_center   [ 0.          6.39994478 12.93951819]
# predict_center [ 0.052958608 6.247101 13.003166 ]
# ---------------
# real_width    [0.         1.65652237 0.93438808]
# predict_center [ 0.011775166 1.7328932 0.9357531 ]
# ---------------
# real_amp      [0.         0.99348086 0.9478093 ]
# predict_center [ 0.010381132 1.0408014 0.95318127 ]
# real_center   [ 3.23631434  6.18606995 12.52827948]
# predict_center [ 3.2015107 6.0816317 12.72473 ]
# ---------------
# real_width    [1.66278035 1.68069287 1.00126402]
# predict_center [ 1.6173596 1.5106952 0.9599036 ]
# ---------------
# real_amp      [0.17531519 0.19742663 0.9243484 ]
# predict_center [ 0.4936775 0.36068296 0.4015441 ]
# real_center   [ 0.          3.86715569 10.86221601]
# predict_center [ 0.012943983 3.8860767 10.909689 ]
# ---------------
# real_width    [0.         0.59165533 0.40581259]
# predict_center [ 0.010624409 0.65132034 0.3850696 ]
# ---------------
# real_amp      [0.         0.51955378 0.53934786]
# predict_center [ 0.0007504821 0.6496197 0.52332056 ]
# real_center   [ 0.          9.45233636 12.62868582]
# predict_center [ -0.013401985 9.536706 12.55273 ]
# ---------------
# real_width    [0.         1.44668865 1.87998592]
# predict_center [ 0.013395891 1.4811859 1.7618219 ]
# ---------------
# real_amp      [0.         0.91245941 0.36050666]
# predict_center [ 0.00087337196 0.94136196 0.5067254 ]
# real_center   [0.         2.00332775 6.03248714]
# predict_center [ -0.021124586 2.0885782 6.2276173 ]
# ---------------
# real_width    [0.         0.59737084 0.7272154 ]
# predict_center [ 0.008261815 0.67981213 0.7665802 ]
# ---------------
# real_amp      [0.         0.90353073 0.66262424]
# predict_center [ -0.0023912042 0.87026244 0.75679237 ]
# real_center   [ 0.         11.42268043 12.25882526]
# predict_center [ -0.01790002 11.368254 12.432786 ]
# ---------------
# real_width    [0.         0.75334379 1.47571775]
# predict_center [ 0.037120372 0.79790145 1.2929914 ]
# ---------------
# real_amp      [0.         0.59638167 0.17278906]
# predict_center [ 0.003977686 0.6425133 0.18847518 ]
# real_center   [ 2.57538501  2.73040878 12.45116549]
# predict_center [ 2.2346783 2.6563494 12.545046 ]
# ---------------
# real_width    [0.41405293 0.60919744 1.12779081]
# predict_center [ 0.36523658 0.4134876 1.3070078 ]
# ---------------
# real_amp      [0.5085511  0.80758984 0.70893355]
# predict_center [ 0.7333935 0.54734844 0.5124753 ]
# real_center   [ 2.9017155   7.54113871 10.03829508]
# predict_center [ 2.8995383 7.488797 10.140456 ]
# ---------------
# real_width    [0.3609779 1.5868491 1.5857514]
# predict_center [ 0.46683222 1.4922662 1.6106293 ]
# ---------------
# real_amp      [0.9967733  0.57811673 0.29408781]
# predict_center [ 1.0241158 0.427141 0.6400724 ]
# real_center   [5.70187413 6.47325447 7.95269075]
# predict_center [ 5.713614 6.338634 8.162185 ]
# ---------------
# real_width    [0.35270478 1.15793397 1.67777024]
# predict_center [ 0.730691 0.84796077 1.6167719 ]
# ---------------
# real_amp      [0.28978847 0.72433166 0.41654231]
# predict_center [ 0.5223895 0.56618446 0.6321856 ]
# real_center   [ 0.          4.21687094 12.34120659]
# predict_center [ 0.0069417357 4.2755284 12.331856 ]
# ---------------
# real_width    [0.         0.36773928 0.81390437]
# predict_center [ 0.0062505156 0.481621 0.83266044 ]
# ---------------
# real_amp      [0.         0.78705796 0.79347587]
# predict_center [ 3.157556e-05 0.8473807 0.7961649 ]
# real_center   [ 7.64690374  7.88672447 11.75998207]
# predict_center [ 7.494009 8.016079 12.02022 ]
# ---------------
# real_width    [1.57721792 0.35065511 1.76987164]
# predict_center [ 1.164921 0.653738 1.7149603 ]
# ---------------
# real_amp      [0.15874303 0.52349397 0.94926077]
# predict_center [ 0.34137285 0.52734953 0.7167073 ]
# real_center   [2.97550177 6.17211837 8.66438667]
# predict_center [ 2.8750875 6.3689437 8.885149 ]
# ---------------
# real_width    [1.63453699 0.70265382 0.91474209]
# predict_center [ 1.689818 0.6300571 1.053658 ]
# ---------------
# real_amp      [0.76022675 1.01366238 1.09569614]
# predict_center [ 0.99054027 1.0606809 0.9210128 ]
# real_center   [ 0.          9.77946893 10.97017916]
# predict_center [ -0.000409469 9.798054 11.193106 ]
# ---------------
# real_width    [0.         0.39829634 1.05510464]
# predict_center [ -0.009775132 0.4518044 1.09615 ]
# ---------------
# real_amp      [0.         1.01298834 0.78358955]
# predict_center [ 0.0221868 0.9799465 0.9144253 ]
# real_center   [ 3.8569353   4.12070216 12.11402843]
# predict_center [ 3.879343 4.1384325 12.14776 ]
# ---------------
# real_width    [0.4981711  0.58429175 1.10961953]
# predict_center [ 0.47757256 0.5108645 1.3215957 ]
# ---------------
# real_amp      [0.83741193 0.49685655 0.19540706]
# predict_center [ 0.68450344 0.77161175 0.33821154 ]
# real_center   [2.4287244  8.00130851 8.73111697]
# predict_center [ 2.3141093 8.1182165 8.986133 ]
# ---------------
# real_width    [1.30205305 0.73029477 1.26629847]
# predict_center [ 1.1190065 0.7601304 1.2640706 ]
# ---------------
# real_amp      [0.414536   0.85436318 0.82462015]
# predict_center [ 0.6091882 0.85681945 0.75537664 ]
# real_center   [0.         4.6604788  7.58096173]
# predict_center [ -0.0047587305 4.6075907 7.854598 ]
# ---------------
# real_width    [0.         0.74087437 0.40953535]
# predict_center [ 0.004021421 0.7018103 0.505369 ]
# ---------------
# real_amp      [0.         1.0195198  1.04926695]
# predict_center [ 0.024266355 1.0617601 0.9776464 ]
# real_center   [ 0.          4.61549707 12.73793585]
# predict_center [ 0.03135678 4.7078714 12.8214855 ]
# ---------------
# real_width    [0.         1.11693444 1.17194019]
# predict_center [ 0.012479171 1.2369983 1.1397431 ]
# ---------------
# real_amp      [0.         0.53062024 0.33579517]
# predict_center [ -0.0045938343 0.5938657 0.33534992 ]
# real_center   [ 5.12023748  5.84530511 10.99748078]
# predict_center [ 5.040637 5.861641 11.15969 ]
# ---------------
# real_width    [1.34057725 0.74437628 1.38113455]
# predict_center [ 1.4150989 0.7277861 1.4393268 ]
# ---------------
# real_amp      [0.84935913 0.70472954 0.46106577]
# predict_center [ 0.80475295 0.81666875 0.5915665 ]
# real_center   [ 8.0085005   8.9801749  11.72798113]
# predict_center [ 8.115177 8.838948 11.868766 ]
# ---------------
# real_width    [1.09531881 1.22843115 0.76551006]
# predict_center [ 1.1745976 1.3143034 0.7168541 ]
# ---------------
# real_amp      [0.71929417 0.23130514 0.83006498]
# predict_center [ 0.5911477 0.65752226 0.4792646 ]

# %%
plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")

# 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("P3HT Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0013647]], dtype=float32), array([[2.8339177e-03, 1.0285907e+01, 1.1060186e+01]], dtype=float32), array([[0.02238694, 1.6453578 , 0.68043923]], dtype=float32), array([[0.00352234, 0.414191  , 0.777012  ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
# Out:
# Text(0.5, 1.0, 'Network fitting vs real XPS graph')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
# Out:
# Text(0.5, 1.0, 'Predict_peak1 vs Xps_peak1')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak2 vs Xps_peak2')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak3 vs Xps_peak3')

# %%
new_predict[1][0],new_predict[2][0],new_predict[3][0]
# Out:
# (0.0028339177, 0.022386938, 0.0035223365)

# %%
new_predict[0][0]
# Out:
# 2.0013647

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.002059]], dtype=float32), array([[0.03939151, 7.3229265 , 8.111479  ]], dtype=float32), array([[0.02285026, 0.60291636, 0.6552572 ]], dtype=float32), array([[0.00418149, 0.45342064, 0.9938913 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')

error_peak_number_total=0
for i in range(test_peak_number.shape[0]):
    error_peak_number_total = error_peak_number_total + (abs(prediction[0][i]-test_peak_number[i]))
print('error_peak_number_total = ',error_peak_number_total)
error_peak_number = error_peak_number_total/test_peak_number.shape[0]
print('error_peak_number =  ',error_peak_number)
print('\n')
# Out:
# error_center_total =  [1706.59537418 3001.30173209 3243.92639928]
# error_center =   [0.08532977 0.15006509 0.16219632]
#
#
# error_width_total =  [1431.73012908 2256.92153212 1928.31109016]
# error_width =   [0.07158651 0.11284608 0.09641555]
#
#
# error_amp_total =  [1896.11755281 2225.69659131 2551.14433144]
# error_amp =   [0.09480588 0.11128483 0.12755722]
#
#
# error_peak_number_total =  [237.748]
# error_peak_number =   [0.0118874]

# %%
# 바꾼거

#model7에다 잔차연결을 해놨어 (Dense_center1,width1,amp1에서부터 concatenate까지)

# %%
# 수정할거

# if 만약 효과가 있다면
# 1-1 global_maxpooling에서 concatenate로 잔차가 좋은지 ->이러면 total_center1로부터 방목현상 크게 걱정 ㄴ
# 1-2 Concatenate에서 241이 됬으니까 total_center도 100까진 늘려야 되는지

# if 효과 없으면 이제 데이터 수정하자
#1.데이터비율
# 2.데이터양
# 3.교수님 model이랑 성능비교

# %%
# 결과

# 이런이런..안하니만 못한 결과가..
# 마지막으로 Dense_center2,width2,amp2에서 해보자
