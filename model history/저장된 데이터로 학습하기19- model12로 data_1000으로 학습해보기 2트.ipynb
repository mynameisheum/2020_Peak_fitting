# %%
# %ls
# Out:
# '2,3peak mix.ipynb'
# '5peak 3 para when it worksss.ipynb'
# 'Fitting_with_noise (1).ipynb'
#  ITO_O1s_bg.txt
#  ITO_O1s_exp.txt
#  ITO_O1s_fitting.txt
#  ITO_O1s_p1.txt
#  ITO_O1s_p2.txt
#  ITO_O1s_p3.txt
#  P3HT_S2p_bg.txt
#  P3HT_S2p_exp.txt
#  P3HT_S2p_fitting.txt
#  P3HT_S2p_p1.txt
#  P3HT_S2p_p2.txt
#  PeakDetection.ipynb
#  Untitled.ipynb
#  Untitled1.ipynb
#  Untitled2.ipynb
#  Untitled3.ipynb
#  Untitled4.ipynb
#  Untitled5.ipynb
#  Untitled6.ipynb
#  Untitled7.ipynb
#  amp.csv
#  amp2.csv
#  amp_1000.csv
#  center.csv
#  center2.csv
#  center_1000.csv
#  graph.csv
#  graph2.csv
#  graph_1000.csv
#  labels.png
#  model.png
#  model_shapes.png
#  peak_number.csv
#  peak_number2.csv
#  peak_number_1000.csv
#  width.csv
#  width2.csv
#  width_1000.csv
# '그래프 대칭.ipynb'
# '논문 수정.ipynb'
# '데이터 얻기.ipynb'
# '저장된 데이터로 학습하기.ipynb'
# '저장된 데이터로 학습하기10.ipynb'
# '저장된 데이터로 학습하기11.ipynb'
# '저장된 데이터로 학습하기12.ipynb'
# '저장된 데이터로 학습하기13.ipynb'
# '저장된 데이터로 학습하기14-model12(조언)가지고 newdata로 xps peak_number예측하기.ipynb'
# '저장된 데이터로 학습하기15 -data1가지고 model12랑 교수님 model 비교하기.ipynb'
# '저장된 데이터로 학습하기16- 교수님model로 data2로 error확인하기.ipynb'
# '저장된 데이터로 학습하기17-급생각난 2번째 모델 확인 data1.ipynb'
# '저장된 데이터로 학습하기17-급생각난 model- data1으로 확인하기 2트.ipynb'
# '저장된 데이터로 학습하기19- model12로 data_1000으로 학습해보기 2트.ipynb'
# '저장된 데이터로 학습하기19- model12로 data_1000으로 학습해보기.ipynb'
# '저장된 데이터로 학습하기2.ipynb'
# '저장된 데이터로 학습하기20 -spark model2로 data_1000으로 학습시켜보기.ipynb'
# '저장된 데이터로 학습하기3.ipynb'
# '저장된 데이터로 학습하기4.ipynb'
# '저장된 데이터로 학습하기5.ipynb'
# '저장된 데이터로 학습하기6.ipynb'
# '저장된 데이터로 학습하기7.ipynb'
# '저장된 데이터로 학습하기8.ipynb'
# '저장된 데이터로 학습하기9.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph_1000.csv').values[:,1:]
center= pd.read_csv('center_1000.csv').values[:,1:]
width= pd.read_csv('width_1000.csv').values[:,1:]
amp= pd.read_csv('amp_1000.csv').values[:,1:]
peak_number= pd.read_csv('peak_number_1000.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(10000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 9.21634859  9.48914101  9.6746136 ]
#  [ 0.         11.26168262 12.74836907]
#  [ 0.          2.12387114  9.04702466]
#  [ 0.          4.96145733  9.91188518]
#  [10.63243993 11.80271559 12.53915876]
#  [ 5.84923381  7.23810912 11.3910589 ]
#  [ 4.70379464  9.96620073 12.81918039]
#  [ 7.14544127  8.06876046 12.64873842]
#  [ 0.          2.08458974  4.24891576]
#  [ 0.          3.80133436 11.76971511]]
# [[1.60158595 1.66123993 0.90235706]
#  [0.         1.40923428 1.3445495 ]
#  [0.         0.78186738 1.13094031]
#  [0.         0.50000271 0.77473982]
#  [1.28667226 0.83949775 1.60972702]
#  [1.8723467  1.61165922 1.05612898]
#  [1.80163672 1.78406503 1.44740219]
#  [0.49529478 1.17637885 1.03014563]
#  [0.         1.3605233  1.35101147]
#  [0.         1.15216295 0.52992202]]
# [[0.26988555 0.18905789 0.24912559]
#  [0.         1.07340945 0.45921841]
#  [0.         0.291188   0.26308662]
#  [0.         1.01440076 0.94229748]
#  [0.33107535 0.92829788 0.97520786]
#  [0.28815727 0.4537231  0.81402281]
#  [0.88170608 0.77501342 0.74417037]
#  [0.80754933 0.50841855 0.35491888]
#  [0.         0.71395818 0.7864612 ]
#  [0.         0.71049866 0.27728167]]
# [3 2 2 2 3 3 3 3 2 2]
# (10000000, 3)
# (10000000, 3)
# (10000000, 3)
# (10000000,)
# (10000000, 401)
# [[ 0.01094473 -0.02272666  0.01609616 ... -0.03043683  0.02722137
#    0.02208656]
#  [-0.00780636  0.00322276  0.00940177 ...  0.01963256  0.01836803
#    0.0234588 ]
#  [ 0.01263877  0.00731667 -0.00526456 ...  0.01546713  0.01695805
#   -0.01905622]
#  ...
#  [ 0.03170691 -0.02419859 -0.00585362 ... -0.00227254  0.00109521
#    0.001506  ]
#  [ 0.01146607 -0.00638027 -0.02255473 ...  0.01860643 -0.01372592
#    0.01849033]
#  [-0.00469547  0.02259855 -0.05179253 ... -0.04310437  0.01702795
#    0.019531  ]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
# 90:9:1
data_number=5000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (9000000, 401) (900000, 401) (100000, 401)
# (9000000, 3) (900000, 3) (100000, 3)
# (9000000, 3) (900000, 3) (100000, 3)
# (9000000, 3) (900000, 3) (100000, 3)
# (9000000,) (900000,) (100000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (9000000, 401, 1)
# (900000, 401, 1)
# (100000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
input_data = Input(shape = (len(x), 1))

t = layers.Conv1D(32,100,strides=5,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(64,4,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,4,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(192,2,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)


Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(1, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(200, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(100, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(200,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(100,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(200,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(100,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
center_Batchnormalization  = BatchNormalization()(total_center1)
# total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center2 = Dense(3, activation = 'linear',name = 'total_center2')(center_Batchnormalization)


width_merge = concatenate([Dense3_peak_number,Dense3_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
width_Batchnormalization  = BatchNormalization()(total_width1)
# total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width2= Dense(3, activation = 'linear',name = 'total_width2')(width_Batchnormalization)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
amp_Batchnormalization  = BatchNormalization()(total_amp1)
# total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp2 = Dense(3, activation = 'linear',name = 'total_amp2')(amp_Batchnormalization)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center2,total_width2,total_amp2])
print(model.summary())
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 61, 32)       3232        input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 30, 32)       0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 27, 64)       8256        max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 13, 64)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 10, 128)      32896       max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 5, 128)       0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 4, 192)       49344       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 2, 192)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 192)          0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 200)          38600       global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 100)          20100       Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 100)          20100       Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 100)          20100       Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 1)            201         Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           4040        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           4040        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           4040        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           1680        concatenate[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           1680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           1680        concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 40)           160         total_center1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 40)           160         total_width1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 40)           160         total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 3)            123         batch_normalization[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 3)            123         batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 3)            123         batch_normalization_2[0][0]
# ==================================================================================================
# Total params: 366,838
# Trainable params: 366,598
# Non-trainable params: 240
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center2' : 'mse',
                      'total_width2' : 'mse',
                      'total_amp2' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 0.5,
#                            'total_width3' : 1,
#                            'total_amp3' : 1,
#                             'Dense3_peak_number' :1 },
              metrics = ['mae'])

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 50,
          batch_size = 5000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/50
# 1800/1800 [==============================] - 59s 33ms/step - loss: 5.2180 - Dense3_peak_number_loss: 0.0973 - total_center2_loss: 4.9950 - total_width2_loss: 0.0909 - total_amp2_loss: 0.0347 - Dense3_peak_number_mae: 0.2174 - total_center2_mae: 1.0649 - total_width2_mae: 0.1932 - total_amp2_mae: 0.1269 - val_loss: 0.3597 - val_Dense3_peak_number_loss: 0.0253 - val_total_center2_loss: 0.2704 - val_total_width2_loss: 0.0404 - val_total_amp2_loss: 0.0237 - val_Dense3_peak_number_mae: 0.1090 - val_total_center2_mae: 0.3052 - val_total_width2_mae: 0.1446 - val_total_amp2_mae: 0.1112
# Epoch 2/50
# 1800/1800 [==============================] - 60s 33ms/step - loss: 0.3083 - Dense3_peak_number_loss: 0.0187 - total_center2_loss: 0.2399 - total_width2_loss: 0.0326 - total_amp2_loss: 0.0171 - Dense3_peak_number_mae: 0.0787 - total_center2_mae: 0.2415 - total_width2_mae: 0.1157 - total_amp2_mae: 0.0868 - val_loss: 0.3150 - val_Dense3_peak_number_loss: 0.0122 - val_total_center2_loss: 0.2214 - val_total_width2_loss: 0.0587 - val_total_amp2_loss: 0.0227 - val_Dense3_peak_number_mae: 0.0536 - val_total_center2_mae: 0.2558 - val_total_width2_mae: 0.1877 - val_total_amp2_mae: 0.1147
# Epoch 3/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.2372 - Dense3_peak_number_loss: 0.0109 - total_center2_loss: 0.1850 - total_width2_loss: 0.0266 - total_amp2_loss: 0.0147 - Dense3_peak_number_mae: 0.0442 - total_center2_mae: 0.1982 - total_width2_mae: 0.1018 - total_amp2_mae: 0.0777 - val_loss: 0.2080 - val_Dense3_peak_number_loss: 0.0106 - val_total_center2_loss: 0.1581 - val_total_width2_loss: 0.0254 - val_total_amp2_loss: 0.0139 - val_Dense3_peak_number_mae: 0.0662 - val_total_center2_mae: 0.1969 - val_total_width2_mae: 0.1043 - val_total_amp2_mae: 0.0780
# Epoch 4/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.2138 - Dense3_peak_number_loss: 0.0095 - total_center2_loss: 0.1668 - total_width2_loss: 0.0239 - total_amp2_loss: 0.0136 - Dense3_peak_number_mae: 0.0369 - total_center2_mae: 0.1817 - total_width2_mae: 0.0955 - total_amp2_mae: 0.0736 - val_loss: 0.5312 - val_Dense3_peak_number_loss: 0.0142 - val_total_center2_loss: 0.4346 - val_total_width2_loss: 0.0537 - val_total_amp2_loss: 0.0288 - val_Dense3_peak_number_mae: 0.0712 - val_total_center2_mae: 0.4627 - val_total_width2_mae: 0.1545 - val_total_amp2_mae: 0.1234
# Epoch 5/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1758 - Dense3_peak_number_loss: 0.0071 - total_center2_loss: 0.1358 - total_width2_loss: 0.0206 - total_amp2_loss: 0.0122 - Dense3_peak_number_mae: 0.0302 - total_center2_mae: 0.1603 - total_width2_mae: 0.0878 - total_amp2_mae: 0.0686 - val_loss: 0.1525 - val_Dense3_peak_number_loss: 0.0047 - val_total_center2_loss: 0.1165 - val_total_width2_loss: 0.0199 - val_total_amp2_loss: 0.0115 - val_Dense3_peak_number_mae: 0.0204 - val_total_center2_mae: 0.1472 - val_total_width2_mae: 0.0870 - val_total_amp2_mae: 0.0657
# Epoch 6/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1619 - Dense3_peak_number_loss: 0.0065 - total_center2_loss: 0.1250 - total_width2_loss: 0.0191 - total_amp2_loss: 0.0115 - Dense3_peak_number_mae: 0.0280 - total_center2_mae: 0.1509 - total_width2_mae: 0.0838 - total_amp2_mae: 0.0659 - val_loss: 0.1525 - val_Dense3_peak_number_loss: 0.0051 - val_total_center2_loss: 0.1141 - val_total_width2_loss: 0.0203 - val_total_amp2_loss: 0.0129 - val_Dense3_peak_number_mae: 0.0267 - val_total_center2_mae: 0.1448 - val_total_width2_mae: 0.0916 - val_total_amp2_mae: 0.0735
# Epoch 7/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.1469 - Dense3_peak_number_loss: 0.0056 - total_center2_loss: 0.1125 - total_width2_loss: 0.0178 - total_amp2_loss: 0.0109 - Dense3_peak_number_mae: 0.0259 - total_center2_mae: 0.1417 - total_width2_mae: 0.0807 - total_amp2_mae: 0.0638 - val_loss: 0.1173 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0882 - val_total_width2_loss: 0.0161 - val_total_amp2_loss: 0.0101 - val_Dense3_peak_number_mae: 0.0150 - val_total_center2_mae: 0.1317 - val_total_width2_mae: 0.0762 - val_total_amp2_mae: 0.0613
# Epoch 8/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1449 - Dense3_peak_number_loss: 0.0056 - total_center2_loss: 0.1114 - total_width2_loss: 0.0172 - total_amp2_loss: 0.0107 - Dense3_peak_number_mae: 0.0253 - total_center2_mae: 0.1401 - total_width2_mae: 0.0785 - total_amp2_mae: 0.0628 - val_loss: 0.1146 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0861 - val_total_width2_loss: 0.0158 - val_total_amp2_loss: 0.0098 - val_Dense3_peak_number_mae: 0.0125 - val_total_center2_mae: 0.1189 - val_total_width2_mae: 0.0774 - val_total_amp2_mae: 0.0599
# Epoch 9/50
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.1313 - Dense3_peak_number_loss: 0.0049 - total_center2_loss: 0.1003 - total_width2_loss: 0.0160 - total_amp2_loss: 0.0101 - Dense3_peak_number_mae: 0.0234 - total_center2_mae: 0.1321 - total_width2_mae: 0.0756 - total_amp2_mae: 0.0607 - val_loss: 0.1130 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0842 - val_total_width2_loss: 0.0156 - val_total_amp2_loss: 0.0102 - val_Dense3_peak_number_mae: 0.0175 - val_total_center2_mae: 0.1217 - val_total_width2_mae: 0.0770 - val_total_amp2_mae: 0.0632
# Epoch 10/50
# 1800/1800 [==============================] - 53s 29ms/step - loss: 0.1240 - Dense3_peak_number_loss: 0.0046 - total_center2_loss: 0.0944 - total_width2_loss: 0.0152 - total_amp2_loss: 0.0098 - Dense3_peak_number_mae: 0.0226 - total_center2_mae: 0.1279 - total_width2_mae: 0.0731 - total_amp2_mae: 0.0592 - val_loss: 0.1109 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0849 - val_total_width2_loss: 0.0139 - val_total_amp2_loss: 0.0092 - val_Dense3_peak_number_mae: 0.0182 - val_total_center2_mae: 0.1315 - val_total_width2_mae: 0.0689 - val_total_amp2_mae: 0.0573
# Epoch 11/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.1218 - Dense3_peak_number_loss: 0.0045 - total_center2_loss: 0.0928 - total_width2_loss: 0.0148 - total_amp2_loss: 0.0097 - Dense3_peak_number_mae: 0.0211 - total_center2_mae: 0.1251 - total_width2_mae: 0.0718 - total_amp2_mae: 0.0585 - val_loss: 0.1043 - val_Dense3_peak_number_loss: 0.0031 - val_total_center2_loss: 0.0789 - val_total_width2_loss: 0.0134 - val_total_amp2_loss: 0.0089 - val_Dense3_peak_number_mae: 0.0114 - val_total_center2_mae: 0.1019 - val_total_width2_mae: 0.0667 - val_total_amp2_mae: 0.0542
# Epoch 12/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.1153 - Dense3_peak_number_loss: 0.0041 - total_center2_loss: 0.0877 - total_width2_loss: 0.0141 - total_amp2_loss: 0.0094 - Dense3_peak_number_mae: 0.0202 - total_center2_mae: 0.1212 - total_width2_mae: 0.0698 - total_amp2_mae: 0.0573 - val_loss: 0.2331 - val_Dense3_peak_number_loss: 0.0074 - val_total_center2_loss: 0.1805 - val_total_width2_loss: 0.0310 - val_total_amp2_loss: 0.0142 - val_Dense3_peak_number_mae: 0.0319 - val_total_center2_mae: 0.2582 - val_total_width2_mae: 0.1311 - val_total_amp2_mae: 0.0814
# Epoch 13/50
# 1800/1800 [==============================] - 53s 30ms/step - loss: 0.1095 - Dense3_peak_number_loss: 0.0038 - total_center2_loss: 0.0830 - total_width2_loss: 0.0136 - total_amp2_loss: 0.0092 - Dense3_peak_number_mae: 0.0190 - total_center2_mae: 0.1180 - total_width2_mae: 0.0685 - total_amp2_mae: 0.0565 - val_loss: 0.0938 - val_Dense3_peak_number_loss: 0.0025 - val_total_center2_loss: 0.0702 - val_total_width2_loss: 0.0126 - val_total_amp2_loss: 0.0085 - val_Dense3_peak_number_mae: 0.0161 - val_total_center2_mae: 0.1016 - val_total_width2_mae: 0.0645 - val_total_amp2_mae: 0.0524
# Epoch 14/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1040 - Dense3_peak_number_loss: 0.0035 - total_center2_loss: 0.0784 - total_width2_loss: 0.0131 - total_amp2_loss: 0.0089 - Dense3_peak_number_mae: 0.0188 - total_center2_mae: 0.1153 - total_width2_mae: 0.0672 - total_amp2_mae: 0.0554 - val_loss: 0.0996 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0745 - val_total_width2_loss: 0.0134 - val_total_amp2_loss: 0.0089 - val_Dense3_peak_number_mae: 0.0200 - val_total_center2_mae: 0.1087 - val_total_width2_mae: 0.0700 - val_total_amp2_mae: 0.0563
# Epoch 15/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.1020 - Dense3_peak_number_loss: 0.0034 - total_center2_loss: 0.0770 - total_width2_loss: 0.0128 - total_amp2_loss: 0.0088 - Dense3_peak_number_mae: 0.0180 - total_center2_mae: 0.1129 - total_width2_mae: 0.0663 - total_amp2_mae: 0.0547 - val_loss: 0.0998 - val_Dense3_peak_number_loss: 0.0031 - val_total_center2_loss: 0.0738 - val_total_width2_loss: 0.0131 - val_total_amp2_loss: 0.0098 - val_Dense3_peak_number_mae: 0.0273 - val_total_center2_mae: 0.1073 - val_total_width2_mae: 0.0700 - val_total_amp2_mae: 0.0615
# Epoch 16/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.1031 - Dense3_peak_number_loss: 0.0035 - total_center2_loss: 0.0780 - total_width2_loss: 0.0128 - total_amp2_loss: 0.0088 - Dense3_peak_number_mae: 0.0188 - total_center2_mae: 0.1134 - total_width2_mae: 0.0662 - total_amp2_mae: 0.0546 - val_loss: 0.1043 - val_Dense3_peak_number_loss: 0.0026 - val_total_center2_loss: 0.0808 - val_total_width2_loss: 0.0125 - val_total_amp2_loss: 0.0085 - val_Dense3_peak_number_mae: 0.0078 - val_total_center2_mae: 0.1266 - val_total_width2_mae: 0.0678 - val_total_amp2_mae: 0.0551
# Epoch 17/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.1040 - Dense3_peak_number_loss: 0.0037 - total_center2_loss: 0.0788 - total_width2_loss: 0.0128 - total_amp2_loss: 0.0087 - Dense3_peak_number_mae: 0.0181 - total_center2_mae: 0.1127 - total_width2_mae: 0.0656 - total_amp2_mae: 0.0541 - val_loss: 0.0879 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0657 - val_total_width2_loss: 0.0115 - val_total_amp2_loss: 0.0084 - val_Dense3_peak_number_mae: 0.0128 - val_total_center2_mae: 0.0998 - val_total_width2_mae: 0.0626 - val_total_amp2_mae: 0.0531
# Epoch 18/50
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0995 - Dense3_peak_number_loss: 0.0033 - total_center2_loss: 0.0753 - total_width2_loss: 0.0123 - total_amp2_loss: 0.0085 - Dense3_peak_number_mae: 0.0163 - total_center2_mae: 0.1110 - total_width2_mae: 0.0648 - total_amp2_mae: 0.0534 - val_loss: 0.0903 - val_Dense3_peak_number_loss: 0.0027 - val_total_center2_loss: 0.0676 - val_total_width2_loss: 0.0116 - val_total_amp2_loss: 0.0085 - val_Dense3_peak_number_mae: 0.0161 - val_total_center2_mae: 0.1011 - val_total_width2_mae: 0.0624 - val_total_amp2_mae: 0.0542
# Epoch 19/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0927 - Dense3_peak_number_loss: 0.0029 - total_center2_loss: 0.0697 - total_width2_loss: 0.0118 - total_amp2_loss: 0.0083 - Dense3_peak_number_mae: 0.0158 - total_center2_mae: 0.1068 - total_width2_mae: 0.0632 - total_amp2_mae: 0.0522 - val_loss: 0.0947 - val_Dense3_peak_number_loss: 0.0025 - val_total_center2_loss: 0.0715 - val_total_width2_loss: 0.0118 - val_total_amp2_loss: 0.0088 - val_Dense3_peak_number_mae: 0.0124 - val_total_center2_mae: 0.1085 - val_total_width2_mae: 0.0635 - val_total_amp2_mae: 0.0560
# Epoch 20/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0960 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0724 - total_width2_loss: 0.0121 - total_amp2_loss: 0.0084 - Dense3_peak_number_mae: 0.0161 - total_center2_mae: 0.1081 - total_width2_mae: 0.0638 - total_amp2_mae: 0.0527 - val_loss: 0.0856 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0633 - val_total_width2_loss: 0.0123 - val_total_amp2_loss: 0.0081 - val_Dense3_peak_number_mae: 0.0113 - val_total_center2_mae: 0.0976 - val_total_width2_mae: 0.0665 - val_total_amp2_mae: 0.0519
# Epoch 21/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0935 - Dense3_peak_number_loss: 0.0030 - total_center2_loss: 0.0704 - total_width2_loss: 0.0118 - total_amp2_loss: 0.0082 - Dense3_peak_number_mae: 0.0157 - total_center2_mae: 0.1074 - total_width2_mae: 0.0630 - total_amp2_mae: 0.0518 - val_loss: 0.0861 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0647 - val_total_width2_loss: 0.0110 - val_total_amp2_loss: 0.0084 - val_Dense3_peak_number_mae: 0.0129 - val_total_center2_mae: 0.0930 - val_total_width2_mae: 0.0595 - val_total_amp2_mae: 0.0546
# Epoch 22/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0901 - Dense3_peak_number_loss: 0.0029 - total_center2_loss: 0.0677 - total_width2_loss: 0.0115 - total_amp2_loss: 0.0081 - Dense3_peak_number_mae: 0.0150 - total_center2_mae: 0.1048 - total_width2_mae: 0.0620 - total_amp2_mae: 0.0513 - val_loss: 0.1023 - val_Dense3_peak_number_loss: 0.0026 - val_total_center2_loss: 0.0782 - val_total_width2_loss: 0.0128 - val_total_amp2_loss: 0.0087 - val_Dense3_peak_number_mae: 0.0143 - val_total_center2_mae: 0.1227 - val_total_width2_mae: 0.0731 - val_total_amp2_mae: 0.0559
# Epoch 23/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0941 - Dense3_peak_number_loss: 0.0031 - total_center2_loss: 0.0712 - total_width2_loss: 0.0117 - total_amp2_loss: 0.0082 - Dense3_peak_number_mae: 0.0153 - total_center2_mae: 0.1060 - total_width2_mae: 0.0625 - total_amp2_mae: 0.0516 - val_loss: 0.0950 - val_Dense3_peak_number_loss: 0.0028 - val_total_center2_loss: 0.0717 - val_total_width2_loss: 0.0117 - val_total_amp2_loss: 0.0088 - val_Dense3_peak_number_mae: 0.0198 - val_total_center2_mae: 0.0997 - val_total_width2_mae: 0.0645 - val_total_amp2_mae: 0.0564
# Epoch 24/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0862 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0645 - total_width2_loss: 0.0112 - total_amp2_loss: 0.0079 - Dense3_peak_number_mae: 0.0144 - total_center2_mae: 0.1030 - total_width2_mae: 0.0613 - total_amp2_mae: 0.0502 - val_loss: 0.0867 - val_Dense3_peak_number_loss: 0.0022 - val_total_center2_loss: 0.0661 - val_total_width2_loss: 0.0107 - val_total_amp2_loss: 0.0077 - val_Dense3_peak_number_mae: 0.0121 - val_total_center2_mae: 0.0968 - val_total_width2_mae: 0.0591 - val_total_amp2_mae: 0.0495
# Epoch 25/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0879 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0660 - total_width2_loss: 0.0112 - total_amp2_loss: 0.0079 - Dense3_peak_number_mae: 0.0145 - total_center2_mae: 0.1032 - total_width2_mae: 0.0612 - total_amp2_mae: 0.0505 - val_loss: 0.1074 - val_Dense3_peak_number_loss: 0.0028 - val_total_center2_loss: 0.0838 - val_total_width2_loss: 0.0121 - val_total_amp2_loss: 0.0087 - val_Dense3_peak_number_mae: 0.0139 - val_total_center2_mae: 0.1181 - val_total_width2_mae: 0.0629 - val_total_amp2_mae: 0.0550
# Epoch 26/50
# 1800/1800 [==============================] - 57s 32ms/step - loss: 0.0874 - Dense3_peak_number_loss: 0.0028 - total_center2_loss: 0.0656 - total_width2_loss: 0.0112 - total_amp2_loss: 0.0079 - Dense3_peak_number_mae: 0.0145 - total_center2_mae: 0.1020 - total_width2_mae: 0.0608 - total_amp2_mae: 0.0499 - val_loss: 0.0867 - val_Dense3_peak_number_loss: 0.0022 - val_total_center2_loss: 0.0662 - val_total_width2_loss: 0.0107 - val_total_amp2_loss: 0.0076 - val_Dense3_peak_number_mae: 0.0075 - val_total_center2_mae: 0.0894 - val_total_width2_mae: 0.0586 - val_total_amp2_mae: 0.0498
# Epoch 27/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0802 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0596 - total_width2_loss: 0.0107 - total_amp2_loss: 0.0076 - Dense3_peak_number_mae: 0.0131 - total_center2_mae: 0.0981 - total_width2_mae: 0.0598 - total_amp2_mae: 0.0490 - val_loss: 0.0791 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0596 - val_total_width2_loss: 0.0103 - val_total_amp2_loss: 0.0076 - val_Dense3_peak_number_mae: 0.0087 - val_total_center2_mae: 0.0877 - val_total_width2_mae: 0.0580 - val_total_amp2_mae: 0.0497
# Epoch 28/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0869 - Dense3_peak_number_loss: 0.0028 - total_center2_loss: 0.0651 - total_width2_loss: 0.0112 - total_amp2_loss: 0.0078 - Dense3_peak_number_mae: 0.0154 - total_center2_mae: 0.1031 - total_width2_mae: 0.0610 - total_amp2_mae: 0.0499 - val_loss: 0.0859 - val_Dense3_peak_number_loss: 0.0021 - val_total_center2_loss: 0.0657 - val_total_width2_loss: 0.0106 - val_total_amp2_loss: 0.0076 - val_Dense3_peak_number_mae: 0.0086 - val_total_center2_mae: 0.0944 - val_total_width2_mae: 0.0575 - val_total_amp2_mae: 0.0476
# Epoch 29/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0796 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0592 - total_width2_loss: 0.0106 - total_amp2_loss: 0.0076 - Dense3_peak_number_mae: 0.0130 - total_center2_mae: 0.0974 - total_width2_mae: 0.0593 - total_amp2_mae: 0.0486 - val_loss: 0.1300 - val_Dense3_peak_number_loss: 0.0045 - val_total_center2_loss: 0.1053 - val_total_width2_loss: 0.0123 - val_total_amp2_loss: 0.0078 - val_Dense3_peak_number_mae: 0.0143 - val_total_center2_mae: 0.1065 - val_total_width2_mae: 0.0639 - val_total_amp2_mae: 0.0482
# Epoch 30/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.0842 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0629 - total_width2_loss: 0.0109 - total_amp2_loss: 0.0077 - Dense3_peak_number_mae: 0.0145 - total_center2_mae: 0.1002 - total_width2_mae: 0.0604 - total_amp2_mae: 0.0493 - val_loss: 0.1092 - val_Dense3_peak_number_loss: 0.0032 - val_total_center2_loss: 0.0851 - val_total_width2_loss: 0.0126 - val_total_amp2_loss: 0.0083 - val_Dense3_peak_number_mae: 0.0195 - val_total_center2_mae: 0.1285 - val_total_width2_mae: 0.0688 - val_total_amp2_mae: 0.0547
# Epoch 31/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0796 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0592 - total_width2_loss: 0.0105 - total_amp2_loss: 0.0075 - Dense3_peak_number_mae: 0.0133 - total_center2_mae: 0.0972 - total_width2_mae: 0.0589 - total_amp2_mae: 0.0483 - val_loss: 0.0887 - val_Dense3_peak_number_loss: 0.0022 - val_total_center2_loss: 0.0676 - val_total_width2_loss: 0.0108 - val_total_amp2_loss: 0.0081 - val_Dense3_peak_number_mae: 0.0085 - val_total_center2_mae: 0.1054 - val_total_width2_mae: 0.0606 - val_total_amp2_mae: 0.0550
# Epoch 32/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0835 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0625 - total_width2_loss: 0.0107 - total_amp2_loss: 0.0076 - Dense3_peak_number_mae: 0.0141 - total_center2_mae: 0.0996 - total_width2_mae: 0.0594 - total_amp2_mae: 0.0486 - val_loss: 0.0935 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0731 - val_total_width2_loss: 0.0105 - val_total_amp2_loss: 0.0075 - val_Dense3_peak_number_mae: 0.0130 - val_total_center2_mae: 0.1182 - val_total_width2_mae: 0.0603 - val_total_amp2_mae: 0.0476
# Epoch 33/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0811 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0603 - total_width2_loss: 0.0106 - total_amp2_loss: 0.0075 - Dense3_peak_number_mae: 0.0141 - total_center2_mae: 0.0980 - total_width2_mae: 0.0589 - total_amp2_mae: 0.0482 - val_loss: 0.0859 - val_Dense3_peak_number_loss: 0.0019 - val_total_center2_loss: 0.0663 - val_total_width2_loss: 0.0104 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0163 - val_total_center2_mae: 0.1167 - val_total_width2_mae: 0.0614 - val_total_amp2_mae: 0.0474
# Epoch 34/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0792 - Dense3_peak_number_loss: 0.0024 - total_center2_loss: 0.0589 - total_width2_loss: 0.0104 - total_amp2_loss: 0.0074 - Dense3_peak_number_mae: 0.0137 - total_center2_mae: 0.0964 - total_width2_mae: 0.0586 - total_amp2_mae: 0.0478 - val_loss: 0.1062 - val_Dense3_peak_number_loss: 0.0029 - val_total_center2_loss: 0.0828 - val_total_width2_loss: 0.0115 - val_total_amp2_loss: 0.0090 - val_Dense3_peak_number_mae: 0.0199 - val_total_center2_mae: 0.1345 - val_total_width2_mae: 0.0613 - val_total_amp2_mae: 0.0584
# Epoch 35/50
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0807 - Dense3_peak_number_loss: 0.0025 - total_center2_loss: 0.0602 - total_width2_loss: 0.0105 - total_amp2_loss: 0.0075 - Dense3_peak_number_mae: 0.0137 - total_center2_mae: 0.0977 - total_width2_mae: 0.0587 - total_amp2_mae: 0.0480 - val_loss: 0.0802 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0613 - val_total_width2_loss: 0.0100 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0098 - val_total_center2_mae: 0.1075 - val_total_width2_mae: 0.0573 - val_total_amp2_mae: 0.0491
# Epoch 36/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0754 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0558 - total_width2_loss: 0.0101 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0131 - total_center2_mae: 0.0945 - total_width2_mae: 0.0576 - total_amp2_mae: 0.0471 - val_loss: 0.0743 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0553 - val_total_width2_loss: 0.0102 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0140 - val_total_center2_mae: 0.0912 - val_total_width2_mae: 0.0600 - val_total_amp2_mae: 0.0466
# Epoch 37/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.0756 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0559 - total_width2_loss: 0.0101 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0128 - total_center2_mae: 0.0950 - total_width2_mae: 0.0577 - total_amp2_mae: 0.0471 - val_loss: 0.0767 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0575 - val_total_width2_loss: 0.0105 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0071 - val_total_center2_mae: 0.0980 - val_total_width2_mae: 0.0615 - val_total_amp2_mae: 0.0471
# Epoch 38/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.0744 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0550 - total_width2_loss: 0.0100 - total_amp2_loss: 0.0073 - Dense3_peak_number_mae: 0.0130 - total_center2_mae: 0.0943 - total_width2_mae: 0.0572 - total_amp2_mae: 0.0469 - val_loss: 0.0719 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0538 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0109 - val_total_center2_mae: 0.0891 - val_total_width2_mae: 0.0541 - val_total_amp2_mae: 0.0457
# Epoch 39/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.0734 - Dense3_peak_number_loss: 0.0022 - total_center2_loss: 0.0540 - total_width2_loss: 0.0100 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0128 - total_center2_mae: 0.0934 - total_width2_mae: 0.0573 - total_amp2_mae: 0.0468 - val_loss: 0.0827 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0637 - val_total_width2_loss: 0.0103 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0139 - val_total_center2_mae: 0.1074 - val_total_width2_mae: 0.0617 - val_total_amp2_mae: 0.0467
# Epoch 40/50
# 1800/1800 [==============================] - 54s 30ms/step - loss: 0.0820 - Dense3_peak_number_loss: 0.0026 - total_center2_loss: 0.0615 - total_width2_loss: 0.0104 - total_amp2_loss: 0.0074 - Dense3_peak_number_mae: 0.0128 - total_center2_mae: 0.0958 - total_width2_mae: 0.0581 - total_amp2_mae: 0.0473 - val_loss: 0.0832 - val_Dense3_peak_number_loss: 0.0026 - val_total_center2_loss: 0.0628 - val_total_width2_loss: 0.0102 - val_total_amp2_loss: 0.0076 - val_Dense3_peak_number_mae: 0.0101 - val_total_center2_mae: 0.0863 - val_total_width2_mae: 0.0557 - val_total_amp2_mae: 0.0490
# Epoch 41/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0798 - Dense3_peak_number_loss: 0.0027 - total_center2_loss: 0.0594 - total_width2_loss: 0.0103 - total_amp2_loss: 0.0074 - Dense3_peak_number_mae: 0.0143 - total_center2_mae: 0.0963 - total_width2_mae: 0.0579 - total_amp2_mae: 0.0471 - val_loss: 0.0830 - val_Dense3_peak_number_loss: 0.0020 - val_total_center2_loss: 0.0638 - val_total_width2_loss: 0.0099 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0074 - val_total_center2_mae: 0.1094 - val_total_width2_mae: 0.0575 - val_total_amp2_mae: 0.0454
# Epoch 42/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0730 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0540 - total_width2_loss: 0.0098 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0120 - total_center2_mae: 0.0917 - total_width2_mae: 0.0562 - total_amp2_mae: 0.0459 - val_loss: 0.0757 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0572 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0072 - val_Dense3_peak_number_mae: 0.0149 - val_total_center2_mae: 0.0830 - val_total_width2_mae: 0.0546 - val_total_amp2_mae: 0.0469
# Epoch 43/50
# 1800/1800 [==============================] - 57s 31ms/step - loss: 0.0717 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0527 - total_width2_loss: 0.0098 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0124 - total_center2_mae: 0.0913 - total_width2_mae: 0.0564 - total_amp2_mae: 0.0460 - val_loss: 0.0750 - val_Dense3_peak_number_loss: 0.0015 - val_total_center2_loss: 0.0550 - val_total_width2_loss: 0.0115 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0103 - val_total_center2_mae: 0.0938 - val_total_width2_mae: 0.0715 - val_total_amp2_mae: 0.0456
# Epoch 44/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0714 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0526 - total_width2_loss: 0.0097 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0118 - total_center2_mae: 0.0908 - total_width2_mae: 0.0563 - total_amp2_mae: 0.0460 - val_loss: 0.0771 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0582 - val_total_width2_loss: 0.0099 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0149 - val_total_center2_mae: 0.0876 - val_total_width2_mae: 0.0574 - val_total_amp2_mae: 0.0471
# Epoch 45/50
# 1800/1800 [==============================] - 55s 30ms/step - loss: 0.0712 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0523 - total_width2_loss: 0.0097 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0123 - total_center2_mae: 0.0910 - total_width2_mae: 0.0563 - total_amp2_mae: 0.0459 - val_loss: 0.0727 - val_Dense3_peak_number_loss: 0.0018 - val_total_center2_loss: 0.0538 - val_total_width2_loss: 0.0101 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0097 - val_total_center2_mae: 0.0769 - val_total_width2_mae: 0.0563 - val_total_amp2_mae: 0.0453
# Epoch 46/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0697 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0511 - total_width2_loss: 0.0096 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0125 - total_center2_mae: 0.0907 - total_width2_mae: 0.0559 - total_amp2_mae: 0.0456 - val_loss: 0.0726 - val_Dense3_peak_number_loss: 0.0017 - val_total_center2_loss: 0.0543 - val_total_width2_loss: 0.0096 - val_total_amp2_loss: 0.0070 - val_Dense3_peak_number_mae: 0.0106 - val_total_center2_mae: 0.0771 - val_total_width2_mae: 0.0564 - val_total_amp2_mae: 0.0454
# Epoch 47/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0741 - Dense3_peak_number_loss: 0.0023 - total_center2_loss: 0.0547 - total_width2_loss: 0.0100 - total_amp2_loss: 0.0072 - Dense3_peak_number_mae: 0.0125 - total_center2_mae: 0.0924 - total_width2_mae: 0.0569 - total_amp2_mae: 0.0460 - val_loss: 0.0721 - val_Dense3_peak_number_loss: 0.0016 - val_total_center2_loss: 0.0541 - val_total_width2_loss: 0.0095 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0075 - val_total_center2_mae: 0.0807 - val_total_width2_mae: 0.0542 - val_total_amp2_mae: 0.0436
# Epoch 48/50
# 1800/1800 [==============================] - 55s 31ms/step - loss: 0.0690 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0506 - total_width2_loss: 0.0094 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0121 - total_center2_mae: 0.0897 - total_width2_mae: 0.0553 - total_amp2_mae: 0.0450 - val_loss: 0.0889 - val_Dense3_peak_number_loss: 0.0023 - val_total_center2_loss: 0.0688 - val_total_width2_loss: 0.0104 - val_total_amp2_loss: 0.0073 - val_Dense3_peak_number_mae: 0.0106 - val_total_center2_mae: 0.0899 - val_total_width2_mae: 0.0613 - val_total_amp2_mae: 0.0468
# Epoch 49/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0719 - Dense3_peak_number_loss: 0.0021 - total_center2_loss: 0.0531 - total_width2_loss: 0.0097 - total_amp2_loss: 0.0071 - Dense3_peak_number_mae: 0.0116 - total_center2_mae: 0.0906 - total_width2_mae: 0.0558 - total_amp2_mae: 0.0455 - val_loss: 0.0720 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0543 - val_total_width2_loss: 0.0092 - val_total_amp2_loss: 0.0071 - val_Dense3_peak_number_mae: 0.0079 - val_total_center2_mae: 0.0849 - val_total_width2_mae: 0.0539 - val_total_amp2_mae: 0.0475
# Epoch 50/50
# 1800/1800 [==============================] - 56s 31ms/step - loss: 0.0703 - Dense3_peak_number_loss: 0.0020 - total_center2_loss: 0.0516 - total_width2_loss: 0.0096 - total_amp2_loss: 0.0070 - Dense3_peak_number_mae: 0.0119 - total_center2_mae: 0.0904 - total_width2_mae: 0.0560 - total_amp2_mae: 0.0453 - val_loss: 0.0738 - val_Dense3_peak_number_loss: 0.0014 - val_total_center2_loss: 0.0553 - val_total_width2_loss: 0.0102 - val_total_amp2_loss: 0.0069 - val_Dense3_peak_number_mae: 0.0063 - val_total_center2_mae: 0.0806 - val_total_width2_mae: 0.0593 - val_total_amp2_mae: 0.0441

# %%
test_graph.shape
# Out:
# (100000, 401, 1)

# %%
for key in models.history.keys():
    print(key)
# Out:
# loss
# Dense3_peak_number_loss
# total_center2_loss
# total_width2_loss
# total_amp2_loss
# Dense3_peak_number_mae
# total_center2_mae
# total_width2_mae
# total_amp2_mae
# val_loss
# val_Dense3_peak_number_loss
# val_total_center2_loss
# val_total_width2_loss
# val_total_amp2_loss
# val_Dense3_peak_number_mae
# val_total_center2_mae
# val_total_width2_mae
# val_total_amp2_mae

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width2_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp2_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp2_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (100000, 1)
# (100000, 3)
# (100000, 3)
# (100000, 3)

# %%
test_center[0][0]
test_width[0][0]
test_amp[0][0]
# Out:
# 1.029883260919523

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,alpha = 0.7,color='black')
    plt.plot(x,y(test_center[i][0],test_width[i][0],test_amp[i][0],x),color = 'blue',label = 'test_data')
    plt.plot(x,y(test_center[i][1],test_width[i][1],test_amp[i][1],x), color = 'blue')
    plt.plot(x,y(test_center[i][2],test_width[i][2],test_amp[i][2],x), color='blue')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'red',label='predict_data')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'red')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'red')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x)+
                y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x)+
                y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'black')
    plt.grid(True)
    plt.title('model3 and test_data')
    plt.legend()
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
    print('---------------')
    print('real_peak_number',test_peak_number[i])
    print('predict_peak_number',prediction[0][i])
# Out:
# real_center   [ 4.22027684  5.40905485 11.55720352]
# predict_center [ 4.184101 5.445795 11.482231 ]
# ---------------
# real_width    [0.53007741 0.82327543 0.65629519]
# predict_center [ 0.48564842 0.7756356 0.6426788 ]
# ---------------
# real_amp      [0.87850098 0.58603946 0.54691306]
# predict_center [ 0.85919267 0.5906023 0.54115885 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.998933]
# real_center   [ 5.28605073 10.23780681 10.36679915]
# predict_center [ 5.1723623 10.136525 10.338417 ]
# ---------------
# real_width    [0.52356667 1.6637154  0.76993815]
# predict_center [ 0.5460218 1.7126012 0.65414816 ]
# ---------------
# real_amp      [0.30736092 0.71421238 0.68100789]
# predict_center [ 0.28261733 0.7967273 0.57516396 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9996607]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [0.         4.49752746 5.96444561]
# predict_center [ -0.03846225 4.513764 5.8150206 ]
# ---------------
# real_width    [0.         0.39900653 0.84588452]
# predict_center [ 0.0026015565 0.50344557 0.7915679 ]
# ---------------
# real_amp      [0.         0.45926132 1.09854382]
# predict_center [ -0.008916721 0.44658104 1.084656 ]
# ---------------
# real_peak_number 2
# predict_peak_number [2.0006106]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [ 0.          3.3047985  12.99352645]
# predict_center [ -0.006962687 3.3588886 12.89532 ]
# ---------------
# real_width    [0.         0.4478863  0.35088863]
# predict_center [ 0.0069115385 0.46116436 0.34064054 ]
# ---------------
# real_amp      [0.         0.32086345 0.46099898]
# predict_center [ -0.0068814605 0.33849174 0.45731732 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9958048]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [ 0.          4.8426485  11.55435647]
# predict_center [ 0.03178653 4.868388 11.591303 ]
# ---------------
# real_width    [0.         1.31601144 1.64925784]
# predict_center [ 0.0033670887 1.3097368 1.5865861 ]
# ---------------
# real_amp      [0.         0.80830004 0.36808622]
# predict_center [ -0.009516701 0.7747799 0.35836858 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.986681]
# real_center   [ 9.11117501 10.02581162 11.06552237]
# predict_center [ 9.267765 10.124525 11.0469265 ]
# ---------------
# real_width    [1.57258002 1.63704521 1.6497351 ]
# predict_center [ 1.7906101 1.6263523 1.5482452 ]
# ---------------
# real_amp      [0.43383904 0.81651803 0.82199799]
# predict_center [ 0.642215 0.67021596 0.7961919 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9992952]
# real_center   [2.1124349  3.46346147 5.32328427]
# predict_center [ 2.3861332 3.6640825 5.3228703 ]
# ---------------
# real_width    [1.81294985 0.99210987 1.79777542]
# predict_center [ 1.8111519 0.9248291 1.7222568 ]
# ---------------
# real_amp      [0.16358486 0.23556273 0.86744568]
# predict_center [ 0.17707899 0.20380461 0.8088037 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0113218]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [0.         4.59307191 6.01879107]
# predict_center [ -0.02500698 4.5813284 5.9562836 ]
# ---------------
# real_width    [0.         0.36435987 1.2270683 ]
# predict_center [ -0.0008400157 0.3820425 1.203655 ]
# ---------------
# real_amp      [0.         0.3420562  0.81788491]
# predict_center [ -0.0064151585 0.3494844 0.79883575 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9973009]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [ 0.          7.9519182  11.78001011]
# predict_center [ -0.019052893 7.982002 11.756991 ]
# ---------------
# real_width    [0.         1.29919315 0.30911976]
# predict_center [ 0.0016767904 1.2660061 0.3124781 ]
# ---------------
# real_amp      [0.         0.9688613  0.38324308]
# predict_center [ -0.0015110075 0.9321426 0.35179126 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.997617]
# real_center   [ 7.39611371 11.38541982 12.5975426 ]
# predict_center [ 7.405468 11.406944 12.64123 ]
# ---------------
# real_width    [1.31412796 1.68856817 0.55079655]
# predict_center [ 1.267207 1.6554501 0.505895 ]
# ---------------
# real_amp      [0.83277974 1.00069316 0.84496746]
# predict_center [ 0.8100386 0.9335562 0.9035197 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9988797]
# real_center   [3.0693817  3.96119973 8.0167427 ]
# predict_center [ 3.0347075 3.886624 7.9885697 ]
# ---------------
# real_width    [1.66503023 0.34486068 1.64945117]
# predict_center [ 1.5036733 0.45354843 1.472648 ]
# ---------------
# real_amp      [0.44934336 0.90800808 0.37361167]
# predict_center [ 0.489832 0.94145656 0.35296583 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.001582]
# real_center   [ 5.02891449  6.11617453 11.81060695]
# predict_center [ 5.1159763 6.0157013 11.620512 ]
# ---------------
# real_width    [0.78586065 1.70826778 1.07889383]
# predict_center [ 0.774865 1.5515487 0.94776577 ]
# ---------------
# real_amp      [0.1202186  1.06748824 0.37421096]
# predict_center [ 0.18830052 1.0509089 0.3649813 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.001209]
# real_center   [6.32489051 6.3676705  9.95680784]
# predict_center [ 6.359627 7.134548 9.864643 ]
# ---------------
# real_width    [1.24102751 1.42493562 0.36778478]
# predict_center [ 1.3715496 1.1927446 0.38285577 ]
# ---------------
# real_amp      [0.12486871 0.29400373 0.63433201]
# predict_center [ 0.29332513 0.2212351 0.55195314 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.9903617]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [ 0.         10.99605454 11.03508472]
# predict_center [ -0.026962548 11.171638 10.873991 ]
# ---------------
# real_width    [0.         0.31831764 1.13505492]
# predict_center [ 0.022819214 0.50383115 0.98001224 ]
# ---------------
# real_amp      [0.         1.06211344 1.09051427]
# predict_center [ 0.0006284714 1.0217732 1.0296556 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9996028]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [0.         4.92825173 6.48574581]
# predict_center [ -0.009670407 5.0084276 6.368325 ]
# ---------------
# real_width    [0.         0.38443235 1.87049415]
# predict_center [ -0.008693345 0.31824654 1.8586915 ]
# ---------------
# real_amp      [0.         0.87340332 0.34363357]
# predict_center [ 0.000854969 0.81523013 0.42095882 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.997616]
# real_center   [4.5990877  5.02017657 5.90633586]
# predict_center [ 4.405526 5.0387707 5.850092 ]
# ---------------
# real_width    [1.63288069 1.69424667 1.01230295]
# predict_center [ 1.5401028 1.5374277 0.9380908 ]
# ---------------
# real_amp      [0.92968044 0.15186802 0.96511676]
# predict_center [ 0.6060557 0.5845989 0.86499393 ]
# ---------------
# real_peak_number 3
# predict_peak_number [2.994961]
# real_center   [4.91387817 8.92067754 9.1424057 ]
# predict_center [ 4.8966255 9.028655 9.173874 ]
# ---------------
# real_width    [0.33206284 0.93602344 1.59261149]
# predict_center [ 0.33391932 0.8994909 1.6050968 ]
# ---------------
# real_amp      [0.3044276  0.56082221 0.47185616]
# predict_center [ 0.28363943 0.6395469 0.3714201 ]
# ---------------
# real_peak_number 3
# predict_peak_number [3.0001574]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [ 0.          8.93206989 10.86473475]
# predict_center [ -0.009996086 8.995289 10.942875 ]
# ---------------
# real_width    [0.         1.54326027 0.7292138 ]
# predict_center [ 0.0070871636 1.5172586 0.71946806 ]
# ---------------
# real_amp      [0.         0.90378989 0.73664604]
# predict_center [ -0.003324777 0.9226651 0.7082691 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9975746]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [ 0.          3.78696558 12.2950481 ]
# predict_center [ -0.0069870055 3.8153741 12.316486 ]
# ---------------
# real_width    [0.         1.09888595 1.07603939]
# predict_center [ 0.006001197 1.1432052 0.9904386 ]
# ---------------
# real_amp      [0.         0.71861993 0.59122818]
# predict_center [ -0.003542021 0.7250092 0.5814264 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9896374]
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-69a298250a73>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# real_center   [0.         7.1622197  8.37241109]
# predict_center [ -0.034769922 7.160663 8.2950325 ]
# ---------------
# real_width    [0.         1.02515104 1.13988345]
# predict_center [ 0.010634713 0.9405127 1.2313669 ]
# ---------------
# real_amp      [0.         0.58262315 0.25556177]
# predict_center [ -0.004956484 0.5817276 0.2572242 ]
# ---------------
# real_peak_number 2
# predict_peak_number [1.9968016]

# %%
import matplotlib.pyplot as plt
import numpy as np


plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")


bg2 = np.flipud(bg)
exp2 = np.flipud(exp)
fitting2 = np.flipud(fitting)
peak12 = np.flipud(peak1)
peak22 = np.flipud(peak2)
peak32 = np.flipud(peak3)
# # 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp2[:, 1] - bg2[:, 1]) / ((exp2[:, 1] - bg2[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak12[:, 1] - bg2[:, 1])/ ((exp2[:, 1] - bg2[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak22[:, 1] - bg2[:, 1])/ ((exp2[:, 1] - bg2[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak32[:, 1] - bg2[:, 1])/ ((exp2[:, 1] - bg2[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("ITO 1S fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[1.995404]], dtype=float32), array([[-0.12012425, 10.489321  , 10.999261  ]], dtype=float32), array([[0.00373832, 1.6082937 , 0.770429  ]], dtype=float32), array([[0.001972  , 0.40453148, 0.7164981 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
new_predict
# Out:
# [array([1.995404], dtype=float32),
#  array([-0.12012425, 10.489321  , 10.999261  ], dtype=float32),
#  array([0.00373832, 1.6082937 , 0.770429  ], dtype=float32),
#  array([0.001972  , 0.40453148, 0.7164981 ], dtype=float32)]

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue',label = 'predict')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),label='predict1',color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),label = 'predict2',color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),label = 'predict3',color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()
plt.show()

# %%
print(new_predict[0],new_predict[1][2],new_predict[2][2],new_predict[3][2])
print(new_predict[0],new_predict[1][1],new_predict[2][1],new_predict[3][1])
print(new_predict[0],new_predict[1][0],new_predict[2][0],new_predict[3][0])
# Out:
# [1.995404] 10.999261 0.770429 0.7164981
# [1.995404] 10.489321 1.6082937 0.40453148
# [1.995404] -0.12012425 0.0037383214 0.0019720048

# %%
new_predict
# Out:
# [array([1.995404], dtype=float32),
#  array([-0.12012425, 10.489321  , 10.999261  ], dtype=float32),
#  array([0.00373832, 1.6082937 , 0.770429  ], dtype=float32),
#  array([0.001972  , 0.40453148, 0.7164981 ], dtype=float32)]

# %%
new_predict[0]
# Out:
# array([1.995404], dtype=float32)

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

bg2 = np.flipud(bg)
exp2 = np.flipud(exp)
fitting2 = np.flipud(fitting)
peak12 = np.flipud(peak1)
peak22 = np.flipud(peak2)
peak32 = np.flipud(peak3)

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp2[:, 1] - bg2[:, 1]) / ((exp2[:, 1] - bg2[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak12[:, 1] - bg2[:, 1])/ ((exp2[:, 1] - bg2[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak22[:, 1] - bg2[:, 1])/ ((exp2[:, 1] - bg2[:, 1]).max()), label = "peak2", linewidth = 2)
plt.title("P3HT 2p Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0218127]], dtype=float32), array([[-0.21707591,  7.4106374 ,  8.107648  ]], dtype=float32), array([[0.04833225, 0.476847  , 0.5341103 ]], dtype=float32), array([[0.0018467 , 0.43034452, 0.95050687]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),label='predict_total',color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),label= 'predict1',color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),label='predict2',color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),label = 'predict3',color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()
plt.show()

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')

error_peak_number_total=0
for i in range(test_peak_number.shape[0]):
    error_peak_number_total = error_peak_number_total + (abs(prediction[0][i]-test_peak_number[i]))
print('error_peak_number_total = ',error_peak_number_total)
error_peak_number = error_peak_number_total/test_peak_number.shape[0]
print('error_peak_number =  ',error_peak_number)
print('\n')
# Out:
# error_center_total =  [ 6613.89784471 10051.61203048  7593.3352174 ]
# error_center =   [0.06613898 0.10051612 0.07593335]
#
#
# error_width_total =  [4139.03652697 6909.05968894 6860.94031635]
# error_width =   [0.04139037 0.0690906  0.0686094 ]
#
#
# error_amp_total =  [3266.06361087 5491.56842386 4526.26422347]
# error_amp =   [0.03266064 0.05491568 0.04526264]
#
#
# error_peak_number_total =  [627.1753]
# error_peak_number =   [0.00627175]
