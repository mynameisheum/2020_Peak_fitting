# %%
# %ls
# Out:
# '2,3peak mix.ipynb'                    Untitled2.ipynb
# '5peak 3 para when it worksss.ipynb'   Untitled3.ipynb
# 'Fitting_with_noise (1).ipynb'         Untitled4.ipynb
#  ITO_O1s_bg.txt                        Untitled5.ipynb
#  ITO_O1s_exp.txt                       amp.csv
#  ITO_O1s_fitting.txt                   center.csv
#  ITO_O1s_p1.txt                        graph.csv
#  ITO_O1s_p2.txt                        labels.png
#  ITO_O1s_p3.txt                        model.png
#  P3HT_S2p_bg.txt                       model_shapes.png
#  P3HT_S2p_exp.txt                      peak_number.csv
#  P3HT_S2p_fitting.txt                  width.csv
#  P3HT_S2p_p1.txt                      '논문 수정.ipynb'
#  P3HT_S2p_p2.txt                      '데이터 얻기.ipynb'
#  PeakDetection.ipynb                  '저장된 데이터로 학습하기.ipynb'
#  Untitled.ipynb                       '저장된 데이터로 학습하기2.ipynb'
#  Untitled1.ipynb                      '저장된 데이터로 학습하기3.ipynb'

# %%
import pandas as pd
import numpy as np

# %%
graph = pd.read_csv('graph.csv').values[:,1:]
center= pd.read_csv('center.csv').values[:,1:]
width= pd.read_csv('width.csv').values[:,1:]
amp= pd.read_csv('amp.csv').values[:,1:]
peak_number= pd.read_csv('peak_number.csv').values[:,1:]

# %%
peak_number=peak_number.reshape(2000000,)

# %%
print(center[0:10])
print(width[0:10])
print(amp[0:10])
print(peak_number[0:10])
print(center.shape)
print(width.shape)
print(amp.shape)
print(peak_number.shape)
print(graph.shape)
print(graph)
# Out:
# [[ 0.          6.08688456 11.0810396 ]
#  [ 5.07493349  8.25999368 11.36195096]
#  [ 0.          2.67516221 10.60419171]
#  [ 0.          5.54053864 12.23836258]
#  [ 0.          4.08422309  7.21849474]
#  [ 0.          7.30192691 12.34014272]
#  [ 0.          2.54016398  5.16493207]
#  [ 0.          4.67819908  6.09299318]
#  [ 4.90655934  5.13202252 10.34134357]
#  [ 0.          5.36008602  5.98285268]]
# [[0.         1.24062404 0.95374601]
#  [0.60456503 0.35785198 1.1738216 ]
#  [0.         1.17339162 1.12952083]
#  [0.         0.81456259 0.81987822]
#  [0.         0.81681444 1.70560007]
#  [0.         0.32207246 0.75414831]
#  [0.         0.30486538 1.895045  ]
#  [0.         0.59293989 0.4647601 ]
#  [1.46428848 1.12931752 1.8841104 ]
#  [0.         1.00584571 1.33599321]]
# [[0.         0.21158879 0.18180892]
#  [0.11125957 0.85593768 0.31159992]
#  [0.         0.59012228 0.71652582]
#  [0.         1.00856931 0.70388527]
#  [0.         0.94976759 0.16667863]
#  [0.         0.43501787 0.93207997]
#  [0.         0.8393851  0.5707349 ]
#  [0.         0.11555586 0.72638366]
#  [1.00347794 0.40013242 0.8164851 ]
#  [0.         0.10848772 1.08853046]]
# [2 3 2 2 2 2 2 2 3 2]
# (2000000, 3)
# (2000000, 3)
# (2000000, 3)
# (2000000,)
# (2000000, 401)
# [[ 1.65293992e-02 -1.56062971e-02 -8.67543953e-07 ...  2.55348472e-02
#   -3.85644720e-02  5.34629487e-04]
#  [ 1.77760845e-02 -1.43048937e-02  2.75018580e-03 ...  2.09525854e-02
#   -8.81444533e-03 -2.84847278e-02]
#  [ 1.36186941e-02 -1.15794033e-02  1.45041681e-02 ...  3.96018586e-02
#   -3.21144103e-03  8.85769143e-03]
#  ...
#  [-1.24151960e-02 -2.96612110e-02 -2.18882173e-02 ... -3.89587815e-02
#   -3.64336021e-02  2.78148435e-02]
#  [ 5.39405308e-03 -3.18972828e-02  3.10126407e-03 ...  1.12031471e-02
#   -4.49491273e-02  2.58940119e-03]
#  [-2.81865060e-02 -1.40640285e-02  3.61211482e-02 ... -1.77982928e-02
#   -8.35706460e-03  1.54521213e-02]]

# %%
import matplotlib.pyplot as plt
x = np.linspace(0, 15, 401) 
def y(a,b,c,x):
    beta = 5.09791537e-01
    gamma = 4.41140472e-01
    y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
#     y = c*(b**2)/((x-a)**2+b**2)
    return y

# %%
for i in range(20,40):
    plt.figure(figsize = (8,4))
    plt.plot(x,graph[i],color = 'black')
    plt.plot(x,y(center[i][0],width[i][0],amp[i][0],x), color = 'blue')
    plt.plot(x,y(center[i][1],width[i][1],amp[i][1],x), color= 'green')
    plt.plot(x,y(center[i][2],width[i][2],amp[i][2],x), color='red')
# Out:
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: divide by zero encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))
# <ipython-input-6-74328273547d>:6: RuntimeWarning: invalid value encountered in true_divide
#   y = c * ( (0.7*np.exp(-np.log(2)*(x - a)**2 / (beta * b)**2)) + (0.3/(1 + (x - a)**2 / (gamma * b)**2)))

# %%
#90:9:1
data_number=1000000

train_graph = graph[:int(0.9*2*data_number)]
val_graph = graph[int(0.9*2*data_number):int(0.99*2*data_number)]
test_graph = graph[int(0.99*2*data_number):]

train_center = center[:int(0.9*2*data_number)]
val_center = center[int(0.9*2*data_number):int(0.99*2*data_number)]
test_center = center[int(0.99*2*data_number):]

train_width = width[:int(0.9*2*data_number)]
val_width = width[int(0.9*2*data_number):int(0.99*2*data_number)]
test_width = width[int(0.99*2*data_number):]

train_amp = amp[:int(0.9*2*data_number)]
val_amp = amp[int(0.9*2*data_number):int(0.99*2*data_number)]
test_amp = amp[int(0.99*2*data_number):]

train_peak_number = peak_number[:int(0.9*2*data_number)]
val_peak_number = peak_number[int(0.9*2*data_number):int(0.99*2*data_number)]
test_peak_number = peak_number[int(0.99*2*data_number):]

# %%
print(train_graph.shape, val_graph.shape, test_graph.shape)
print(train_center.shape, val_center.shape, test_center.shape)
print(train_width.shape, val_width.shape, test_width.shape)
print(train_amp.shape, val_amp.shape, test_amp.shape)
print(train_peak_number.shape, val_peak_number.shape, test_peak_number.shape)
# Out:
# (1800000, 401) (180000, 401) (20000, 401)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000, 3) (180000, 3) (20000, 3)
# (1800000,) (180000,) (20000,)

# %%
# conv1d 쓰기 위해 reshape 사용 
# 1차원 그래프 변환

train_graph = train_graph.reshape(train_graph.shape[0],train_graph.shape[1],1)
val_graph = val_graph.reshape(val_graph.shape[0],val_graph.shape[1],1)
test_graph = test_graph.reshape(test_graph.shape[0],test_graph.shape[1],1)

print(train_graph.shape)
print(val_graph.shape)
print(test_graph.shape)
# Out:
# (1800000, 401, 1)
# (180000, 401, 1)
# (20000, 401, 1)

# %%
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input, Dense, Flatten, BatchNormalization
from keras.layers.convolutional import Conv1D
from keras.layers.pooling import MaxPooling1D, GlobalMaxPooling1D
from keras.layers.merge import concatenate
from keras import layers

# %%
len(x)
# Out:
# 401

# %%
input_data = Input(shape = (len(x),1))
t = layers.Conv1D(128,100,activation = 'relu')(input_data)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,50,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(128,20,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)
t = layers.Conv1D(16,10,activation = 'relu')(t)
t = layers.MaxPooling1D(2)(t)

t = layers.GlobalMaxPooling1D()(t)

Dense1_peak_number = Dense(200, activation = 'relu',name='Dense1_peak_number')(t)
Dense2_peak_number = Dense(200, activation = 'relu',name = 'Dense2_peak_number')(Dense1_peak_number)
Dense3_peak_number = Dense(1, activation = 'linear',name = 'Dense3_peak_number')(Dense2_peak_number)


Dense1_center = Dense(200, activation = 'relu',name='Dense1_center')(t)
Dense2_center = Dense(100, activation = 'relu',name='Dense2_center')(Dense1_center)
Dense3_center = Dense(40, activation = 'relu',name='Dense3_center')(Dense2_center)
# output_center = Dense(3, activation = 'linear',name='output_center')(Dense3_center)

Dense1_width = Dense(200,activation = 'relu',name='Dense1_width')(t)
Dense2_width = Dense(100,activation = 'relu',name='Dense2_width')(Dense1_width)
Dense3_width = Dense(40,activation = 'relu',name='Dense3_width')(Dense2_width)
# output_width = Dense(3,activation = 'linear',name='output_width')(Dense3_width)

Dense1_amp = Dense(200,activation = 'relu',name='Dense1_amp')(t)
Dense2_amp = Dense(100,activation = 'relu',name='Dense2_amp')(Dense1_amp)
Dense3_amp = Dense(40,activation = 'relu',name='Dense3_amp')(Dense2_amp)
# output_amp = Dense(3,activation = 'linear',name='output_amp')(Dense3_amp)

center_merge = concatenate([Dense3_peak_number,Dense3_center])
total_center1 = Dense(40, activation = 'relu',name = 'total_center1')(center_merge)
total_center2 = Dense(40, activation = 'relu',name = 'total_center2')(total_center1)
total_center3 = Dense(3, activation = 'linear',name = 'total_center3')(total_center2)


width_merge = concatenate([Dense3_peak_number,Dense3_width])
total_width1 = Dense(40, activation = 'relu',name = 'total_width1')(width_merge)
total_width2 = Dense(40, activation = 'relu',name = 'total_width2')(total_width1)
total_width3 = Dense(3, activation = 'linear',name = 'total_width3')(total_width2)


amp_merge = concatenate([Dense3_peak_number,Dense3_amp])
total_amp1 = Dense(40, activation = 'relu',name = 'total_amp1')(amp_merge)
total_amp2 = Dense(40, activation = 'relu',name = 'total_amp2')(total_amp1)
total_amp3 = Dense(3, activation = 'linear',name = 'total_amp3')(total_amp2)


model = Model(inputs = input_data,
              outputs = [Dense3_peak_number,total_center3,total_width3,total_amp3])
print(model.summary())
plot_model(model)
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 401, 1)]     0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 302, 128)     12928       input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 151, 128)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 102, 128)     819328      max_pooling1d[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 51, 128)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 32, 128)      327808      max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 16, 128)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 7, 16)        20496       max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 3, 16)        0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d (GlobalMax (None, 16)           0           max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# Dense1_peak_number (Dense)      (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_center (Dense)           (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_width (Dense)            (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense1_amp (Dense)              (None, 200)          3400        global_max_pooling1d[0][0]
# __________________________________________________________________________________________________
# Dense2_peak_number (Dense)      (None, 200)          40200       Dense1_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense2_center (Dense)           (None, 100)          20100       Dense1_center[0][0]
# __________________________________________________________________________________________________
# Dense2_width (Dense)            (None, 100)          20100       Dense1_width[0][0]
# __________________________________________________________________________________________________
# Dense2_amp (Dense)              (None, 100)          20100       Dense1_amp[0][0]
# __________________________________________________________________________________________________
# Dense3_peak_number (Dense)      (None, 1)            201         Dense2_peak_number[0][0]
# __________________________________________________________________________________________________
# Dense3_center (Dense)           (None, 40)           4040        Dense2_center[0][0]
# __________________________________________________________________________________________________
# Dense3_width (Dense)            (None, 40)           4040        Dense2_width[0][0]
# __________________________________________________________________________________________________
# Dense3_amp (Dense)              (None, 40)           4040        Dense2_amp[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_center[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_width[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 41)           0           Dense3_peak_number[0][0]
#                                                                  Dense3_amp[0][0]
# __________________________________________________________________________________________________
# total_center1 (Dense)           (None, 40)           1680        concatenate[0][0]
# __________________________________________________________________________________________________
# total_width1 (Dense)            (None, 40)           1680        concatenate_1[0][0]
# __________________________________________________________________________________________________
# total_amp1 (Dense)              (None, 40)           1680        concatenate_2[0][0]
# __________________________________________________________________________________________________
# total_center2 (Dense)           (None, 40)           1640        total_center1[0][0]
# __________________________________________________________________________________________________
# total_width2 (Dense)            (None, 40)           1640        total_width1[0][0]
# __________________________________________________________________________________________________
# total_amp2 (Dense)              (None, 40)           1640        total_amp1[0][0]
# __________________________________________________________________________________________________
# total_center3 (Dense)           (None, 3)            123         total_center2[0][0]
# __________________________________________________________________________________________________
# total_width3 (Dense)            (None, 3)            123         total_width2[0][0]
# __________________________________________________________________________________________________
# total_amp3 (Dense)              (None, 3)            123         total_amp2[0][0]
# ==================================================================================================
# Total params: 1,317,310
# Trainable params: 1,317,310
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.keras.utils import plot_model

plot_model(model, to_file = 'labels.png')
plot_model(model, to_file='model_shapes.png', show_shapes=True)

# %%
model.compile(optimizer='adam',
              loss = {'total_center3' : 'mse',
                      'total_width3' : 'mse',
                      'total_amp3' : 'mse',
                      'Dense3_peak_number' : 'mse'},
#               loss_weights={'total_center3' : 0.5,
#                            'total_width3' : 1,
#                            'total_amp3' : 1,
#                             'Dense2_peak_number' :1 },
              metrics = ['mae'])

# %%
train_peak_number.shape
# Out:
# (1800000,)

# %%
models=model.fit(train_graph, [train_peak_number,train_center , train_width, train_amp],
          epochs = 50,
          batch_size = 1000,
          validation_data = (val_graph, [val_peak_number, val_center, val_width, val_amp]))
# Out:
# Epoch 1/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 3.1179 - Dense3_peak_number_loss: 0.1747 - total_center3_loss: 2.6757 - total_width3_loss: 0.1921 - total_amp3_loss: 0.0755 - Dense3_peak_number_mae: 0.3143 - total_center3_mae: 1.0510 - total_width3_mae: 0.3473 - total_amp3_mae: 0.2237 - val_loss: 1.0071 - val_Dense3_peak_number_loss: 0.0514 - val_total_center3_loss: 0.7832 - val_total_width3_loss: 0.1117 - val_total_amp3_loss: 0.0608 - val_Dense3_peak_number_mae: 0.1539 - val_total_center3_mae: 0.5179 - val_total_width3_mae: 0.2488 - val_total_amp3_mae: 0.1960
# Epoch 2/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.7114 - Dense3_peak_number_loss: 0.0315 - total_center3_loss: 0.5310 - total_width3_loss: 0.0908 - total_amp3_loss: 0.0581 - Dense3_peak_number_mae: 0.1056 - total_center3_mae: 0.3984 - total_width3_mae: 0.2150 - total_amp3_mae: 0.1886 - val_loss: 0.4587 - val_Dense3_peak_number_loss: 0.0138 - val_total_center3_loss: 0.3194 - val_total_width3_loss: 0.0735 - val_total_amp3_loss: 0.0520 - val_Dense3_peak_number_mae: 0.0605 - val_total_center3_mae: 0.2895 - val_total_width3_mae: 0.1878 - val_total_amp3_mae: 0.1754
# Epoch 3/50
# 1800/1800 [==============================] - 95s 53ms/step - loss: 0.4557 - Dense3_peak_number_loss: 0.0150 - total_center3_loss: 0.3220 - total_width3_loss: 0.0695 - total_amp3_loss: 0.0491 - Dense3_peak_number_mae: 0.0630 - total_center3_mae: 0.3018 - total_width3_mae: 0.1810 - total_amp3_mae: 0.1691 - val_loss: 0.3613 - val_Dense3_peak_number_loss: 0.0089 - val_total_center3_loss: 0.2428 - val_total_width3_loss: 0.0626 - val_total_amp3_loss: 0.0469 - val_Dense3_peak_number_mae: 0.0435 - val_total_center3_mae: 0.2709 - val_total_width3_mae: 0.1720 - val_total_amp3_mae: 0.1653
# Epoch 4/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.3614 - Dense3_peak_number_loss: 0.0107 - total_center3_loss: 0.2484 - total_width3_loss: 0.0602 - total_amp3_loss: 0.0423 - Dense3_peak_number_mae: 0.0486 - total_center3_mae: 0.2570 - total_width3_mae: 0.1654 - total_amp3_mae: 0.1535 - val_loss: 0.2923 - val_Dense3_peak_number_loss: 0.0077 - val_total_center3_loss: 0.1881 - val_total_width3_loss: 0.0556 - val_total_amp3_loss: 0.0410 - val_Dense3_peak_number_mae: 0.0368 - val_total_center3_mae: 0.2212 - val_total_width3_mae: 0.1585 - val_total_amp3_mae: 0.1501
# Epoch 5/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.3045 - Dense3_peak_number_loss: 0.0083 - total_center3_loss: 0.2038 - total_width3_loss: 0.0532 - total_amp3_loss: 0.0392 - Dense3_peak_number_mae: 0.0418 - total_center3_mae: 0.2274 - total_width3_mae: 0.1538 - total_amp3_mae: 0.1460 - val_loss: 0.2419 - val_Dense3_peak_number_loss: 0.0046 - val_total_center3_loss: 0.1551 - val_total_width3_loss: 0.0455 - val_total_amp3_loss: 0.0367 - val_Dense3_peak_number_mae: 0.0293 - val_total_center3_mae: 0.2143 - val_total_width3_mae: 0.1406 - val_total_amp3_mae: 0.1401
# Epoch 6/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.2728 - Dense3_peak_number_loss: 0.0072 - total_center3_loss: 0.1802 - total_width3_loss: 0.0473 - total_amp3_loss: 0.0381 - Dense3_peak_number_mae: 0.0381 - total_center3_mae: 0.2121 - total_width3_mae: 0.1438 - total_amp3_mae: 0.1430 - val_loss: 0.2455 - val_Dense3_peak_number_loss: 0.0087 - val_total_center3_loss: 0.1551 - val_total_width3_loss: 0.0437 - val_total_amp3_loss: 0.0381 - val_Dense3_peak_number_mae: 0.0610 - val_total_center3_mae: 0.1975 - val_total_width3_mae: 0.1383 - val_total_amp3_mae: 0.1438
# Epoch 7/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.2397 - Dense3_peak_number_loss: 0.0059 - total_center3_loss: 0.1547 - total_width3_loss: 0.0422 - total_amp3_loss: 0.0368 - Dense3_peak_number_mae: 0.0330 - total_center3_mae: 0.1944 - total_width3_mae: 0.1349 - total_amp3_mae: 0.1399 - val_loss: 0.1965 - val_Dense3_peak_number_loss: 0.0044 - val_total_center3_loss: 0.1205 - val_total_width3_loss: 0.0371 - val_total_amp3_loss: 0.0346 - val_Dense3_peak_number_mae: 0.0279 - val_total_center3_mae: 0.1623 - val_total_width3_mae: 0.1236 - val_total_amp3_mae: 0.1342
# Epoch 8/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.2230 - Dense3_peak_number_loss: 0.0054 - total_center3_loss: 0.1425 - total_width3_loss: 0.0392 - total_amp3_loss: 0.0359 - Dense3_peak_number_mae: 0.0299 - total_center3_mae: 0.1834 - total_width3_mae: 0.1290 - total_amp3_mae: 0.1375 - val_loss: 0.2002 - val_Dense3_peak_number_loss: 0.0040 - val_total_center3_loss: 0.1244 - val_total_width3_loss: 0.0381 - val_total_amp3_loss: 0.0338 - val_Dense3_peak_number_mae: 0.0213 - val_total_center3_mae: 0.1728 - val_total_width3_mae: 0.1262 - val_total_amp3_mae: 0.1329
# Epoch 9/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.2039 - Dense3_peak_number_loss: 0.0048 - total_center3_loss: 0.1279 - total_width3_loss: 0.0362 - total_amp3_loss: 0.0349 - Dense3_peak_number_mae: 0.0287 - total_center3_mae: 0.1741 - total_width3_mae: 0.1236 - total_amp3_mae: 0.1351 - val_loss: 0.1882 - val_Dense3_peak_number_loss: 0.0039 - val_total_center3_loss: 0.1147 - val_total_width3_loss: 0.0346 - val_total_amp3_loss: 0.0350 - val_Dense3_peak_number_mae: 0.0171 - val_total_center3_mae: 0.1536 - val_total_width3_mae: 0.1188 - val_total_amp3_mae: 0.1352
# Epoch 10/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.2033 - Dense3_peak_number_loss: 0.0048 - total_center3_loss: 0.1278 - total_width3_loss: 0.0359 - total_amp3_loss: 0.0347 - Dense3_peak_number_mae: 0.0264 - total_center3_mae: 0.1690 - total_width3_mae: 0.1228 - total_amp3_mae: 0.1342 - val_loss: 0.1749 - val_Dense3_peak_number_loss: 0.0041 - val_total_center3_loss: 0.1055 - val_total_width3_loss: 0.0322 - val_total_amp3_loss: 0.0330 - val_Dense3_peak_number_mae: 0.0338 - val_total_center3_mae: 0.1431 - val_total_width3_mae: 0.1175 - val_total_amp3_mae: 0.1317
# Epoch 11/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1814 - Dense3_peak_number_loss: 0.0041 - total_center3_loss: 0.1116 - total_width3_loss: 0.0325 - total_amp3_loss: 0.0332 - Dense3_peak_number_mae: 0.0254 - total_center3_mae: 0.1561 - total_width3_mae: 0.1162 - total_amp3_mae: 0.1306 - val_loss: 0.1647 - val_Dense3_peak_number_loss: 0.0043 - val_total_center3_loss: 0.0973 - val_total_width3_loss: 0.0305 - val_total_amp3_loss: 0.0327 - val_Dense3_peak_number_mae: 0.0292 - val_total_center3_mae: 0.1471 - val_total_width3_mae: 0.1132 - val_total_amp3_mae: 0.1302
# Epoch 12/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1790 - Dense3_peak_number_loss: 0.0041 - total_center3_loss: 0.1102 - total_width3_loss: 0.0318 - total_amp3_loss: 0.0329 - Dense3_peak_number_mae: 0.0245 - total_center3_mae: 0.1551 - total_width3_mae: 0.1151 - total_amp3_mae: 0.1299 - val_loss: 0.1576 - val_Dense3_peak_number_loss: 0.0029 - val_total_center3_loss: 0.0941 - val_total_width3_loss: 0.0301 - val_total_amp3_loss: 0.0305 - val_Dense3_peak_number_mae: 0.0214 - val_total_center3_mae: 0.1327 - val_total_width3_mae: 0.1117 - val_total_amp3_mae: 0.1244
# Epoch 13/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1678 - Dense3_peak_number_loss: 0.0036 - total_center3_loss: 0.1016 - total_width3_loss: 0.0304 - total_amp3_loss: 0.0321 - Dense3_peak_number_mae: 0.0230 - total_center3_mae: 0.1490 - total_width3_mae: 0.1123 - total_amp3_mae: 0.1278 - val_loss: 0.1679 - val_Dense3_peak_number_loss: 0.0033 - val_total_center3_loss: 0.1063 - val_total_width3_loss: 0.0282 - val_total_amp3_loss: 0.0302 - val_Dense3_peak_number_mae: 0.0150 - val_total_center3_mae: 0.1431 - val_total_width3_mae: 0.1056 - val_total_amp3_mae: 0.1214
# Epoch 14/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1596 - Dense3_peak_number_loss: 0.0033 - total_center3_loss: 0.0959 - total_width3_loss: 0.0290 - total_amp3_loss: 0.0315 - Dense3_peak_number_mae: 0.0211 - total_center3_mae: 0.1434 - total_width3_mae: 0.1097 - total_amp3_mae: 0.1258 - val_loss: 0.1484 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0872 - val_total_width3_loss: 0.0275 - val_total_amp3_loss: 0.0317 - val_Dense3_peak_number_mae: 0.0120 - val_total_center3_mae: 0.1343 - val_total_width3_mae: 0.1063 - val_total_amp3_mae: 0.1259
# Epoch 15/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1550 - Dense3_peak_number_loss: 0.0031 - total_center3_loss: 0.0927 - total_width3_loss: 0.0282 - total_amp3_loss: 0.0310 - Dense3_peak_number_mae: 0.0205 - total_center3_mae: 0.1416 - total_width3_mae: 0.1078 - total_amp3_mae: 0.1246 - val_loss: 0.1408 - val_Dense3_peak_number_loss: 0.0018 - val_total_center3_loss: 0.0807 - val_total_width3_loss: 0.0278 - val_total_amp3_loss: 0.0305 - val_Dense3_peak_number_mae: 0.0130 - val_total_center3_mae: 0.1313 - val_total_width3_mae: 0.1086 - val_total_amp3_mae: 0.1252
# Epoch 16/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1468 - Dense3_peak_number_loss: 0.0028 - total_center3_loss: 0.0860 - total_width3_loss: 0.0274 - total_amp3_loss: 0.0305 - Dense3_peak_number_mae: 0.0189 - total_center3_mae: 0.1354 - total_width3_mae: 0.1063 - total_amp3_mae: 0.1232 - val_loss: 0.1796 - val_Dense3_peak_number_loss: 0.0029 - val_total_center3_loss: 0.1137 - val_total_width3_loss: 0.0308 - val_total_amp3_loss: 0.0323 - val_Dense3_peak_number_mae: 0.0219 - val_total_center3_mae: 0.1844 - val_total_width3_mae: 0.1192 - val_total_amp3_mae: 0.1286
# Epoch 17/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1447 - Dense3_peak_number_loss: 0.0028 - total_center3_loss: 0.0848 - total_width3_loss: 0.0269 - total_amp3_loss: 0.0301 - Dense3_peak_number_mae: 0.0177 - total_center3_mae: 0.1342 - total_width3_mae: 0.1052 - total_amp3_mae: 0.1221 - val_loss: 0.1412 - val_Dense3_peak_number_loss: 0.0024 - val_total_center3_loss: 0.0825 - val_total_width3_loss: 0.0257 - val_total_amp3_loss: 0.0306 - val_Dense3_peak_number_mae: 0.0173 - val_total_center3_mae: 0.1261 - val_total_width3_mae: 0.1029 - val_total_amp3_mae: 0.1240
# Epoch 18/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1421 - Dense3_peak_number_loss: 0.0027 - total_center3_loss: 0.0827 - total_width3_loss: 0.0267 - total_amp3_loss: 0.0300 - Dense3_peak_number_mae: 0.0162 - total_center3_mae: 0.1318 - total_width3_mae: 0.1046 - total_amp3_mae: 0.1215 - val_loss: 0.1487 - val_Dense3_peak_number_loss: 0.0026 - val_total_center3_loss: 0.0916 - val_total_width3_loss: 0.0258 - val_total_amp3_loss: 0.0288 - val_Dense3_peak_number_mae: 0.0131 - val_total_center3_mae: 0.1289 - val_total_width3_mae: 0.1008 - val_total_amp3_mae: 0.1186
# Epoch 19/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1377 - Dense3_peak_number_loss: 0.0025 - total_center3_loss: 0.0794 - total_width3_loss: 0.0264 - total_amp3_loss: 0.0295 - Dense3_peak_number_mae: 0.0156 - total_center3_mae: 0.1306 - total_width3_mae: 0.1039 - total_amp3_mae: 0.1203 - val_loss: 0.1315 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0762 - val_total_width3_loss: 0.0246 - val_total_amp3_loss: 0.0289 - val_Dense3_peak_number_mae: 0.0161 - val_total_center3_mae: 0.1228 - val_total_width3_mae: 0.0990 - val_total_amp3_mae: 0.1192
# Epoch 20/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1305 - Dense3_peak_number_loss: 0.0022 - total_center3_loss: 0.0740 - total_width3_loss: 0.0253 - total_amp3_loss: 0.0289 - Dense3_peak_number_mae: 0.0133 - total_center3_mae: 0.1259 - total_width3_mae: 0.1015 - total_amp3_mae: 0.1187 - val_loss: 0.1271 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0732 - val_total_width3_loss: 0.0243 - val_total_amp3_loss: 0.0277 - val_Dense3_peak_number_mae: 0.0095 - val_total_center3_mae: 0.1150 - val_total_width3_mae: 0.0975 - val_total_amp3_mae: 0.1149
# Epoch 21/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1316 - Dense3_peak_number_loss: 0.0023 - total_center3_loss: 0.0748 - total_width3_loss: 0.0254 - total_amp3_loss: 0.0290 - Dense3_peak_number_mae: 0.0130 - total_center3_mae: 0.1262 - total_width3_mae: 0.1018 - total_amp3_mae: 0.1188 - val_loss: 0.1354 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0813 - val_total_width3_loss: 0.0239 - val_total_amp3_loss: 0.0283 - val_Dense3_peak_number_mae: 0.0138 - val_total_center3_mae: 0.1229 - val_total_width3_mae: 0.0982 - val_total_amp3_mae: 0.1174
# Epoch 22/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1257 - Dense3_peak_number_loss: 0.0021 - total_center3_loss: 0.0702 - total_width3_loss: 0.0247 - total_amp3_loss: 0.0287 - Dense3_peak_number_mae: 0.0114 - total_center3_mae: 0.1227 - total_width3_mae: 0.1004 - total_amp3_mae: 0.1178 - val_loss: 0.1408 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0861 - val_total_width3_loss: 0.0239 - val_total_amp3_loss: 0.0287 - val_Dense3_peak_number_mae: 0.0128 - val_total_center3_mae: 0.1204 - val_total_width3_mae: 0.0990 - val_total_amp3_mae: 0.1182
# Epoch 23/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1225 - Dense3_peak_number_loss: 0.0020 - total_center3_loss: 0.0678 - total_width3_loss: 0.0243 - total_amp3_loss: 0.0284 - Dense3_peak_number_mae: 0.0106 - total_center3_mae: 0.1211 - total_width3_mae: 0.0994 - total_amp3_mae: 0.1170 - val_loss: 0.1352 - val_Dense3_peak_number_loss: 0.0018 - val_total_center3_loss: 0.0800 - val_total_width3_loss: 0.0247 - val_total_amp3_loss: 0.0287 - val_Dense3_peak_number_mae: 0.0093 - val_total_center3_mae: 0.1241 - val_total_width3_mae: 0.1022 - val_total_amp3_mae: 0.1183
# Epoch 24/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1213 - Dense3_peak_number_loss: 0.0019 - total_center3_loss: 0.0670 - total_width3_loss: 0.0242 - total_amp3_loss: 0.0282 - Dense3_peak_number_mae: 0.0102 - total_center3_mae: 0.1199 - total_width3_mae: 0.0992 - total_amp3_mae: 0.1166 - val_loss: 0.1483 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0937 - val_total_width3_loss: 0.0238 - val_total_amp3_loss: 0.0289 - val_Dense3_peak_number_mae: 0.0082 - val_total_center3_mae: 0.1404 - val_total_width3_mae: 0.0979 - val_total_amp3_mae: 0.1190
# Epoch 25/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1145 - Dense3_peak_number_loss: 0.0017 - total_center3_loss: 0.0617 - total_width3_loss: 0.0235 - total_amp3_loss: 0.0277 - Dense3_peak_number_mae: 0.0093 - total_center3_mae: 0.1154 - total_width3_mae: 0.0974 - total_amp3_mae: 0.1151 - val_loss: 0.1170 - val_Dense3_peak_number_loss: 0.0014 - val_total_center3_loss: 0.0659 - val_total_width3_loss: 0.0231 - val_total_amp3_loss: 0.0266 - val_Dense3_peak_number_mae: 0.0080 - val_total_center3_mae: 0.1042 - val_total_width3_mae: 0.0965 - val_total_amp3_mae: 0.1114
# Epoch 26/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1159 - Dense3_peak_number_loss: 0.0018 - total_center3_loss: 0.0626 - total_width3_loss: 0.0238 - total_amp3_loss: 0.0278 - Dense3_peak_number_mae: 0.0093 - total_center3_mae: 0.1163 - total_width3_mae: 0.0984 - total_amp3_mae: 0.1154 - val_loss: 0.1325 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0782 - val_total_width3_loss: 0.0244 - val_total_amp3_loss: 0.0279 - val_Dense3_peak_number_mae: 0.0064 - val_total_center3_mae: 0.1104 - val_total_width3_mae: 0.0998 - val_total_amp3_mae: 0.1150
# Epoch 27/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1130 - Dense3_peak_number_loss: 0.0017 - total_center3_loss: 0.0602 - total_width3_loss: 0.0233 - total_amp3_loss: 0.0277 - Dense3_peak_number_mae: 0.0091 - total_center3_mae: 0.1143 - total_width3_mae: 0.0971 - total_amp3_mae: 0.1152 - val_loss: 0.1287 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0778 - val_total_width3_loss: 0.0226 - val_total_amp3_loss: 0.0263 - val_Dense3_peak_number_mae: 0.0062 - val_total_center3_mae: 0.1039 - val_total_width3_mae: 0.0932 - val_total_amp3_mae: 0.1103
# Epoch 28/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1099 - Dense3_peak_number_loss: 0.0016 - total_center3_loss: 0.0581 - total_width3_loss: 0.0230 - total_amp3_loss: 0.0272 - Dense3_peak_number_mae: 0.0085 - total_center3_mae: 0.1117 - total_width3_mae: 0.0964 - total_amp3_mae: 0.1137 - val_loss: 0.1214 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0703 - val_total_width3_loss: 0.0228 - val_total_amp3_loss: 0.0268 - val_Dense3_peak_number_mae: 0.0086 - val_total_center3_mae: 0.1145 - val_total_width3_mae: 0.0951 - val_total_amp3_mae: 0.1124
# Epoch 29/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1120 - Dense3_peak_number_loss: 0.0017 - total_center3_loss: 0.0595 - total_width3_loss: 0.0234 - total_amp3_loss: 0.0274 - Dense3_peak_number_mae: 0.0088 - total_center3_mae: 0.1137 - total_width3_mae: 0.0973 - total_amp3_mae: 0.1142 - val_loss: 0.1279 - val_Dense3_peak_number_loss: 0.0017 - val_total_center3_loss: 0.0749 - val_total_width3_loss: 0.0237 - val_total_amp3_loss: 0.0276 - val_Dense3_peak_number_mae: 0.0088 - val_total_center3_mae: 0.1121 - val_total_width3_mae: 0.0983 - val_total_amp3_mae: 0.1159
# Epoch 30/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.1060 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0550 - total_width3_loss: 0.0226 - total_amp3_loss: 0.0270 - Dense3_peak_number_mae: 0.0079 - total_center3_mae: 0.1100 - total_width3_mae: 0.0956 - total_amp3_mae: 0.1129 - val_loss: 0.1155 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0652 - val_total_width3_loss: 0.0221 - val_total_amp3_loss: 0.0267 - val_Dense3_peak_number_mae: 0.0071 - val_total_center3_mae: 0.1081 - val_total_width3_mae: 0.0953 - val_total_amp3_mae: 0.1123
# Epoch 31/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1068 - Dense3_peak_number_loss: 0.0016 - total_center3_loss: 0.0555 - total_width3_loss: 0.0227 - total_amp3_loss: 0.0269 - Dense3_peak_number_mae: 0.0082 - total_center3_mae: 0.1103 - total_width3_mae: 0.0959 - total_amp3_mae: 0.1129 - val_loss: 0.1224 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0713 - val_total_width3_loss: 0.0222 - val_total_amp3_loss: 0.0269 - val_Dense3_peak_number_mae: 0.0072 - val_total_center3_mae: 0.1045 - val_total_width3_mae: 0.0935 - val_total_amp3_mae: 0.1121
# Epoch 32/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1046 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0541 - total_width3_loss: 0.0223 - total_amp3_loss: 0.0267 - Dense3_peak_number_mae: 0.0078 - total_center3_mae: 0.1083 - total_width3_mae: 0.0946 - total_amp3_mae: 0.1123 - val_loss: 0.1181 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0686 - val_total_width3_loss: 0.0215 - val_total_amp3_loss: 0.0265 - val_Dense3_peak_number_mae: 0.0068 - val_total_center3_mae: 0.1049 - val_total_width3_mae: 0.0927 - val_total_amp3_mae: 0.1108
# Epoch 33/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1027 - Dense3_peak_number_loss: 0.0015 - total_center3_loss: 0.0525 - total_width3_loss: 0.0223 - total_amp3_loss: 0.0265 - Dense3_peak_number_mae: 0.0079 - total_center3_mae: 0.1071 - total_width3_mae: 0.0948 - total_amp3_mae: 0.1116 - val_loss: 0.1128 - val_Dense3_peak_number_loss: 0.0012 - val_total_center3_loss: 0.0642 - val_total_width3_loss: 0.0217 - val_total_amp3_loss: 0.0256 - val_Dense3_peak_number_mae: 0.0044 - val_total_center3_mae: 0.1021 - val_total_width3_mae: 0.0935 - val_total_amp3_mae: 0.1084
# Epoch 34/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1020 - Dense3_peak_number_loss: 0.0014 - total_center3_loss: 0.0518 - total_width3_loss: 0.0222 - total_amp3_loss: 0.0266 - Dense3_peak_number_mae: 0.0080 - total_center3_mae: 0.1071 - total_width3_mae: 0.0948 - total_amp3_mae: 0.1118 - val_loss: 0.1211 - val_Dense3_peak_number_loss: 0.0019 - val_total_center3_loss: 0.0695 - val_total_width3_loss: 0.0232 - val_total_amp3_loss: 0.0265 - val_Dense3_peak_number_mae: 0.0085 - val_total_center3_mae: 0.1102 - val_total_width3_mae: 0.0973 - val_total_amp3_mae: 0.1118
# Epoch 35/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.1004 - Dense3_peak_number_loss: 0.0014 - total_center3_loss: 0.0509 - total_width3_loss: 0.0218 - total_amp3_loss: 0.0264 - Dense3_peak_number_mae: 0.0081 - total_center3_mae: 0.1059 - total_width3_mae: 0.0938 - total_amp3_mae: 0.1113 - val_loss: 0.1129 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0648 - val_total_width3_loss: 0.0210 - val_total_amp3_loss: 0.0256 - val_Dense3_peak_number_mae: 0.0063 - val_total_center3_mae: 0.1009 - val_total_width3_mae: 0.0906 - val_total_amp3_mae: 0.1087
# Epoch 36/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.0990 - Dense3_peak_number_loss: 0.0014 - total_center3_loss: 0.0496 - total_width3_loss: 0.0218 - total_amp3_loss: 0.0262 - Dense3_peak_number_mae: 0.0078 - total_center3_mae: 0.1052 - total_width3_mae: 0.0938 - total_amp3_mae: 0.1109 - val_loss: 0.1122 - val_Dense3_peak_number_loss: 0.0015 - val_total_center3_loss: 0.0635 - val_total_width3_loss: 0.0215 - val_total_amp3_loss: 0.0257 - val_Dense3_peak_number_mae: 0.0101 - val_total_center3_mae: 0.0994 - val_total_width3_mae: 0.0919 - val_total_amp3_mae: 0.1094
# Epoch 37/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0957 - Dense3_peak_number_loss: 0.0012 - total_center3_loss: 0.0471 - total_width3_loss: 0.0214 - total_amp3_loss: 0.0260 - Dense3_peak_number_mae: 0.0075 - total_center3_mae: 0.1019 - total_width3_mae: 0.0927 - total_amp3_mae: 0.1100 - val_loss: 0.1107 - val_Dense3_peak_number_loss: 0.0013 - val_total_center3_loss: 0.0634 - val_total_width3_loss: 0.0204 - val_total_amp3_loss: 0.0255 - val_Dense3_peak_number_mae: 0.0048 - val_total_center3_mae: 0.0972 - val_total_width3_mae: 0.0892 - val_total_amp3_mae: 0.1079
# Epoch 38/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0987 - Dense3_peak_number_loss: 0.0014 - total_center3_loss: 0.0496 - total_width3_loss: 0.0216 - total_amp3_loss: 0.0261 - Dense3_peak_number_mae: 0.0077 - total_center3_mae: 0.1040 - total_width3_mae: 0.0933 - total_amp3_mae: 0.1105 - val_loss: 0.1098 - val_Dense3_peak_number_loss: 0.0014 - val_total_center3_loss: 0.0612 - val_total_width3_loss: 0.0214 - val_total_amp3_loss: 0.0257 - val_Dense3_peak_number_mae: 0.0064 - val_total_center3_mae: 0.1013 - val_total_width3_mae: 0.0927 - val_total_amp3_mae: 0.1093
# Epoch 39/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0961 - Dense3_peak_number_loss: 0.0013 - total_center3_loss: 0.0475 - total_width3_loss: 0.0213 - total_amp3_loss: 0.0260 - Dense3_peak_number_mae: 0.0079 - total_center3_mae: 0.1029 - total_width3_mae: 0.0928 - total_amp3_mae: 0.1102 - val_loss: 0.1231 - val_Dense3_peak_number_loss: 0.0021 - val_total_center3_loss: 0.0726 - val_total_width3_loss: 0.0223 - val_total_amp3_loss: 0.0261 - val_Dense3_peak_number_mae: 0.0088 - val_total_center3_mae: 0.1045 - val_total_width3_mae: 0.0951 - val_total_amp3_mae: 0.1104
# Epoch 40/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0917 - Dense3_peak_number_loss: 0.0012 - total_center3_loss: 0.0440 - total_width3_loss: 0.0210 - total_amp3_loss: 0.0255 - Dense3_peak_number_mae: 0.0073 - total_center3_mae: 0.0994 - total_width3_mae: 0.0917 - total_amp3_mae: 0.1088 - val_loss: 0.1295 - val_Dense3_peak_number_loss: 0.0014 - val_total_center3_loss: 0.0765 - val_total_width3_loss: 0.0242 - val_total_amp3_loss: 0.0274 - val_Dense3_peak_number_mae: 0.0072 - val_total_center3_mae: 0.1139 - val_total_width3_mae: 0.0988 - val_total_amp3_mae: 0.1143
# Epoch 41/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0950 - Dense3_peak_number_loss: 0.0012 - total_center3_loss: 0.0465 - total_width3_loss: 0.0214 - total_amp3_loss: 0.0258 - Dense3_peak_number_mae: 0.0077 - total_center3_mae: 0.1016 - total_width3_mae: 0.0929 - total_amp3_mae: 0.1096 - val_loss: 0.1217 - val_Dense3_peak_number_loss: 0.0025 - val_total_center3_loss: 0.0712 - val_total_width3_loss: 0.0223 - val_total_amp3_loss: 0.0258 - val_Dense3_peak_number_mae: 0.0069 - val_total_center3_mae: 0.1020 - val_total_width3_mae: 0.0939 - val_total_amp3_mae: 0.1084
# Epoch 42/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0911 - Dense3_peak_number_loss: 0.0011 - total_center3_loss: 0.0436 - total_width3_loss: 0.0208 - total_amp3_loss: 0.0255 - Dense3_peak_number_mae: 0.0072 - total_center3_mae: 0.0994 - total_width3_mae: 0.0914 - total_amp3_mae: 0.1089 - val_loss: 0.1162 - val_Dense3_peak_number_loss: 0.0016 - val_total_center3_loss: 0.0673 - val_total_width3_loss: 0.0220 - val_total_amp3_loss: 0.0253 - val_Dense3_peak_number_mae: 0.0046 - val_total_center3_mae: 0.1015 - val_total_width3_mae: 0.0940 - val_total_amp3_mae: 0.1070
# Epoch 43/50
# 1800/1800 [==============================] - 93s 52ms/step - loss: 0.0943 - Dense3_peak_number_loss: 0.0013 - total_center3_loss: 0.0458 - total_width3_loss: 0.0213 - total_amp3_loss: 0.0259 - Dense3_peak_number_mae: 0.0078 - total_center3_mae: 0.1023 - total_width3_mae: 0.0928 - total_amp3_mae: 0.1099 - val_loss: 0.1190 - val_Dense3_peak_number_loss: 0.0018 - val_total_center3_loss: 0.0705 - val_total_width3_loss: 0.0215 - val_total_amp3_loss: 0.0253 - val_Dense3_peak_number_mae: 0.0079 - val_total_center3_mae: 0.1025 - val_total_width3_mae: 0.0918 - val_total_amp3_mae: 0.1081
# Epoch 44/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0904 - Dense3_peak_number_loss: 0.0012 - total_center3_loss: 0.0431 - total_width3_loss: 0.0207 - total_amp3_loss: 0.0254 - Dense3_peak_number_mae: 0.0073 - total_center3_mae: 0.0981 - total_width3_mae: 0.0912 - total_amp3_mae: 0.1085 - val_loss: 0.1138 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0657 - val_total_width3_loss: 0.0209 - val_total_amp3_loss: 0.0252 - val_Dense3_peak_number_mae: 0.0058 - val_total_center3_mae: 0.0989 - val_total_width3_mae: 0.0927 - val_total_amp3_mae: 0.1079
# Epoch 45/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0897 - Dense3_peak_number_loss: 0.0011 - total_center3_loss: 0.0426 - total_width3_loss: 0.0208 - total_amp3_loss: 0.0252 - Dense3_peak_number_mae: 0.0073 - total_center3_mae: 0.0980 - total_width3_mae: 0.0912 - total_amp3_mae: 0.1080 - val_loss: 0.1280 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0799 - val_total_width3_loss: 0.0213 - val_total_amp3_loss: 0.0247 - val_Dense3_peak_number_mae: 0.0072 - val_total_center3_mae: 0.1011 - val_total_width3_mae: 0.0911 - val_total_amp3_mae: 0.1055
# Epoch 46/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0880 - Dense3_peak_number_loss: 0.0011 - total_center3_loss: 0.0415 - total_width3_loss: 0.0203 - total_amp3_loss: 0.0251 - Dense3_peak_number_mae: 0.0070 - total_center3_mae: 0.0967 - total_width3_mae: 0.0904 - total_amp3_mae: 0.1077 - val_loss: 0.1272 - val_Dense3_peak_number_loss: 0.0022 - val_total_center3_loss: 0.0766 - val_total_width3_loss: 0.0226 - val_total_amp3_loss: 0.0257 - val_Dense3_peak_number_mae: 0.0132 - val_total_center3_mae: 0.1110 - val_total_width3_mae: 0.0950 - val_total_amp3_mae: 0.1079
# Epoch 47/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0881 - Dense3_peak_number_loss: 0.0011 - total_center3_loss: 0.0415 - total_width3_loss: 0.0205 - total_amp3_loss: 0.0251 - Dense3_peak_number_mae: 0.0074 - total_center3_mae: 0.0973 - total_width3_mae: 0.0909 - total_amp3_mae: 0.1076 - val_loss: 0.1124 - val_Dense3_peak_number_loss: 0.0013 - val_total_center3_loss: 0.0657 - val_total_width3_loss: 0.0206 - val_total_amp3_loss: 0.0247 - val_Dense3_peak_number_mae: 0.0052 - val_total_center3_mae: 0.0999 - val_total_width3_mae: 0.0904 - val_total_amp3_mae: 0.1065
# Epoch 48/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0881 - Dense3_peak_number_loss: 0.0010 - total_center3_loss: 0.0415 - total_width3_loss: 0.0204 - total_amp3_loss: 0.0251 - Dense3_peak_number_mae: 0.0071 - total_center3_mae: 0.0966 - total_width3_mae: 0.0905 - total_amp3_mae: 0.1078 - val_loss: 0.1172 - val_Dense3_peak_number_loss: 0.0018 - val_total_center3_loss: 0.0695 - val_total_width3_loss: 0.0211 - val_total_amp3_loss: 0.0248 - val_Dense3_peak_number_mae: 0.0049 - val_total_center3_mae: 0.0933 - val_total_width3_mae: 0.0904 - val_total_amp3_mae: 0.1056
# Epoch 49/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0856 - Dense3_peak_number_loss: 0.0010 - total_center3_loss: 0.0395 - total_width3_loss: 0.0203 - total_amp3_loss: 0.0248 - Dense3_peak_number_mae: 0.0069 - total_center3_mae: 0.0953 - total_width3_mae: 0.0902 - total_amp3_mae: 0.1067 - val_loss: 0.1187 - val_Dense3_peak_number_loss: 0.0020 - val_total_center3_loss: 0.0712 - val_total_width3_loss: 0.0205 - val_total_amp3_loss: 0.0249 - val_Dense3_peak_number_mae: 0.0119 - val_total_center3_mae: 0.1037 - val_total_width3_mae: 0.0906 - val_total_amp3_mae: 0.1069
# Epoch 50/50
# 1800/1800 [==============================] - 94s 52ms/step - loss: 0.0864 - Dense3_peak_number_loss: 0.0011 - total_center3_loss: 0.0404 - total_width3_loss: 0.0202 - total_amp3_loss: 0.0247 - Dense3_peak_number_mae: 0.0070 - total_center3_mae: 0.0962 - total_width3_mae: 0.0901 - total_amp3_mae: 0.1066 - val_loss: 0.1405 - val_Dense3_peak_number_loss: 0.0026 - val_total_center3_loss: 0.0883 - val_total_width3_loss: 0.0241 - val_total_amp3_loss: 0.0256 - val_Dense3_peak_number_mae: 0.0109 - val_total_center3_mae: 0.1071 - val_total_width3_mae: 0.0984 - val_total_amp3_mae: 0.1095

# %%
test_graph.shape
# Out:
# (20000, 401, 1)

# %%
for key in models.history.keys():
    print(key)
# Out:
# loss
# Dense3_peak_number_loss
# total_center3_loss
# total_width3_loss
# total_amp3_loss
# Dense3_peak_number_mae
# total_center3_mae
# total_width3_mae
# total_amp3_mae
# val_loss
# val_Dense3_peak_number_loss
# val_total_center3_loss
# val_total_width3_loss
# val_total_amp3_loss
# val_Dense3_peak_number_mae
# val_total_center3_mae
# val_total_width3_mae
# val_total_amp3_mae

# %%
plt.figure(figsize = (25, 15))

plt.subplot(231)
plt.plot(models.history['loss'], 'b-', label = 'training')
plt.plot(models.history['val_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Total Loss", size = 32)
plt.legend()


plt.subplot(232)
plt.plot(models.history['Dense3_peak_number_loss'], 'b-', label = 'training')
plt.plot(models.history['val_Dense3_peak_number_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("Number of Peak Loss", size = 32)
plt.legend()

plt.subplot(233)
plt.plot(models.history['total_center3_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_center3_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("center Loss", size = 32)
plt.legend()

plt.subplot(234)
plt.plot(models.history['total_width3_loss'], 'b-', label = 'training')
plt.plot(models.history['val_total_width3_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("width Loss", size = 32)
plt.legend()

plt.subplot(235)
plt.plot(models.history['total_amp3_mae'], 'b-', label = 'training')
plt.plot(models.history['val_total_amp3_loss'], 'r:', label = 'validation')
plt.grid(True)
plt.title("amp Loss", size = 32)
plt.legend()

# %%
prediction = model.predict(test_graph)
print(len(prediction))
# Out:
# 4

# %%
print(prediction[0].shape)
print(prediction[1].shape)# if center
print(prediction[2].shape)# width
print(prediction[3].shape)# amp
# Out:
# (20000, 1)
# (20000, 3)
# (20000, 3)
# (20000, 3)

# %%
for i in range(30,50):

    plt.figure(figsize=(12,6))
    plt.plot(x,test_graph[i] ,color='black')
    plt.plot(x,y(prediction[1][i][0],prediction[2][i][0],prediction[3][i][0],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][1],prediction[2][i][1],prediction[3][i][1],x),color = 'blue')
    plt.plot(x,y(prediction[1][i][2],prediction[2][i][2],prediction[3][i][2],x),color = 'blue')
    plt.grid(True)
    plt.show()
    print('real_center  ',test_center[i])
    print('predict_center','[',prediction[1][i][0],prediction[1][i][1],prediction[1][i][2],']')
    print('---------------')
    print('real_width   ',test_width[i])
    print('predict_center','[',prediction[2][i][0],prediction[2][i][1],prediction[2][i][2],']')
    print('---------------')
    print('real_amp     ',test_amp[i])
    print('predict_center','[',prediction[3][i][0],prediction[3][i][1],prediction[3][i][2],']')
# Out:
# real_center   [ 0.          5.71315308 11.91923309]
# predict_center [ 0.0039735883 5.6910634 11.8918705 ]
# ---------------
# real_width    [0.         0.84337558 1.79121459]
# predict_center [ -0.004256904 0.73910594 1.8359665 ]
# ---------------
# real_amp      [0.         0.88023975 1.04841723]
# predict_center [ 0.01282219 0.7047068 1.0319519 ]
# real_center   [ 0.          6.39994478 12.93951819]
# predict_center [ 0.0029347986 6.23528 12.990507 ]
# ---------------
# real_width    [0.         1.65652237 0.93438808]
# predict_center [ 0.0020548552 1.6132908 0.9689723 ]
# ---------------
# real_amp      [0.         0.99348086 0.9478093 ]
# predict_center [ 0.01612022 0.805668 0.9419727 ]
# real_center   [ 3.23631434  6.18606995 12.52827948]
# predict_center [ 3.1575062 6.213584 12.471586 ]
# ---------------
# real_width    [1.66278035 1.68069287 1.00126402]
# predict_center [ 1.680693 1.5979885 1.0322552 ]
# ---------------
# real_amp      [0.17531519 0.19742663 0.9243484 ]
# predict_center [ 0.24470049 0.25678703 0.46123993 ]
# real_center   [ 0.          3.86715569 10.86221601]
# predict_center [ 0.006199226 3.8061955 10.973526 ]
# ---------------
# real_width    [0.         0.59165533 0.40581259]
# predict_center [ -0.0029040575 0.5982506 0.44070745 ]
# ---------------
# real_amp      [0.         0.51955378 0.53934786]
# predict_center [ 0.008609256 0.6119109 0.55334765 ]
# real_center   [ 0.          9.45233636 12.62868582]
# predict_center [ -0.005802408 9.267488 12.444973 ]
# ---------------
# real_width    [0.         1.44668865 1.87998592]
# predict_center [ -0.0019120574 1.4667166 1.802176 ]
# ---------------
# real_amp      [0.         0.91245941 0.36050666]
# predict_center [ 0.008095803 0.91324174 0.4928738 ]
# real_center   [0.         2.00332775 6.03248714]
# predict_center [ 0.007934436 2.099861 6.1180973 ]
# ---------------
# real_width    [0.         0.59737084 0.7272154 ]
# predict_center [ -0.014063761 0.46601695 0.77477664 ]
# ---------------
# real_amp      [0.         0.90353073 0.66262424]
# predict_center [ 0.01606022 0.67404914 0.8574027 ]
# real_center   [ 0.         11.42268043 12.25882526]
# predict_center [ -0.00088872015 11.548889 12.407328 ]
# ---------------
# real_width    [0.         0.75334379 1.47571775]
# predict_center [ -0.0004497245 0.72996587 1.3922577 ]
# ---------------
# real_amp      [0.         0.59638167 0.17278906]
# predict_center [ 0.0018866044 0.4679746 0.3044919 ]
# real_center   [ 2.57538501  2.73040878 12.45116549]
# predict_center [ 2.6025462 2.776454 12.626007 ]
# ---------------
# real_width    [0.41405293 0.60919744 1.12779081]
# predict_center [ 0.48342323 0.5526657 1.1447946 ]
# ---------------
# real_amp      [0.5085511  0.80758984 0.70893355]
# predict_center [ 0.7740586 0.5696995 0.67003673 ]
# real_center   [ 2.9017155   7.54113871 10.03829508]
# predict_center [ 2.882795 7.466279 10.108912 ]
# ---------------
# real_width    [0.3609779 1.5868491 1.5857514]
# predict_center [ 0.4667011 1.4406619 1.5837014 ]
# ---------------
# real_amp      [0.9967733  0.57811673 0.29408781]
# predict_center [ 1.0337592 0.54386115 0.57501197 ]
# real_center   [5.70187413 6.47325447 7.95269075]
# predict_center [ 5.880145 6.484186 7.9796987 ]
# ---------------
# real_width    [0.35270478 1.15793397 1.67777024]
# predict_center [ 0.97128844 0.9996202 1.54365 ]
# ---------------
# real_amp      [0.28978847 0.72433166 0.41654231]
# predict_center [ 0.4512799 0.51852596 0.40453017 ]
# real_center   [ 0.          4.21687094 12.34120659]
# predict_center [ 0.0065033287 4.197452 12.469221 ]
# ---------------
# real_width    [0.         0.36773928 0.81390437]
# predict_center [ -0.010150239 0.43864202 0.8827589 ]
# ---------------
# real_amp      [0.         0.78705796 0.79347587]
# predict_center [ 0.014901193 0.80988824 0.7525212 ]
# real_center   [ 7.64690374  7.88672447 11.75998207]
# predict_center [ 7.630173 8.157669 11.952778 ]
# ---------------
# real_width    [1.57721792 0.35065511 1.76987164]
# predict_center [ 1.4917748 0.4749205 1.819183 ]
# ---------------
# real_amp      [0.15874303 0.52349397 0.94926077]
# predict_center [ 0.266121 0.38904846 1.0439329 ]
# real_center   [2.97550177 6.17211837 8.66438667]
# predict_center [ 2.9466102 6.028558 8.574226 ]
# ---------------
# real_width    [1.63453699 0.70265382 0.91474209]
# predict_center [ 1.6804883 0.61112916 0.90507543 ]
# ---------------
# real_amp      [0.76022675 1.01366238 1.09569614]
# predict_center [ 0.86261016 0.87792397 0.8130237 ]
# real_center   [ 0.          9.77946893 10.97017916]
# predict_center [ -0.014285818 9.860644 10.960363 ]
# ---------------
# real_width    [0.         0.39829634 1.05510464]
# predict_center [ -0.0014882013 0.4369817 1.011801 ]
# ---------------
# real_amp      [0.         1.01298834 0.78358955]
# predict_center [ 0.01611639 0.95012736 0.80755824 ]
# real_center   [ 3.8569353   4.12070216 12.11402843]
# predict_center [ 3.7736566 4.003797 12.181415 ]
# ---------------
# real_width    [0.4981711  0.58429175 1.10961953]
# predict_center [ 0.46617407 0.5590821 1.2115922 ]
# ---------------
# real_amp      [0.83741193 0.49685655 0.19540706]
# predict_center [ 0.66946507 0.6203904 0.6679504 ]
# real_center   [2.4287244  8.00130851 8.73111697]
# predict_center [ 2.3195686 8.039495 8.645803 ]
# ---------------
# real_width    [1.30205305 0.73029477 1.26629847]
# predict_center [ 1.1089616 0.7763541 1.1774825 ]
# ---------------
# real_amp      [0.414536   0.85436318 0.82462015]
# predict_center [ 0.7109304 0.9076272 0.8751966 ]
# real_center   [0.         4.6604788  7.58096173]
# predict_center [ -0.0066111237 4.5890427 7.465727 ]
# ---------------
# real_width    [0.         0.74087437 0.40953535]
# predict_center [ -0.005060002 0.7522552 0.56405103 ]
# ---------------
# real_amp      [0.         1.0195198  1.04926695]
# predict_center [ 0.02548022 0.9440818 1.0271721 ]
# real_center   [ 0.          4.61549707 12.73793585]
# predict_center [ 0.004806742 4.5466323 12.630832 ]
# ---------------
# real_width    [0.         1.11693444 1.17194019]
# predict_center [ 0.0017337352 1.0415888 1.0744126 ]
# ---------------
# real_amp      [0.         0.53062024 0.33579517]
# predict_center [ 0.0035604257 0.5316663 0.3593356 ]
# real_center   [ 5.12023748  5.84530511 10.99748078]
# predict_center [ 5.0567026 5.7791486 10.999959 ]
# ---------------
# real_width    [1.34057725 0.74437628 1.38113455]
# predict_center [ 1.2473648 0.70469534 1.4654202 ]
# ---------------
# real_amp      [0.84935913 0.70472954 0.46106577]
# predict_center [ 0.83870834 0.8207104 0.5800146 ]
# real_center   [ 8.0085005   8.9801749  11.72798113]
# predict_center [ 7.9801126 8.91267 11.708109 ]
# ---------------
# real_width    [1.09531881 1.22843115 0.76551006]
# predict_center [ 1.0303326 1.4594585 0.5866852 ]
# ---------------
# real_amp      [0.71929417 0.23130514 0.83006498]
# predict_center [ 0.52537555 0.50803816 0.4750008 ]

# %%
plt.style.use(["seaborn-whitegrid"])
plt.figure(figsize = (12, 6))

# only three peaks
bg = np.loadtxt("ITO_O1s_bg.txt")
exp = np.loadtxt("ITO_O1s_exp.txt")
fitting = np.loadtxt("ITO_O1s_fitting.txt")
peak1 = np.loadtxt("ITO_O1s_p1.txt")
peak2 = np.loadtxt("ITO_O1s_p2.txt")
peak3 = np.loadtxt("ITO_O1s_p3.txt")

# 테스트하고자 하는 실제 XPS 데이터의 parameter 범위가 너무 크므로 
# 네트워크 자체는 작은 규모의 파라미터 범위에서 학습시키고,
# 테스트할 경우, 범위를 줄인 xps 데이터를 불러와서 테스트해본다..

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

#plt.plot(fitting[:, 0], fitting[:, 1] - bg[:, 1], label = "fitting", linewidth = 2)

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)
plt.plot(peak3[:, 0], (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3', linewidth = 2)

plt.grid(True)
plt.title("P3HT Fitting and experiment", size = 24)
plt.xlabel("Energy range", size = 24)
plt.ylabel("Intensity", size = 24)
plt.legend()
plt.show()

# %%
# normalize된 그래프의 y값

test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
plt.plot(test_result[0])
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[2.0067925]], dtype=float32), array([[-1.0687292e-02,  1.0192092e+01,  1.0798068e+01]], dtype=float32), array([[0.00246109, 1.7355572 , 0.747728  ]], dtype=float32), array([[0.00934237, 0.43679255, 0.73876923]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  # num_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
peak_1 = [new_predict[1][0], new_predict[2][0], new_predict[3][0]]
peak_2 = [new_predict[1][1], new_predict[2][1], new_predict[3][1]]
peak_3 = [new_predict[1][2], new_predict[2][2], new_predict[3][2]]

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
# plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
# plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed",color='black')
plt.title("Network fitting vs real XPS graph", size = 24)
# Out:
# Text(0.5, 1.0, 'Network fitting vs real XPS graph')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color='blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2, color='black')
plt.title("Predict_peak1 vs Xps_peak1", size = 24)
# Out:
# Text(0.5, 1.0, 'Predict_peak1 vs Xps_peak1')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color='blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak2 vs Xps_peak2')

# %%
plt.figure(figsize = (12,6))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color='blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = 'peak3',color = 'black', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
# Out:
# Text(0.5, 1.0, 'Pre_peak3 vs Xps_peak3')

# %%
new_predict[1][0],new_predict[2][0],new_predict[3][0]
# Out:
# (-0.0068677515, -0.006193593, 0.012514757)

# %%
new_predict[0][0]# peak_number을 2로 인식하는구나..데이터의 문제인건가
# Out:
# 1.9995167

# %%
# only two peak
bg = np.loadtxt("P3HT_S2p_bg.txt")
exp = np.loadtxt("P3HT_S2p_exp.txt")
fitting = np.loadtxt("P3HT_S2p_fitting.txt")
peak1 = np.loadtxt("P3HT_S2p_p1.txt")
peak2 = np.loadtxt("P3HT_S2p_p2.txt")

# %%
plt.figure(figsize = (12, 6))

# exp data에서 background를 제거하고, peak 높이를 1로 normalize한다.
plt.plot(exp[:, 0], (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()), label = "exp bg removed")

# 마찬가지로 개별 peak도 크기를 줄인다.
plt.plot(peak1[:, 0], (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak1", linewidth = 2)
plt.plot(peak2[:, 0], (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()), label = "peak2", linewidth = 2)

# %%
# normalize된 그래프의 y값
test_result = ((exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max())).reshape((1, 401, 1))
print(test_result.shape)
# Out:
# (1, 401, 1)

# %%
predict = model.predict(test_result)
print(predict)
# Out:
# [array([[1.9995167]], dtype=float32), array([[-6.8677515e-03,  6.9617901e+00,  7.8977852e+00]], dtype=float32), array([[-0.00619359,  0.8432464 ,  0.57958925]], dtype=float32), array([[0.01251476, 0.6725843 , 1.0271295 ]], dtype=float32)]

# %%
new_predict = []

for element in predict:
    new_predict.append(element.reshape((element.shape[1])))

# %%
print(new_predict[0].shape)  #number_peak
print(new_predict[1].shape)  # center
print(new_predict[2].shape)  # width
print(new_predict[3].shape)  # amp
# Out:
# (1,)
# (3,)
# (3,)
# (3,)

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x)+
         y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x)+
         y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (exp[:, 1] - bg[:, 1]) / ((exp[:, 1] - bg[:, 1]).max()),color = 'black', label = "exp bg removed")
plt.title("Network fitting vs real XPS graph", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][2],new_predict[2][2],new_predict[3][2],x),color = 'blue')
plt.plot(x, (peak1[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak1", linewidth = 2)
plt.title("Pre_peak1 vs Xps_peak1", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][1],new_predict[2][1],new_predict[3][1],x),color = 'blue')
plt.plot(x, (peak2[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = "peak2", linewidth = 2)
plt.title("Pre_peak2 vs Xps_peak2", size = 24)
plt.legend()

# %%
plt.figure(figsize = (25,15))
plt.plot(x,y(new_predict[1][0],new_predict[2][0],new_predict[3][0],x),color = 'blue')
plt.plot(x, (peak3[:, 1] - bg[:, 1])/ ((exp[:, 1] - bg[:, 1]).max()),color='black', label = 'peak3', linewidth = 2)
plt.title("Pre_peak3 vs Xps_peak3", size = 24)
plt.legend()

# %%
error_center_total=0
for i in range(test_center.shape[0]):
    error_center_total = error_center_total + (abs(prediction[1][i]-test_center[i]))
print('error_center_total = ',error_center_total)
error_center = error_center_total/test_center.shape[0]
print('error_center =  ',error_center)
print('\n')

error_width_total=0
for i in range(test_width.shape[0]):
    error_width_total = error_width_total + (abs(prediction[2][i]-test_width[i]))
print('error_width_total = ',error_width_total)
error_width = error_width_total/test_width.shape[0]
print('error_width =  ',error_width)
print('\n')

error_amp_total=0
for i in range(test_amp.shape[0]):
    error_amp_total = error_amp_total + (abs(prediction[3][i]-test_amp[i]))
print('error_amp_total = ',error_amp_total)
error_amp = error_amp_total/test_amp.shape[0]
print('error_amp =  ',error_amp)
print('\n')
# Out:
# error_center_total =  [1518.82698349 3105.26782471 1905.18768574]
# error_center =   [0.07594135 0.15526339 0.09525938]
#
#
# error_width_total =  [1406.16937432 2500.37373696 1939.63441008]
# error_width =   [0.07030847 0.12501869 0.09698172]
#
#
# error_amp_total =  [1736.81578756 2283.71840307 2474.91737511]
# error_amp =   [0.08684079 0.11418592 0.12374587]

# %%
#바꾼것

# loss _weight  안만지고 
# center,width,amp 200 100 40늘리고
# peak_number 마지막 출력측 1로 해놓음

# %%
#효과

# 확실히 amp하고 width가 줄었어

# %%
#수정할거 

#해놓을거 loss_weight를 center= 0.5로 낮추고
# conv1d마지막 출력층 올릴거
# 잔차함수까지
# 그러면서 전체층수 줄이고

# %%
# 문제점

# 계쏙 peak를 2개로 보고있어..데이터의 문제인가
